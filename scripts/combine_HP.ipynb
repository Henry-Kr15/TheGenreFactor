# %% [markdown]
# # Werte aus verschiedenen HPOs werden kombiniert

# %%
import pandas as pd

df1= pd.read_csv('../data/optimization_results_chris_2707.csv')
df1.head()
# Out:
#    num_hidden_layers  units_1  units_2  units_3  units_4  dropout_rate
# 0                  2      128      256      512     1024           0.2  \
# 1                  2      128      256      512     1024           0.2
# 2                  2      128      256      512     1024           0.2
# 3                  2      128      256      512     1024           0.2
# 4                  2      128      256      512     1024           0.2
#
#   activation_function  batch_size  early_stopping_patience  reduce_lr_factor
# 0                relu          64                       15               0.1  \
# 1                relu          64                       15               0.1
# 2                relu          64                       20               0.1
# 3                relu          64                       20               0.1
# 4                relu         128                       15               0.1
#
#    ...  optimizer  best_val_accuracy val_accuracy_std  best_val_loss
# ...

# %%
df2= pd.read_csv('../data/optimization_results_final.csv')
df2['optimizer'] = 'adam'
df2.head()
# Out:
#    num_hidden_layers  units_1  units_2  units_3  units_4  dropout_rate
# 0                  2       64      128      256      512           0.3  \
# 1                  2       64      128      256      512           0.3
# 2                  2       64      128      256      512           0.3
# 3                  2       64      128      256      512           0.3
# 4                  2       64      128      256      512           0.3
#
#   activation_function  batch_size  early_stopping_patience  reduce_lr_factor
# 0           LeakyReLU         512                       15               0.1  \
# 1           LeakyReLU         512                       15               0.1
# 2           LeakyReLU         512                       15               0.1
# 3           LeakyReLU         512                       15               0.1
# 4           LeakyReLU         512                       15               0.5
#
#    ...  best_val_accuracy  val_accuracy_std  best_val_loss  val_loss_std
# ...
