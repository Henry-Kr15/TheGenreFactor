# %% [markdown]
# # Neuronales Netz

# %% [markdown]
# ### Daten laden

# %%
import pandas as pd

csv_file = "../data/data_selected_v1.csv"

df = pd.read_csv(csv_file)
df.columns
# Out:
# Index(['Unnamed: 0', 'Danceability', 'Energy', 'Key', 'Loudness',
#        'Speechiness', 'Acousticness', 'Instrumentalness', 'Liveness',
#        'Valence', 'Tempo', 'Duration_ms', 'Views', 'Likes', 'Comments',
#        'Stream', 'Genre', 'Artist_encoded', 'Album_type_encoded',
#        'Licensed_encoded', 'official_video_encoded'],
#       dtype='object')

# %%
import tensorflow as tf
# Manuell auf CPU einschränken
tf.config.set_visible_devices([], "GPU")

# %% [markdown]
# ### Genres für das Training auswählen

# %%
genres_to_keep = ["classic", "metal", "rock", "hip hop", "electronic", "pop"]
df = df[df['Genre'].isin(genres_to_keep)]

# %%
import matplotlib.pyplot as plt

# Anzahl der Einträge pro Genre
genre_counts = df['Genre'].value_counts()
print(genre_counts)
# Histogramm erstellen
plt.figure(figsize=(10, 6))
genre_counts.plot(kind='bar')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.title('barchart of class imbalance')
plt.savefig('../figures/genre_hist.pdf')
print(f"Anzahl an Songs: {df.shape[0]}")
# Out:
# Genre
# hip hop       2361
# rock          1418
# pop           1391
# electronic     677
# metal          430
# classic        169
# Name: count, dtype: int64
# Anzahl an Songs: 6446

# %% [markdown]
# ### Designmatrix und Target erstellen

# %%
features_drop = ['Genre', 'Unnamed: 0']

df = df.sample(frac=1, random_state=42) #daten mischen

X = df.drop(features_drop, axis=1)
Y = df['Genre']

# %%
# One-Hot-Encoding durchführen
Y = pd.get_dummies(Y)
num_classes = len(Y.value_counts())

# label um One-Hot-Encoding hinterher wieder zu übersetzen
genre_mapping = Y.columns
label = []
for index, genre in enumerate(genre_mapping):
    label.append(genre)
    print("Genre", index, ":", genre)
# Out:
# Genre 0 : classic
# Genre 1 : electronic
# Genre 2 : hip hop
# Genre 3 : metal
# Genre 4 : pop
# Genre 5 : rock

# %% [markdown]
# ### Split in Train, Validation und Test

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, stratify=Y, random_state=42)
X_train, X_val,  Y_train, Y_val  = train_test_split(X_train, Y_train, test_size=0.3, stratify=Y_train, random_state=42)

# %% [markdown]
# ### Transformation und Skalierung der Features

# %%
from sklearn.preprocessing import QuantileTransformer, MinMaxScaler
# Fit NUR auf train...
transformer = QuantileTransformer(output_distribution="normal")
transformer.fit(X_train)

# ... dann transform auf alle
X_train = transformer.transform(X_train)
X_val = transformer.transform(X_val)
X_test = transformer.transform(X_test)

# Werte der Attribute mit MinMax auf [-1,1] skalieren
scaler = MinMaxScaler(feature_range=(-1, 1))
# Fit wieder auf train...
scaler.fit(X_train)

# ... dann wieder transform
X_train = scaler.transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# %% [markdown]
# ### Modell

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import numpy as np
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

def build_model_from_params(params):
    num_hidden_layers = params['num_hidden_layers']
    activation_function = params['activation_function']
    dropout_rate = params['dropout_rate']
    units_per_layer = [params['units_1'],params['units_2'],params['units_3'],params['units_4']]

    model = Sequential()
    model.add(Dense(units=units_per_layer[0], activation=activation_function, input_dim=X_train.shape[1]))
    model.add(Dropout(dropout_rate))

    for i in range(1, num_hidden_layers+1):
        if i < len(units_per_layer):
            model.add(Dense(units=units_per_layer[i], activation=activation_function))
            model.add(Dropout(dropout_rate))

    model.add(Dense(units=num_classes, activation='softmax'))
    
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %% [markdown]
# ### Kombinationen aller Hyperparameter

# %%
import itertools

param_space = {
    'num_hidden_layers': [2, 3],
    'units_1': [64, 128],
    'units_2': [128, 256],
    'units_3': [256, 512],
    'units_4': [512, 1024],
    'dropout_rate': [0.3, 0.5],
    'activation_function': ['LeakyReLU', "relu"],
    'batch_size' : [128, 256, 512, 1024],
    'early_stopping_patience': [15, 20],
    'reduce_lr_factor': [0.1, 0.5],
    'reduce_lr_patience': [5, 7],
    'reduce_lr_min_lr': [1e-7, 1e-5],
}

#param_space = {
#    'num_hidden_layers': [2, 3],
#    'units_1': [64, 128, 256],
#    'units_2': [128, 256, 512],
#    'units_3': [256, 512, 1024],
#    'units_4': [512, 1024],
#    'dropout_rate': [0.3, 0.5, 0.7],
#    'activation_function': ['relu', 'LeakyReLU'],
#    'batch_size' : [128, 256, 512],
#    'early_stopping_patience': [5, 10, 15],
#    'reduce_lr_factor': [0.1, 0.5, 0.9],
#    'reduce_lr_patience': [5, 10, 15],
#    'reduce_lr_min_lr': [1e-7, 1e-5, 1e-3],
#}

value_combis = itertools.product(*[v for v in param_space.values()])

# List comprehension short form:
param_combis = [{key:value for key, value in zip(param_space.keys(), combi)} for combi in value_combis]

print(f"We have a total of {len(param_combis)} combinations:")
# Out:
# We have a total of 8192 combinations:

# %% [markdown]
# ### Hyperparameteroptimierung

# %%
import time

# Start der Zeitmessung
start_time = time.time()

search_results = []

search_results = []

k_folds = 3
skf = StratifiedKFold(n_splits=k_folds)

for idx, params in enumerate(param_combis):
    print(f"Start run {idx+1}/{len(param_combis)}: Parameters: {params}")
    
    val_accuracies = []
    val_losses = []
    train_accuracies = []
    train_losses = []
    
    for fold_idx, (train_index, val_index) in enumerate(skf.split(X_train, np.argmax(Y_train, axis=1))):
        X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
        Y_train_fold, Y_val_fold = Y_train.reset_index(drop=True).iloc[train_index], Y_train.reset_index(drop=True).iloc[val_index]
        
        filepath = f"../model_fold/model_fold_{idx+1}_fold_{fold_idx+1}.h5"
        checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=0, save_best_only=True, mode='max')
        
        this_model = build_model_from_params(params)
        
        batch_size = params['batch_size']
        nb_epoch = 60

        early_stopping = EarlyStopping(monitor='val_loss', patience=params['early_stopping_patience'], mode='min', restore_best_weights=True)
        reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=params['reduce_lr_factor'], patience=params['reduce_lr_patience'], mode='min', min_lr=params['reduce_lr_min_lr'])
        fit_results = this_model.fit(X_train_fold, Y_train_fold, validation_data=(X_val_fold, Y_val_fold), 
                 epochs=nb_epoch, batch_size=batch_size, callbacks=[checkpoint, early_stopping, reduce_lr], verbose=0)
        
        # Extract the best validation scores
        best_val_epoch = np.argmax(fit_results.history['val_accuracy'])
        val_accuracies.append(np.max(fit_results.history['val_accuracy']))
        val_losses.append(fit_results.history['val_loss'][best_val_epoch])
        
        # Get training accuracy and loss
        best_model = load_model(filepath)
        train_loss, train_acc = best_model.evaluate(X_train_fold, Y_train_fold)
        train_accuracies.append(train_acc)
        train_losses.append(train_loss)
    
    # Store results
    search_results.append({
        **params,
        'best_val_accuracy': np.mean(val_accuracies),
        'val_accuracy_std': np.std(val_accuracies),
        'best_val_loss': np.mean(val_losses),
        'val_loss_std': np.std(val_losses),
        'best_train_accuracy': np.mean(train_accuracies),
        'train_accuracy_std': np.std(train_accuracies),
        'best_train_loss': np.mean(train_losses),
        'train_loss_std': np.std(train_losses)
    })

# Ende der Zeitmessung
end_time = time.time()

# Berechnung der verstrichenen Zeit in Stunden
elapsed_time_hours = (end_time - start_time) / 3600

print(f"Die Ausführung dieser Zelle hat {elapsed_time_hours} Stunden gedauert.")
# Out:
# Start run 1/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 128, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 520us/step - loss: 0.8409 - accuracy: 0.6817
# 66/66 [==============================] - 0s 517us/step - loss: 0.8640 - accuracy: 0.6694
# 66/66 [==============================] - 0s 510us/step - loss: 0.8719 - accuracy: 0.6610
# Start run 2/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 128, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 469us/step - loss: 0.8499 - accuracy: 0.6789
# 66/66 [==============================] - 0s 483us/step - loss: 0.8403 - accuracy: 0.6770
# 66/66 [==============================] - 0s 528us/step - loss: 0.8666 - accuracy: 0.6657
# Start run 3/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 128, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 515us/step - loss: 0.8181 - accuracy: 0.6950
# 66/66 [==============================] - 0s 487us/step - loss: 0.8125 - accuracy: 0.6831
# 66/66 [==============================] - 0s 519us/step - loss: 0.9070 - accuracy: 0.6519
# Start run 4/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 128, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 513us/step - loss: 0.8347 - accuracy: 0.6822
# 66/66 [==============================] - 0s 503us/step - loss: 0.8479 - accuracy: 0.6703
# 66/66 [==============================] - 0s 535us/step - loss: 0.8639 - accuracy: 0.6686
# Start run 5/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 128, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 488us/step - loss: 0.8357 - accuracy: 0.6860
# 66/66 [==============================] - 0s 486us/step - loss: 0.8312 - accuracy: 0.6784
# 66/66 [==============================] - 0s 509us/step - loss: 0.8625 - accuracy: 0.6690
# Start run 6/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 128, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 499us/step - loss: 0.8319 - accuracy: 0.6907
# 66/66 [==============================] - 0s 495us/step - loss: 0.8164 - accuracy: 0.6812
# 66/66 [==============================] - 0s 504us/step - loss: 0.8405 - accuracy: 0.6776
# Start run 7/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 128, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 508us/step - loss: 0.8480 - accuracy: 0.6812
# 66/66 [==============================] - 0s 475us/step - loss: 0.8501 - accuracy: 0.6746
# 66/66 [==============================] - 0s 507us/step - loss: 0.8648 - accuracy: 0.6700
# Start run 8/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 128, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 500us/step - loss: 0.8042 - accuracy: 0.7055
# 66/66 [==============================] - 0s 473us/step - loss: 0.8362 - accuracy: 0.6841
# 66/66 [==============================] - 0s 471us/step - loss: 0.8482 - accuracy: 0.6738
# Start run 9/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 128, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 476us/step - loss: 0.8327 - accuracy: 0.6841
# 66/66 [==============================] - 0s 499us/step - loss: 0.8571 - accuracy: 0.6703
# 66/66 [==============================] - 0s 525us/step - loss: 0.8555 - accuracy: 0.6681
# Start run 10/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 128, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 500us/step - loss: 0.8431 - accuracy: 0.6846
# 66/66 [==============================] - 0s 501us/step - loss: 0.8303 - accuracy: 0.6817
# 66/66 [==============================] - 0s 494us/step - loss: 0.8614 - accuracy: 0.6648
# Start run 11/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 128, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 489us/step - loss: 0.8120 - accuracy: 0.7002
# 66/66 [==============================] - 0s 512us/step - loss: 0.8259 - accuracy: 0.6812
# 66/66 [==============================] - 0s 494us/step - loss: 0.8867 - accuracy: 0.6629
# Start run 12/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 128, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 545us/step - loss: 0.8325 - accuracy: 0.6888
# 66/66 [==============================] - 0s 502us/step - loss: 0.8455 - accuracy: 0.6736
# 66/66 [==============================] - 0s 480us/step - loss: 0.8453 - accuracy: 0.6700
# Start run 13/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 128, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 537us/step - loss: 0.8461 - accuracy: 0.6789
# 66/66 [==============================] - 0s 530us/step - loss: 0.8282 - accuracy: 0.6827
# 66/66 [==============================] - 0s 513us/step - loss: 0.8504 - accuracy: 0.6700
# Start run 14/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 128, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 533us/step - loss: 0.8390 - accuracy: 0.6874
# 66/66 [==============================] - 0s 507us/step - loss: 0.8462 - accuracy: 0.6789
# 66/66 [==============================] - 0s 531us/step - loss: 0.8685 - accuracy: 0.6662
# Start run 15/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 128, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 494us/step - loss: 0.8469 - accuracy: 0.6779
# 66/66 [==============================] - 0s 511us/step - loss: 0.8236 - accuracy: 0.6789
# 66/66 [==============================] - 0s 474us/step - loss: 0.8577 - accuracy: 0.6638
# Start run 16/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 128, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 509us/step - loss: 0.8523 - accuracy: 0.6817
# 66/66 [==============================] - 0s 476us/step - loss: 0.8388 - accuracy: 0.6755
# 66/66 [==============================] - 0s 533us/step - loss: 0.8418 - accuracy: 0.6686
# Start run 17/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 513us/step - loss: 0.8765 - accuracy: 0.6689
# 66/66 [==============================] - 0s 525us/step - loss: 0.8718 - accuracy: 0.6646
# 66/66 [==============================] - 0s 508us/step - loss: 0.9019 - accuracy: 0.6586
# Start run 18/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 512us/step - loss: 0.8899 - accuracy: 0.6641
# 66/66 [==============================] - 0s 503us/step - loss: 0.8648 - accuracy: 0.6679
# 66/66 [==============================] - 0s 486us/step - loss: 0.8902 - accuracy: 0.6610
# Start run 19/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 524us/step - loss: 0.8498 - accuracy: 0.6869
# 66/66 [==============================] - 0s 520us/step - loss: 0.8606 - accuracy: 0.6684
# 66/66 [==============================] - 0s 486us/step - loss: 0.8986 - accuracy: 0.6605
# Start run 20/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 488us/step - loss: 0.8744 - accuracy: 0.6717
# 66/66 [==============================] - 0s 504us/step - loss: 0.8718 - accuracy: 0.6651
# 66/66 [==============================] - 0s 501us/step - loss: 0.9010 - accuracy: 0.6510
# Start run 21/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 493us/step - loss: 0.8612 - accuracy: 0.6765
# 66/66 [==============================] - 0s 535us/step - loss: 0.8499 - accuracy: 0.6646
# 66/66 [==============================] - 0s 492us/step - loss: 0.9165 - accuracy: 0.6496
# Start run 22/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 519us/step - loss: 0.8799 - accuracy: 0.6689
# 66/66 [==============================] - 0s 513us/step - loss: 0.8491 - accuracy: 0.6760
# 66/66 [==============================] - 0s 543us/step - loss: 0.8794 - accuracy: 0.6667
# Start run 23/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 492us/step - loss: 0.9060 - accuracy: 0.6618
# 66/66 [==============================] - 0s 513us/step - loss: 0.8443 - accuracy: 0.6755
# 66/66 [==============================] - 0s 486us/step - loss: 0.8806 - accuracy: 0.6600
# Start run 24/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 525us/step - loss: 0.8342 - accuracy: 0.6884
# 66/66 [==============================] - 0s 494us/step - loss: 0.8717 - accuracy: 0.6641
# 66/66 [==============================] - 0s 491us/step - loss: 0.8860 - accuracy: 0.6652
# Start run 25/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 479us/step - loss: 0.8818 - accuracy: 0.6694
# 66/66 [==============================] - 0s 498us/step - loss: 0.8847 - accuracy: 0.6632
# 66/66 [==============================] - 0s 547us/step - loss: 0.8997 - accuracy: 0.6524
# Start run 26/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 500us/step - loss: 0.8701 - accuracy: 0.6746
# 66/66 [==============================] - 0s 519us/step - loss: 0.8914 - accuracy: 0.6565
# 66/66 [==============================] - 0s 488us/step - loss: 0.9008 - accuracy: 0.6562
# Start run 27/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 516us/step - loss: 0.8662 - accuracy: 0.6803
# 66/66 [==============================] - 0s 509us/step - loss: 0.8498 - accuracy: 0.6713
# 66/66 [==============================] - 0s 505us/step - loss: 0.9252 - accuracy: 0.6472
# Start run 28/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 501us/step - loss: 0.8615 - accuracy: 0.6803
# 66/66 [==============================] - 0s 485us/step - loss: 0.8481 - accuracy: 0.6713
# 66/66 [==============================] - 0s 485us/step - loss: 0.8765 - accuracy: 0.6633
# Start run 29/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 533us/step - loss: 0.8801 - accuracy: 0.6708
# 66/66 [==============================] - 0s 483us/step - loss: 0.8466 - accuracy: 0.6770
# 66/66 [==============================] - 0s 501us/step - loss: 0.8734 - accuracy: 0.6657
# Start run 30/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 522us/step - loss: 0.8462 - accuracy: 0.6779
# 66/66 [==============================] - 0s 530us/step - loss: 0.8491 - accuracy: 0.6722
# 66/66 [==============================] - 0s 488us/step - loss: 0.8906 - accuracy: 0.6591
# Start run 31/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 482us/step - loss: 0.8453 - accuracy: 0.6855
# 66/66 [==============================] - 0s 489us/step - loss: 0.8744 - accuracy: 0.6599
# 66/66 [==============================] - 0s 536us/step - loss: 0.8891 - accuracy: 0.6629
# Start run 32/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 584us/step - loss: 0.8885 - accuracy: 0.6670
# 66/66 [==============================] - 0s 505us/step - loss: 0.8427 - accuracy: 0.6722
# 66/66 [==============================] - 0s 522us/step - loss: 0.8849 - accuracy: 0.6643
# Start run 33/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 513us/step - loss: 0.8940 - accuracy: 0.6632
# 66/66 [==============================] - 0s 537us/step - loss: 0.8926 - accuracy: 0.6537
# 66/66 [==============================] - 0s 482us/step - loss: 0.9782 - accuracy: 0.6330
# Start run 34/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 539us/step - loss: 0.9215 - accuracy: 0.6641
# 66/66 [==============================] - 0s 489us/step - loss: 0.9073 - accuracy: 0.6489
# 66/66 [==============================] - 0s 505us/step - loss: 0.9427 - accuracy: 0.6453
# Start run 35/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 498us/step - loss: 0.9052 - accuracy: 0.6570
# 66/66 [==============================] - 0s 506us/step - loss: 0.8930 - accuracy: 0.6565
# 66/66 [==============================] - 0s 508us/step - loss: 0.9460 - accuracy: 0.6401
# Start run 36/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 505us/step - loss: 0.9129 - accuracy: 0.6599
# 66/66 [==============================] - 0s 512us/step - loss: 0.8985 - accuracy: 0.6499
# 66/66 [==============================] - 0s 559us/step - loss: 0.9374 - accuracy: 0.6515
# Start run 37/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 539us/step - loss: 0.8721 - accuracy: 0.6717
# 66/66 [==============================] - 0s 566us/step - loss: 0.8809 - accuracy: 0.6618
# 66/66 [==============================] - 0s 556us/step - loss: 0.9282 - accuracy: 0.6458
# Start run 38/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 501us/step - loss: 0.9015 - accuracy: 0.6627
# 66/66 [==============================] - 0s 474us/step - loss: 0.8927 - accuracy: 0.6447
# 66/66 [==============================] - 0s 522us/step - loss: 0.9478 - accuracy: 0.6406
# Start run 39/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 493us/step - loss: 0.8869 - accuracy: 0.6689
# 66/66 [==============================] - 0s 528us/step - loss: 0.9028 - accuracy: 0.6570
# 66/66 [==============================] - 0s 502us/step - loss: 0.9208 - accuracy: 0.6443
# Start run 40/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 499us/step - loss: 0.8953 - accuracy: 0.6660
# 66/66 [==============================] - 0s 488us/step - loss: 0.9063 - accuracy: 0.6485
# 66/66 [==============================] - 0s 506us/step - loss: 0.9163 - accuracy: 0.6496
# Start run 41/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 512, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 509us/step - loss: 0.9070 - accuracy: 0.6637
# 66/66 [==============================] - 0s 530us/step - loss: 0.8946 - accuracy: 0.6589
# 66/66 [==============================] - 0s 478us/step - loss: 0.9309 - accuracy: 0.6453
# Start run 42/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 512, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 489us/step - loss: 0.8911 - accuracy: 0.6632
# 66/66 [==============================] - 0s 503us/step - loss: 0.8878 - accuracy: 0.6622
# 66/66 [==============================] - 0s 492us/step - loss: 0.9259 - accuracy: 0.6453
# Start run 43/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 512, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 485us/step - loss: 0.8991 - accuracy: 0.6694
# 66/66 [==============================] - 0s 548us/step - loss: 0.8811 - accuracy: 0.6551
# 66/66 [==============================] - 0s 505us/step - loss: 0.9141 - accuracy: 0.6534
# Start run 44/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 512, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 537us/step - loss: 0.9174 - accuracy: 0.6565
# 66/66 [==============================] - 0s 493us/step - loss: 0.9046 - accuracy: 0.6494
# 66/66 [==============================] - 0s 489us/step - loss: 0.9169 - accuracy: 0.6510
# Start run 45/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 512, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 509us/step - loss: 0.9006 - accuracy: 0.6537
# 66/66 [==============================] - 0s 496us/step - loss: 0.9432 - accuracy: 0.6418
# 66/66 [==============================] - 0s 492us/step - loss: 0.9188 - accuracy: 0.6510
# Start run 46/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 512, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 513us/step - loss: 0.8924 - accuracy: 0.6651
# 66/66 [==============================] - 0s 540us/step - loss: 0.9012 - accuracy: 0.6466
# 66/66 [==============================] - 0s 518us/step - loss: 0.9378 - accuracy: 0.6472
# Start run 47/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 512, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 504us/step - loss: 0.8873 - accuracy: 0.6708
# 66/66 [==============================] - 0s 502us/step - loss: 0.8878 - accuracy: 0.6556
# 66/66 [==============================] - 0s 487us/step - loss: 0.9440 - accuracy: 0.6462
# Start run 48/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 512, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 480us/step - loss: 0.8887 - accuracy: 0.6698
# 66/66 [==============================] - 0s 502us/step - loss: 0.9370 - accuracy: 0.6390
# 66/66 [==============================] - 0s 487us/step - loss: 0.9281 - accuracy: 0.6453
# Start run 49/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 505us/step - loss: 0.9342 - accuracy: 0.6618
# 66/66 [==============================] - 0s 486us/step - loss: 0.9291 - accuracy: 0.6456
# 66/66 [==============================] - 0s 497us/step - loss: 0.9613 - accuracy: 0.6382
# Start run 50/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 497us/step - loss: 0.9578 - accuracy: 0.6413
# 66/66 [==============================] - 0s 486us/step - loss: 0.9482 - accuracy: 0.6390
# 66/66 [==============================] - 0s 489us/step - loss: 0.9675 - accuracy: 0.6325
# Start run 51/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 534us/step - loss: 0.9517 - accuracy: 0.6466
# 66/66 [==============================] - 0s 497us/step - loss: 0.9238 - accuracy: 0.6470
# 66/66 [==============================] - 0s 475us/step - loss: 0.9692 - accuracy: 0.6339
# Start run 52/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 517us/step - loss: 0.9239 - accuracy: 0.6546
# 66/66 [==============================] - 0s 486us/step - loss: 0.9412 - accuracy: 0.6409
# 66/66 [==============================] - 0s 503us/step - loss: 0.9783 - accuracy: 0.6296
# Start run 53/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 501us/step - loss: 0.9509 - accuracy: 0.6442
# 66/66 [==============================] - 0s 491us/step - loss: 0.9381 - accuracy: 0.6513
# 66/66 [==============================] - 0s 504us/step - loss: 0.9661 - accuracy: 0.6401
# Start run 54/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 486us/step - loss: 0.9451 - accuracy: 0.6542
# 66/66 [==============================] - 0s 489us/step - loss: 0.9485 - accuracy: 0.6432
# 66/66 [==============================] - 0s 546us/step - loss: 0.9817 - accuracy: 0.6358
# Start run 55/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 500us/step - loss: 0.9282 - accuracy: 0.6551
# 66/66 [==============================] - 0s 497us/step - loss: 0.9674 - accuracy: 0.6266
# 66/66 [==============================] - 0s 484us/step - loss: 0.9790 - accuracy: 0.6325
# Start run 56/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 483us/step - loss: 0.9363 - accuracy: 0.6527
# 66/66 [==============================] - 0s 479us/step - loss: 0.9277 - accuracy: 0.6461
# 66/66 [==============================] - 0s 505us/step - loss: 0.9883 - accuracy: 0.6349
# Start run 57/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 1024, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 488us/step - loss: 0.9613 - accuracy: 0.6480
# 66/66 [==============================] - 0s 511us/step - loss: 0.9620 - accuracy: 0.6399
# 66/66 [==============================] - 0s 478us/step - loss: 0.9652 - accuracy: 0.6406
# Start run 58/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 1024, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 477us/step - loss: 0.9415 - accuracy: 0.6499
# 66/66 [==============================] - 0s 492us/step - loss: 0.9327 - accuracy: 0.6380
# 66/66 [==============================] - 0s 494us/step - loss: 0.9753 - accuracy: 0.6353
# Start run 59/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 1024, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 491us/step - loss: 0.9351 - accuracy: 0.6542
# 66/66 [==============================] - 0s 513us/step - loss: 0.9443 - accuracy: 0.6375
# 66/66 [==============================] - 0s 522us/step - loss: 0.9900 - accuracy: 0.6220
# Start run 60/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 1024, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 507us/step - loss: 0.9235 - accuracy: 0.6542
# 66/66 [==============================] - 0s 506us/step - loss: 0.9643 - accuracy: 0.6304
# 66/66 [==============================] - 0s 511us/step - loss: 0.9652 - accuracy: 0.6429
# Start run 61/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 1024, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 496us/step - loss: 0.9255 - accuracy: 0.6575
# 66/66 [==============================] - 0s 499us/step - loss: 0.9301 - accuracy: 0.6437
# 66/66 [==============================] - 0s 485us/step - loss: 0.9695 - accuracy: 0.6301
# Start run 62/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 1024, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 528us/step - loss: 0.9422 - accuracy: 0.6556
# 66/66 [==============================] - 0s 497us/step - loss: 0.9500 - accuracy: 0.6447
# 66/66 [==============================] - 0s 539us/step - loss: 0.9804 - accuracy: 0.6277
# Start run 63/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 1024, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 486us/step - loss: 0.9458 - accuracy: 0.6470
# 66/66 [==============================] - 0s 471us/step - loss: 0.9323 - accuracy: 0.6485
# 66/66 [==============================] - 0s 521us/step - loss: 0.9951 - accuracy: 0.6258
# Start run 64/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 1024, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 540us/step - loss: 0.9428 - accuracy: 0.6508
# 66/66 [==============================] - 0s 533us/step - loss: 0.9690 - accuracy: 0.6318
# 66/66 [==============================] - 0s 481us/step - loss: 0.9704 - accuracy: 0.6334
# Start run 65/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'relu', 'batch_size': 128, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 497us/step - loss: 0.8278 - accuracy: 0.6960
# 66/66 [==============================] - 0s 491us/step - loss: 0.8670 - accuracy: 0.6694
# 66/66 [==============================] - 0s 467us/step - loss: 0.8227 - accuracy: 0.6790
# Start run 66/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'relu', 'batch_size': 128, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 455us/step - loss: 0.7780 - accuracy: 0.7121
# 66/66 [==============================] - 0s 480us/step - loss: 0.8150 - accuracy: 0.6869
# 66/66 [==============================] - 0s 490us/step - loss: 0.8463 - accuracy: 0.6795
# Start run 67/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'relu', 'batch_size': 128, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 489us/step - loss: 0.8346 - accuracy: 0.6850
# 66/66 [==============================] - 0s 474us/step - loss: 0.7722 - accuracy: 0.6974
# 66/66 [==============================] - 0s 457us/step - loss: 0.7757 - accuracy: 0.7009
# Start run 68/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'relu', 'batch_size': 128, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 459us/step - loss: 0.8321 - accuracy: 0.7002
# 66/66 [==============================] - 0s 492us/step - loss: 0.7575 - accuracy: 0.7083
# 66/66 [==============================] - 0s 494us/step - loss: 0.7892 - accuracy: 0.7042
# Start run 69/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'relu', 'batch_size': 128, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 488us/step - loss: 0.8175 - accuracy: 0.6969
# 66/66 [==============================] - 0s 464us/step - loss: 0.7621 - accuracy: 0.7107
# 66/66 [==============================] - 0s 488us/step - loss: 0.8168 - accuracy: 0.6876
# Start run 70/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'relu', 'batch_size': 128, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 484us/step - loss: 0.7693 - accuracy: 0.7131
# 66/66 [==============================] - 0s 440us/step - loss: 0.7764 - accuracy: 0.6964
# 66/66 [==============================] - 0s 494us/step - loss: 0.8059 - accuracy: 0.6961
# Start run 71/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'relu', 'batch_size': 128, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 495us/step - loss: 0.8228 - accuracy: 0.6950
# 66/66 [==============================] - 0s 467us/step - loss: 0.8552 - accuracy: 0.6736
# 66/66 [==============================] - 0s 485us/step - loss: 0.8105 - accuracy: 0.6847
# Start run 72/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'relu', 'batch_size': 128, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 484us/step - loss: 0.8397 - accuracy: 0.6793
# 66/66 [==============================] - 0s 471us/step - loss: 0.7968 - accuracy: 0.6969
# 66/66 [==============================] - 0s 510us/step - loss: 0.8388 - accuracy: 0.6795
# Start run 73/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'relu', 'batch_size': 128, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 480us/step - loss: 0.8349 - accuracy: 0.6893
# 66/66 [==============================] - 0s 493us/step - loss: 0.8510 - accuracy: 0.6698
# 66/66 [==============================] - 0s 484us/step - loss: 0.7650 - accuracy: 0.7104
# Start run 74/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'relu', 'batch_size': 128, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 488us/step - loss: 0.8092 - accuracy: 0.6988
# 66/66 [==============================] - 0s 498us/step - loss: 0.8165 - accuracy: 0.6855
# 66/66 [==============================] - 0s 488us/step - loss: 0.7948 - accuracy: 0.6923
# Start run 75/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'relu', 'batch_size': 128, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 471us/step - loss: 0.8279 - accuracy: 0.6884
# 66/66 [==============================] - 0s 538us/step - loss: 0.7878 - accuracy: 0.6945
# 66/66 [==============================] - 0s 484us/step - loss: 0.8136 - accuracy: 0.6952
# Start run 76/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'relu', 'batch_size': 128, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 501us/step - loss: 0.8401 - accuracy: 0.6760
# 66/66 [==============================] - 0s 487us/step - loss: 0.7494 - accuracy: 0.7078
# 66/66 [==============================] - 0s 494us/step - loss: 0.8318 - accuracy: 0.6909
# Start run 77/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'relu', 'batch_size': 128, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 446us/step - loss: 0.8529 - accuracy: 0.6784
# 66/66 [==============================] - 0s 473us/step - loss: 0.8204 - accuracy: 0.6793
# 66/66 [==============================] - 0s 451us/step - loss: 0.8071 - accuracy: 0.6961
# Start run 78/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'relu', 'batch_size': 128, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 477us/step - loss: 0.8029 - accuracy: 0.7002
# 66/66 [==============================] - 0s 463us/step - loss: 0.7722 - accuracy: 0.6993
# 66/66 [==============================] - 0s 484us/step - loss: 0.8196 - accuracy: 0.6866
# Start run 79/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'relu', 'batch_size': 128, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 459us/step - loss: 0.7667 - accuracy: 0.7159
# 66/66 [==============================] - 0s 509us/step - loss: 0.7754 - accuracy: 0.6945
# 66/66 [==============================] - 0s 495us/step - loss: 0.7967 - accuracy: 0.6975
# Start run 80/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'relu', 'batch_size': 128, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 480us/step - loss: 0.7927 - accuracy: 0.7026
# 66/66 [==============================] - 0s 496us/step - loss: 0.7548 - accuracy: 0.7012
# 66/66 [==============================] - 0s 481us/step - loss: 0.7940 - accuracy: 0.6990
# Start run 81/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'relu', 'batch_size': 256, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 469us/step - loss: 0.8350 - accuracy: 0.6912
# 66/66 [==============================] - 0s 475us/step - loss: 0.8433 - accuracy: 0.6789
# 66/66 [==============================] - 0s 461us/step - loss: 0.8657 - accuracy: 0.6714
# Start run 82/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'relu', 'batch_size': 256, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 470us/step - loss: 0.8013 - accuracy: 0.6969
# 66/66 [==============================] - 0s 524us/step - loss: 0.8350 - accuracy: 0.6784
# 66/66 [==============================] - 0s 476us/step - loss: 0.8551 - accuracy: 0.6852
# Start run 83/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'relu', 'batch_size': 256, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 473us/step - loss: 0.8043 - accuracy: 0.7059
# 66/66 [==============================] - 0s 478us/step - loss: 0.8199 - accuracy: 0.6903
# 66/66 [==============================] - 0s 491us/step - loss: 0.8438 - accuracy: 0.6771
# Start run 84/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'dropout_rate': 0.3, 'activation_function': 'relu', 'batch_size': 256, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 468us/step - loss: 0.7865 - accuracy: 0.7097
# 66/66 [==============================] - 0s 490us/step - loss: 0.8427 - accuracy: 0.6689
# 66/66 [==============================] - 0s 469us/step - loss: 0.8567 - accuracy: 0.6800
# ...
# 66/66 [==============================] - 0s 561us/step - loss: 0.8495 - accuracy: 0.6705
# Start run 1294/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 128, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 528us/step - loss: 0.8434 - accuracy: 0.6831
# 66/66 [==============================] - 0s 516us/step - loss: 0.8160 - accuracy: 0.6884
# 66/66 [==============================] - 0s 553us/step - loss: 0.8177 - accuracy: 0.6847
# Start run 1295/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 128, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 570us/step - loss: 0.8173 - accuracy: 0.6931
# 66/66 [==============================] - 0s 536us/step - loss: 0.8029 - accuracy: 0.6888
# 66/66 [==============================] - 0s 570us/step - loss: 0.8303 - accuracy: 0.6776
# Start run 1296/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 128, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 542us/step - loss: 0.8551 - accuracy: 0.6841
# 66/66 [==============================] - 0s 558us/step - loss: 0.7954 - accuracy: 0.6931
# 66/66 [==============================] - 0s 562us/step - loss: 0.8197 - accuracy: 0.6828
# Start run 1297/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 568us/step - loss: 0.8565 - accuracy: 0.6789
# 66/66 [==============================] - 0s 581us/step - loss: 0.8787 - accuracy: 0.6589
# 66/66 [==============================] - 0s 679us/step - loss: 0.8847 - accuracy: 0.6667
# Start run 1298/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 614us/step - loss: 0.8530 - accuracy: 0.6874
# 66/66 [==============================] - 0s 585us/step - loss: 0.8429 - accuracy: 0.6774
# 66/66 [==============================] - 0s 547us/step - loss: 0.8699 - accuracy: 0.6624
# Start run 1299/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 580us/step - loss: 0.8523 - accuracy: 0.6836
# 66/66 [==============================] - 0s 564us/step - loss: 0.8376 - accuracy: 0.6793
# 66/66 [==============================] - 0s 536us/step - loss: 0.8699 - accuracy: 0.6667
# Start run 1300/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 548us/step - loss: 0.8700 - accuracy: 0.6774
# 66/66 [==============================] - 0s 577us/step - loss: 0.8228 - accuracy: 0.6865
# 66/66 [==============================] - 0s 540us/step - loss: 0.8569 - accuracy: 0.6638
# Start run 1301/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 542us/step - loss: 0.9006 - accuracy: 0.6637
# 66/66 [==============================] - 0s 565us/step - loss: 0.8618 - accuracy: 0.6589
# 66/66 [==============================] - 0s 582us/step - loss: 0.8678 - accuracy: 0.6757
# Start run 1302/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 574us/step - loss: 0.8511 - accuracy: 0.6746
# 66/66 [==============================] - 0s 531us/step - loss: 0.8234 - accuracy: 0.6855
# 66/66 [==============================] - 0s 534us/step - loss: 0.8753 - accuracy: 0.6619
# Start run 1303/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 530us/step - loss: 0.8420 - accuracy: 0.6855
# 66/66 [==============================] - 0s 524us/step - loss: 0.8235 - accuracy: 0.6817
# 66/66 [==============================] - 0s 566us/step - loss: 0.8542 - accuracy: 0.6785
# Start run 1304/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 539us/step - loss: 0.8250 - accuracy: 0.6936
# 66/66 [==============================] - 0s 516us/step - loss: 0.8337 - accuracy: 0.6808
# 66/66 [==============================] - 0s 582us/step - loss: 0.8499 - accuracy: 0.6747
# Start run 1305/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 542us/step - loss: 0.8681 - accuracy: 0.6698
# 66/66 [==============================] - 0s 567us/step - loss: 0.8327 - accuracy: 0.6741
# 66/66 [==============================] - 0s 528us/step - loss: 0.8644 - accuracy: 0.6714
# Start run 1306/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 572us/step - loss: 0.8594 - accuracy: 0.6760
# 66/66 [==============================] - 0s 541us/step - loss: 0.8369 - accuracy: 0.6755
# 66/66 [==============================] - 0s 574us/step - loss: 0.9028 - accuracy: 0.6496
# Start run 1307/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 569us/step - loss: 0.8276 - accuracy: 0.6926
# 66/66 [==============================] - 0s 552us/step - loss: 0.8206 - accuracy: 0.6827
# 66/66 [==============================] - 0s 550us/step - loss: 0.8650 - accuracy: 0.6757
# Start run 1308/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 535us/step - loss: 0.8604 - accuracy: 0.6765
# 66/66 [==============================] - 0s 641us/step - loss: 0.8467 - accuracy: 0.6722
# 66/66 [==============================] - 0s 575us/step - loss: 0.8964 - accuracy: 0.6605
# Start run 1309/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 545us/step - loss: 0.8354 - accuracy: 0.6907
# 66/66 [==============================] - 0s 594us/step - loss: 0.8485 - accuracy: 0.6736
# 66/66 [==============================] - 0s 542us/step - loss: 0.8725 - accuracy: 0.6695
# Start run 1310/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 555us/step - loss: 0.8436 - accuracy: 0.6827
# 66/66 [==============================] - 0s 579us/step - loss: 0.8758 - accuracy: 0.6651
# 66/66 [==============================] - 0s 557us/step - loss: 0.8680 - accuracy: 0.6714
# Start run 1311/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 526us/step - loss: 0.8337 - accuracy: 0.6879
# 66/66 [==============================] - 0s 548us/step - loss: 0.8185 - accuracy: 0.6912
# 66/66 [==============================] - 0s 600us/step - loss: 0.8629 - accuracy: 0.6714
# Start run 1312/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 256, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 582us/step - loss: 0.8437 - accuracy: 0.6874
# 66/66 [==============================] - 0s 533us/step - loss: 0.8462 - accuracy: 0.6708
# 66/66 [==============================] - 0s 556us/step - loss: 0.8518 - accuracy: 0.6790
# Start run 1313/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 513us/step - loss: 0.8957 - accuracy: 0.6708
# 66/66 [==============================] - 0s 513us/step - loss: 0.9336 - accuracy: 0.6499
# 66/66 [==============================] - 0s 563us/step - loss: 0.9163 - accuracy: 0.6524
# Start run 1314/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 533us/step - loss: 0.8902 - accuracy: 0.6689
# 66/66 [==============================] - 0s 584us/step - loss: 0.8964 - accuracy: 0.6537
# 66/66 [==============================] - 0s 569us/step - loss: 0.9110 - accuracy: 0.6538
# Start run 1315/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 559us/step - loss: 0.8886 - accuracy: 0.6679
# 66/66 [==============================] - 0s 547us/step - loss: 0.8960 - accuracy: 0.6551
# 66/66 [==============================] - 0s 524us/step - loss: 0.9071 - accuracy: 0.6553
# Start run 1316/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 542us/step - loss: 0.8729 - accuracy: 0.6784
# 66/66 [==============================] - 0s 524us/step - loss: 0.8945 - accuracy: 0.6546
# 66/66 [==============================] - 0s 566us/step - loss: 0.9418 - accuracy: 0.6401
# Start run 1317/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 537us/step - loss: 0.8752 - accuracy: 0.6736
# 66/66 [==============================] - 0s 572us/step - loss: 0.9128 - accuracy: 0.6565
# 66/66 [==============================] - 0s 571us/step - loss: 0.9053 - accuracy: 0.6562
# Start run 1318/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 534us/step - loss: 0.8874 - accuracy: 0.6651
# 66/66 [==============================] - 0s 549us/step - loss: 0.8979 - accuracy: 0.6575
# 66/66 [==============================] - 0s 525us/step - loss: 0.9309 - accuracy: 0.6481
# Start run 1319/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 545us/step - loss: 0.8724 - accuracy: 0.6751
# 66/66 [==============================] - 0s 541us/step - loss: 0.8689 - accuracy: 0.6732
# 66/66 [==============================] - 0s 590us/step - loss: 0.9212 - accuracy: 0.6515
# Start run 1320/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 549us/step - loss: 0.9159 - accuracy: 0.6594
# 66/66 [==============================] - 0s 529us/step - loss: 0.8652 - accuracy: 0.6741
# 66/66 [==============================] - 0s 550us/step - loss: 0.9261 - accuracy: 0.6538
# Start run 1321/8192: Parameters: {'num_hidden_layers': 2, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'dropout_rate': 0.3, 'activation_function': 'LeakyReLU', 'batch_size': 512, 'early_stopping_patience': 20, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 547us/step - loss: 0.8984 - accuracy: 0.6665

# %% [markdown]
# ### Sichern der Hyperparameter in csv Datei

# %%
import pandas as pd

#resultsDF = pd.DataFrame(search_results)
#resultsDF['delta_acc'] = (resultsDF['best_train_accuracy']-resultsDF['best_val_accuracy'])/resultsDF['best_val_accuracy']
#resultsDF.to_csv('../data/optimization_results_final_größer.csv', index=False)
resultsDF = pd.read_csv('../data/optimization_results_final.csv')
resultsDF.head()
# Out:
#    num_hidden_layers  units_1  units_2  units_3  units_4  dropout_rate
# 0                  2       64      128      256      512           0.3  \
# 1                  2       64      128      256      512           0.3
# 2                  2       64      128      256      512           0.3
# 3                  2       64      128      256      512           0.3
# 4                  2       64      128      256      512           0.3
#
#   activation_function  batch_size  early_stopping_patience  reduce_lr_factor
# 0           LeakyReLU         512                       15               0.1  \
# 1           LeakyReLU         512                       15               0.1
# 2           LeakyReLU         512                       15               0.1
# 3           LeakyReLU         512                       15               0.1
# 4           LeakyReLU         512                       15               0.5
#
#    ...  reduce_lr_min_lr  best_val_accuracy  val_accuracy_std  best_val_loss
# 0  ...      1.000000e-07           0.626983          0.011391       0.992029  \
# 1  ...      1.000000e-05           0.629830          0.005520       0.995193
# 2  ...      1.000000e-07           0.633315          0.007252       0.995624
# 3  ...      1.000000e-05           0.632999          0.011828       0.995118
# 4  ...      1.000000e-07           0.626667          0.012062       0.995532
#
#    val_loss_std  best_train_accuracy  train_accuracy_std  best_train_loss
# 0      0.020353             0.641546            0.002888         0.951796  \
# 1      0.022945             0.639329            0.002561         0.954996
# 2      0.025843             0.645820            0.010524         0.954179
# 3      0.013549             0.641863            0.005293         0.955882
# 4      0.020262             0.640912            0.001003         0.955270
#
#    train_loss_std  delta_acc
# 0        0.016576   0.023227
# 1        0.016467   0.015082
# 2        0.005979   0.019746
# 3        0.023427   0.014004
# 4        0.013912   0.022732
#
# [5 rows x 21 columns]

# %% [markdown]
# ### graphische Darstellung der Performanceänderung

# %%
import seaborn as sns

# Mapping der activation_function auf numerische Werte
activation_mapping = {'relu': 0, 'LeakyReLU': 1}
resultsDF['activation_numerical'] = resultsDF['activation_function'].map(activation_mapping)

x_vars = [
    'num_hidden_layers',
    'units_1',
    'units_2',
    'units_3',
    'units_4',
    'dropout_rate',
#    'activation_numerical',
    'batch_size',
#    'early_stopping_patience',
#    'reduce_lr_factor',
#    'reduce_lr_patience',
#    'reduce_lr_min_lr'
]

y_vars = [
    'best_val_accuracy',
    'best_train_accuracy',
    'delta_acc'
]

sns.pairplot(resultsDF, x_vars=x_vars, y_vars=y_vars, kind='reg', height=2)
plt.savefig('../figures/HPO_parameter.pdf', format='pdf')

# %% [markdown]
# ### Auswählen der besten Hyperparameter-Kombination

# %%
def calculate_score(row):
    # Bestmöglicher Score ist 
    best_score = 1.0
    
    # Berechnung des Scores basierend auf Delta-Accuracy und Best Validation Accuracy
    delta_acc_score = 1.0 - abs(row['delta_acc'])  # Je kleiner das Delta, desto besser der Score
    best_val_acc_score = row['best_val_accuracy']  # Je größer die Best Validation Accuracy, desto besser der Score
    
    #Gewichte
    w1=0.4
    w2=1
    
    # Gesamtscore berechnen
    score = (w1 * delta_acc_score + w2 * best_val_acc_score) / 2
    
    # Normalisierung des Scores auf den Bereich [0, 1]
    normalized_score = score / best_score
    
    return normalized_score

# Score-Spalte hinzufügen
resultsDF['score'] = resultsDF.apply(calculate_score, axis=1)
resultsDF = resultsDF.sort_values('score', ascending=False)
resultsDF.head()
# Out:
#      num_hidden_layers  units_1  units_2  units_3  units_4  dropout_rate
# 482                  2      128      256      512     1024           0.3  \
# 646                  3       64      256      256      512           0.3
# 992                  3      128      256      512     1024           0.3
# 804                  3      128      128      256     1024           0.3
# 132                  2       64      256      256      512           0.3
#
#     activation_function  batch_size  early_stopping_patience
# 482           LeakyReLU         512                       15  \
# 646           LeakyReLU         512                       15
# 992           LeakyReLU         512                       15
# 804           LeakyReLU         512                       15
# 132           LeakyReLU         512                       15
#
#      reduce_lr_factor  ...  val_accuracy_std  best_val_loss  val_loss_std
# 482               0.1  ...          0.010340       0.968424      0.023989  \
# 646               0.5  ...          0.010445       0.976671      0.024215
# 992               0.1  ...          0.012416       0.969724      0.035851
# 804               0.5  ...          0.011112       0.972934      0.029237
# 132               0.5  ...          0.010542       0.993103      0.015215
#
#      best_train_accuracy  train_accuracy_std  best_train_loss  train_loss_std
# 482             0.659438            0.007983         0.903025        0.027278  \
# 646             0.649464            0.011288         0.921184        0.016501
# 992             0.656902            0.004205         0.895910        0.007996
# 804             0.657221            0.008986         0.902227        0.022315
# 132             0.639805            0.007160         0.950453        0.025905
#
#      delta_acc  activation_numerical     score
# 482   0.018832                     1  0.519858
# 646   0.009350                     1  0.519854
# 992   0.016904                     1  0.519611
# 804   0.017397                     1  0.519512
# 132   0.001235                     1  0.519261
#
# [5 rows x 23 columns]

# %%
import matplotlib.pyplot as plt

best_params = resultsDF.head(1)

# Scatterplot erstellen
sns.scatterplot(data=resultsDF, x='best_val_accuracy', y='delta_acc', alpha=0.5, label='models')
sns.scatterplot(data=best_params, x='best_val_accuracy', y='delta_acc', color='red', label='best model')

# Achsentitel hinzufügen
plt.xlabel('best_val_accuracy')
plt.ylabel('delta_acc')

# Plot anzeigen
plt.savefig('../figures/HPO_scatter.pdf')

# %%
best_params = resultsDF.iloc[1]
model = build_model_from_params(best_params)
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 64)                1280
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_10 (Dense)            (None, 256)               16640
#
#  dropout_8 (Dropout)         (None, 256)               0
#
#  dense_11 (Dense)            (None, 256)               65792
#
#  dropout_9 (Dropout)         (None, 256)               0
#
#  dense_12 (Dense)            (None, 512)               131584
#
#  dropout_10 (Dropout)        (None, 512)               0
#
#  dense_13 (Dense)            (None, 6)                 3078
#
# =================================================================
# Total params: 218,374
# Trainable params: 218,374
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Das beste Modell

# %%
batch_size = best_params['batch_size']
nb_epoch = 300

# Definiere die Early Stopping-Bedingungen
early_stopping = EarlyStopping(monitor='val_loss', patience=best_params['early_stopping_patience'], mode='min', restore_best_weights=True)

# Definiere die Reduzierung der Lernrate, falls die Verbesserung stagniert
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=best_params['reduce_lr_factor'], best_patience=best_params['reduce_lr_patience'], mode='min', min_lr=best_params['reduce_lr_min_lr'])

hist = model.fit(X_train, Y_train, validation_data=(X_val, Y_val), 
                 epochs=nb_epoch, batch_size=batch_size, callbacks=[early_stopping, reduce_lr], verbose=0)

# %%
Y_pred = model.predict(X_test)
# Out:
# 61/61 [==============================] - 0s 3ms/step

# %% [markdown]
# ### Evaluation

# %%
def plot_history(network_history):
    plt.figure()
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.plot(network_history.history['loss'])
    plt.plot(network_history.history['val_loss'])
    plt.legend(['Training', 'Validation'])
    plt.savefig('../figures/Loss.pdf')
    
    plt.figure()
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.plot(network_history.history['accuracy'])
    plt.plot(network_history.history['val_accuracy'])
    plt.legend(['Training', 'Validation'], loc='lower right')
    plt.savefig('../figures/Acc.pdf')

# %%
plot_history(hist)

# %%
from sklearn.metrics import confusion_matrix

Y_pred_classes = np.argmax(Y_pred, axis=1)
Y_test_classes = np.argmax(Y_test, axis=1)

cm = confusion_matrix(Y_test_classes, Y_pred_classes, normalize='true')
plt.figure(figsize=(20,20))
sns.heatmap(cm, annot=True, xticklabels=label, yticklabels=label)
plt.xlabel('Vorhergesagtes Genre')
plt.ylabel('Tatsächliches Genre')
plt.savefig('../figures/confusion_matrix_NN.png')
plt.show()

# %%
from sklearn.metrics import precision_recall_curve, auc

if isinstance(Y_test, pd.DataFrame):
    Y_test = Y_test.values
if isinstance(Y_pred, pd.DataFrame):
    Y_pred = Y_pred.values

precision, recall, thresholds = precision_recall_curve(Y_test.ravel(), Y_pred.ravel())


# Berechne Precision, Recall und Schwellenwerte
precision, recall, thresholds = precision_recall_curve(Y_test.ravel(), Y_pred.ravel())

# Berechne den AUC-PR
auc_pr = auc(recall, precision)

plt.plot(recall, precision, label=f"AUC-PR = {auc_pr:.3}")
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend()
plt.title('Precision-Recall Curve')
plt.show()

# %%
# Precision Recall Curve für jede Klasse einzeln

n_classes = Y_test.shape[1]

if isinstance(Y_test, np.ndarray):
    Y_test = pd.DataFrame(Y_test)
if isinstance(Y_pred, np.ndarray):
    Y_pred = pd.DataFrame(Y_pred)

auc_pr_values = []

# Für jede Klasse
for i in range(n_classes):
    precision, recall, _ = precision_recall_curve(Y_test.iloc[:, i], Y_pred.iloc[:, i])

    # Berechne den AUC-PR
    auc_pr = auc(recall, precision)
    auc_pr_values.append((label[i], auc_pr))

    plt.plot(
        recall,
        precision,
        label=f"{label[i]}, AUC-PR = {auc_pr:.3}",
    )

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.legend()
plt.title("Precision-Recall Curve")

# Genres nach AUC-PR-Wert sortieren
auc_pr_values_sorted = sorted(auc_pr_values, key=lambda x: x[1], reverse=True)

# Ausgabe der Genres und AUC-PR-Werte
for genre, auc_pr in auc_pr_values_sorted:
    print(f"{genre}: AUC-PR = {auc_pr:.3}")
# Out:
# hip hop: AUC-PR = 0.879
# classic: AUC-PR = 0.851
# metal: AUC-PR = 0.71
# rock: AUC-PR = 0.691
# electronic: AUC-PR = 0.521
# pop: AUC-PR = 0.49

# %%
Y_pred = model.predict(X_test)

# Konvertiere die Vorhersagen in diskrete Klassen
Y_pred_classes = np.argmax(Y_pred, axis=1)

# Konvertiere die Ground-Truth-Labels in diskrete Klassen
Y_test_classes = np.argmax(Y_test, axis=1)

# Berechne die Accuracy
accuracy = np.mean(Y_pred_classes == Y_test_classes)
print("Accuracy:", accuracy)
# Out:
# 61/61 [==============================] - 0s 4ms/step
# Accuracy: 0.6587383660806618
