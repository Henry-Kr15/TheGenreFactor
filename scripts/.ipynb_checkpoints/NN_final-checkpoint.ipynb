# %% [markdown]
# # Neuronales Nezt

# %% [markdown]
# ### Daten laden

# %%
import pandas as pd

csv_file = "../data/data_selected_v1.csv"

df = pd.read_csv(csv_file)
df.columns
# Out:
# Index(['Unnamed: 0', 'Danceability', 'Energy', 'Key', 'Loudness',
#        'Speechiness', 'Acousticness', 'Instrumentalness', 'Liveness',
#        'Valence', 'Tempo', 'Duration_ms', 'Views', 'Likes', 'Comments',
#        'Stream', 'Genre', 'Artist_encoded', 'Album_type_encoded',
#        'Licensed_encoded', 'official_video_encoded'],
#       dtype='object')

# %% [markdown]
# ### Genres für das Training auswählen

# %%
genres_to_keep = ["classic", "metal", "rock", "hip hop", "electronic", "pop"]
df = df[df['Genre'].isin(genres_to_keep)]

# %% [markdown]
# ### Designmatrix und Target erstellen

# %%
features_drop = ['Genre', 'Unnamed: 0']

df = df.sample(frac=1, random_state=42) #daten mischen

X = df.drop(features_drop, axis=1)
Y = df['Genre']

# %%
# One-Hot-Encoding durchführen
Y = pd.get_dummies(Y)
num_classes = len(Y.value_counts())

# label um One-Hot-Encoding hinterher wieder zu übersetzen
genre_mapping = Y.columns
label = []
for index, genre in enumerate(genre_mapping):
    label.append(genre)
    print("Genre", index, ":", genre)
# Out:
# Genre 0 : classic
# Genre 1 : electronic
# Genre 2 : hip hop
# Genre 3 : metal
# Genre 4 : pop
# Genre 5 : rock

# %% [markdown]
# ### Split in Train, Validation und Test

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, stratify=Y, random_state=42)
X_train, X_val,  Y_train, Y_val  = train_test_split(X_train, Y_train, test_size=0.3, stratify=Y_train, random_state=42)

# %% [markdown]
# ### Skalierung der Features

# %%
from sklearn.preprocessing import QuantileTransformer

transformer = QuantileTransformer(output_distribution="normal")
transformer.fit(X_train)

X_train = transformer.transform(X_train)
X_val = transformer.transform(X_val)
X_test = transformer.transform(X_test)

# %% [markdown]
# ### Modell

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

def build_model_from_params(params):
    num_hidden_layers = params['num_hidden_layers']
    activation_function = params['activation_function']
    dropout_rate = params['dropout_rate']
    units_per_layer = [params['units_1'],params['units_2'],params['units_3'],params['units_4']]

    model = Sequential()
    model.add(Dense(units=units_per_layer[0], activation=activation_function, input_dim=X_train.shape[1]))
    model.add(Dropout(dropout_rate))

    for i in range(1, num_hidden_layers+1):
        if i < len(units_per_layer):
            model.add(Dense(units=units_per_layer[i], activation=activation_function))
            model.add(Dropout(dropout_rate))

    model.add(Dense(units=num_classes, activation='softmax'))
    
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model
# Out:
# 2023-07-08 12:14:49.646048: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Kombinationen aller Hyperparameter

# %%
import itertools

param_space = {
    'num_hidden_layers': [2, 3],
    'units_1': [64, 128],
    'units_2': [128, 256],
    'units_3': [256, 512],
    'units_4': [512, 1024],
    'dropout_rate': [0.3, 0.5],
    'activation_function': ['LeakyReLU'],
    'batch_size' : [512, 1024],
    'early_stopping_patience': [15],
    'reduce_lr_factor': [0.1, 0.5],
    'reduce_lr_patience': [5, 7],
    'reduce_lr_min_lr': [1e-7, 1e-5],
}

#param_space = {
#    'num_hidden_layers': [2, 3],
#    'units_1': [64, 128, 256],
#    'units_2': [128, 256, 512],
#    'units_3': [256, 512, 1024],
#    'units_4': [512, 1024],
#    'dropout_rate': [0.3, 0.5, 0.7],
#    'activation_function': ['relu', 'LeakyReLU'],
#    'batch_size' : [128, 256, 512],
#    'early_stopping_patience': [5, 10, 15],
#    'reduce_lr_factor': [0.1, 0.5, 0.9],
#    'reduce_lr_patience': [5, 10, 15],
#    'reduce_lr_min_lr': [1e-7, 1e-5, 1e-3],
#}

value_combis = itertools.product(*[v for v in param_space.values()])

# List comprehension short form:
param_combis = [{key:value for key, value in zip(param_space.keys(), combi)} for combi in value_combis]

print(f"We have a total of {len(param_combis)} combinations:")
# Out:
# We have a total of 1024 combinations:

# %% [markdown]
# ### Hyperparameteroptimierung

# %%
import numpy as np
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

search_results = []

k_folds = 3
skf = StratifiedKFold(n_splits=k_folds)

for idx, params in enumerate(param_combis):
    print(f"Start run {idx+1}/{len(param_combis)}: Parameters: {params}")
    
    val_accuracies = []
    val_losses = []
    train_accuracies = []
    train_losses = []
    
    for fold_idx, (train_index, val_index) in enumerate(skf.split(X_train, np.argmax(Y_train, axis=1))):
        X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
        Y_train_fold, Y_val_fold = Y_train.reset_index(drop=True).iloc[train_index], Y_train.reset_index(drop=True).iloc[val_index]
        
        filepath = f"../model_fold/model_fold_{idx+1}_fold_{fold_idx+1}.h5"
        checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=0, save_best_only=True, mode='max')
        
        this_model = build_model_from_params(params)
        
        batch_size = params['batch_size']
        nb_epoch = 30

        early_stopping = EarlyStopping(monitor='val_loss', patience=params['early_stopping_patience'], mode='min', restore_best_weights=True)
        reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=params['reduce_lr_factor'], patience=params['reduce_lr_patience'], mode='min', min_lr=params['reduce_lr_min_lr'])
        fit_results = this_model.fit(X_train_fold, Y_train_fold, validation_data=(X_val_fold, Y_val_fold), 
                 epochs=nb_epoch, batch_size=batch_size, callbacks=[checkpoint, early_stopping, reduce_lr], verbose=0)
        
        # Extract the best validation scores
        best_val_epoch = np.argmax(fit_results.history['val_accuracy'])
        val_accuracies.append(np.max(fit_results.history['val_accuracy']))
        val_losses.append(fit_results.history['val_loss'][best_val_epoch])
        
        # Get training accuracy and loss
        best_model = load_model(filepath)
        train_loss, train_acc = best_model.evaluate(X_train_fold, Y_train_fold)
        train_accuracies.append(train_acc)
        train_losses.append(train_loss)
    
    # Store results
    search_results.append({
        **params,
        'best_val_accuracy': np.mean(val_accuracies),
        'val_accuracy_std': np.std(val_accuracies),
        'best_val_loss': np.mean(val_losses),
        'val_loss_std': np.std(val_losses),
        'best_train_accuracy': np.mean(train_accuracies),
        'train_accuracy_std': np.std(train_accuracies),
        'best_train_loss': np.mean(train_losses),
        'train_loss_std': np.std(train_losses)
    })
# Out:
# Start run 1/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9386 - accuracy: 0.6423
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9394 - accuracy: 0.6466
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9717 - accuracy: 0.6349
# Start run 2/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9458 - accuracy: 0.6508
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9232 - accuracy: 0.6442
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9771 - accuracy: 0.6330
# Start run 3/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9681 - accuracy: 0.6413
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9210 - accuracy: 0.6523
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9746 - accuracy: 0.6425
# Start run 4/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9156 - accuracy: 0.6546
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9348 - accuracy: 0.6447
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9625 - accuracy: 0.6429
# Start run 5/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9342 - accuracy: 0.6608
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9713 - accuracy: 0.6337
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9596 - accuracy: 0.6306
# Start run 6/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9189 - accuracy: 0.6570
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9497 - accuracy: 0.6442
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9761 - accuracy: 0.6425
# Start run 7/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 1s 5ms/step - loss: 0.9323 - accuracy: 0.6551
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9305 - accuracy: 0.6580
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9601 - accuracy: 0.6472
# Start run 8/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9270 - accuracy: 0.6603
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9325 - accuracy: 0.6418
# 66/66 [==============================] - 0s 4ms/step - loss: 0.9589 - accuracy: 0.6368
# Start run 9/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9892 - accuracy: 0.6466
# 66/66 [==============================] - 0s 4ms/step - loss: 0.9820 - accuracy: 0.6337
# 66/66 [==============================] - 0s 2ms/step - loss: 1.0169 - accuracy: 0.6173
# Start run 10/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 4ms/step - loss: 0.9759 - accuracy: 0.6423
# 66/66 [==============================] - 1s 5ms/step - loss: 1.0067 - accuracy: 0.6271
# 66/66 [==============================] - 1s 5ms/step - loss: 1.0037 - accuracy: 0.6216
# Start run 11/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 1s 5ms/step - loss: 0.9794 - accuracy: 0.6404
# 66/66 [==============================] - 1s 5ms/step - loss: 0.9947 - accuracy: 0.6276
# 66/66 [==============================] - 0s 4ms/step - loss: 1.0243 - accuracy: 0.6235
# Start run 12/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 1s 5ms/step - loss: 0.9895 - accuracy: 0.6295
# 66/66 [==============================] - 0s 4ms/step - loss: 1.0119 - accuracy: 0.6185
# 66/66 [==============================] - 0s 3ms/step - loss: 1.0142 - accuracy: 0.6334
# Start run 13/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 1s 3ms/step - loss: 1.0179 - accuracy: 0.6352
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9728 - accuracy: 0.6285
# 66/66 [==============================] - 0s 3ms/step - loss: 1.0447 - accuracy: 0.6116
# Start run 14/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9964 - accuracy: 0.6399
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9932 - accuracy: 0.6371
# 66/66 [==============================] - 0s 2ms/step - loss: 1.0237 - accuracy: 0.6197
# Start run 15/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9828 - accuracy: 0.6428
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9984 - accuracy: 0.6195
# 66/66 [==============================] - 0s 2ms/step - loss: 1.0127 - accuracy: 0.6311
# Start run 16/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9782 - accuracy: 0.6480
# 66/66 [==============================] - 0s 4ms/step - loss: 0.9993 - accuracy: 0.6295
# 66/66 [==============================] - 0s 2ms/step - loss: 1.0487 - accuracy: 0.6192
# Start run 17/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9525 - accuracy: 0.6518
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9506 - accuracy: 0.6380
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9663 - accuracy: 0.6410
# Start run 18/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9460 - accuracy: 0.6589
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9243 - accuracy: 0.6489
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9595 - accuracy: 0.6377
# Start run 19/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9250 - accuracy: 0.6561
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9584 - accuracy: 0.6456
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9806 - accuracy: 0.6292
# Start run 20/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9349 - accuracy: 0.6580
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9756 - accuracy: 0.6371
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9657 - accuracy: 0.6401
# Start run 21/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9238 - accuracy: 0.6599
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9290 - accuracy: 0.6418
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9644 - accuracy: 0.6282
# Start run 22/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9265 - accuracy: 0.6603
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9510 - accuracy: 0.6399
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9687 - accuracy: 0.6439
# Start run 23/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9432 - accuracy: 0.6499
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9300 - accuracy: 0.6480
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9545 - accuracy: 0.6472
# Start run 24/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9270 - accuracy: 0.6570
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9281 - accuracy: 0.6556
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9677 - accuracy: 0.6415
# Start run 25/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9913 - accuracy: 0.6447
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9863 - accuracy: 0.6257
# 66/66 [==============================] - 0s 2ms/step - loss: 1.0233 - accuracy: 0.6211
# Start run 26/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9973 - accuracy: 0.6390
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9805 - accuracy: 0.6299
# 66/66 [==============================] - 0s 2ms/step - loss: 1.0244 - accuracy: 0.6197
# Start run 27/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9990 - accuracy: 0.6314
# 66/66 [==============================] - 0s 2ms/step - loss: 1.0492 - accuracy: 0.6143
# 66/66 [==============================] - 0s 2ms/step - loss: 1.0176 - accuracy: 0.6225
# Start run 28/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9793 - accuracy: 0.6337
# 66/66 [==============================] - 0s 2ms/step - loss: 1.0338 - accuracy: 0.6257
# 66/66 [==============================] - 0s 2ms/step - loss: 1.0137 - accuracy: 0.6268
# Start run 29/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9720 - accuracy: 0.6437
# 66/66 [==============================] - 0s 3ms/step - loss: 1.0120 - accuracy: 0.6356
# 66/66 [==============================] - 0s 2ms/step - loss: 1.0109 - accuracy: 0.6220
# Start run 30/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9729 - accuracy: 0.6447
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9896 - accuracy: 0.6309
# 66/66 [==============================] - 0s 2ms/step - loss: 1.0100 - accuracy: 0.6301
# Start run 31/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9802 - accuracy: 0.6380
# 66/66 [==============================] - 0s 2ms/step - loss: 1.0060 - accuracy: 0.6219
# 66/66 [==============================] - 0s 2ms/step - loss: 1.0209 - accuracy: 0.6258
# Start run 32/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 2ms/step - loss: 1.0013 - accuracy: 0.6371
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9957 - accuracy: 0.6276
# 66/66 [==============================] - 0s 2ms/step - loss: 1.0389 - accuracy: 0.6282
# Start run 33/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9238 - accuracy: 0.6584
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9281 - accuracy: 0.6527
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9435 - accuracy: 0.6429
# Start run 34/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9276 - accuracy: 0.6594
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9876 - accuracy: 0.6295
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9798 - accuracy: 0.6282
# Start run 35/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9094 - accuracy: 0.6665
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9457 - accuracy: 0.6413
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9705 - accuracy: 0.6282
# Start run 36/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9320 - accuracy: 0.6603
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9088 - accuracy: 0.6523
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9487 - accuracy: 0.6448
# Start run 37/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9173 - accuracy: 0.6641
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9604 - accuracy: 0.6380
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9594 - accuracy: 0.6358
# Start run 38/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9135 - accuracy: 0.6679
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9102 - accuracy: 0.6451
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9502 - accuracy: 0.6410
# Start run 39/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9323 - accuracy: 0.6575
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9131 - accuracy: 0.6475
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9719 - accuracy: 0.6439
# Start run 40/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9438 - accuracy: 0.6584
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9401 - accuracy: 0.6442
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9493 - accuracy: 0.6491
# Start run 41/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 512, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9698 - accuracy: 0.6461
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9599 - accuracy: 0.6394
# 66/66 [==============================] - 0s 3ms/step - loss: 1.0118 - accuracy: 0.6363
# Start run 42/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 512, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9649 - accuracy: 0.6447
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9797 - accuracy: 0.6299
# 66/66 [==============================] - 0s 3ms/step - loss: 1.0051 - accuracy: 0.6311
# Start run 43/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 512, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9520 - accuracy: 0.6575
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9964 - accuracy: 0.6190
# 66/66 [==============================] - 0s 3ms/step - loss: 1.0336 - accuracy: 0.6244
# Start run 44/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 512, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9738 - accuracy: 0.6447
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9805 - accuracy: 0.6423
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9928 - accuracy: 0.6306
# Start run 45/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 512, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 2ms/step - loss: 1.0122 - accuracy: 0.6371
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9774 - accuracy: 0.6361
# 66/66 [==============================] - 0s 2ms/step - loss: 1.0095 - accuracy: 0.6211
# Start run 46/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 512, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9734 - accuracy: 0.6451
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9672 - accuracy: 0.6337
# 66/66 [==============================] - 0s 2ms/step - loss: 1.0138 - accuracy: 0.6249
# Start run 47/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 512, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 1s 3ms/step - loss: 0.9666 - accuracy: 0.6423
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9677 - accuracy: 0.6456
# 66/66 [==============================] - 0s 2ms/step - loss: 1.0125 - accuracy: 0.6216
# Start run 48/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 512, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9856 - accuracy: 0.6347
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9664 - accuracy: 0.6404
# 66/66 [==============================] - 0s 3ms/step - loss: 1.0120 - accuracy: 0.6216
# Start run 49/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 1024, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9435 - accuracy: 0.6556
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9217 - accuracy: 0.6489
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9479 - accuracy: 0.6396
# Start run 50/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 1024, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9625 - accuracy: 0.6451
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9252 - accuracy: 0.6523
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9821 - accuracy: 0.6330
# Start run 51/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 1024, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9265 - accuracy: 0.6637
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9270 - accuracy: 0.6556
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9810 - accuracy: 0.6349
# Start run 52/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 1024, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9198 - accuracy: 0.6580
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9202 - accuracy: 0.6527
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9920 - accuracy: 0.6277
# Start run 53/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 1024, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9281 - accuracy: 0.6589
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9227 - accuracy: 0.6475
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9593 - accuracy: 0.6453
# Start run 54/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 1024, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9251 - accuracy: 0.6637
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9468 - accuracy: 0.6489
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9693 - accuracy: 0.6396
# Start run 55/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 1024, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9220 - accuracy: 0.6622
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9194 - accuracy: 0.6489
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9806 - accuracy: 0.6368
# Start run 56/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 1024, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9167 - accuracy: 0.6656
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9236 - accuracy: 0.6466
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9659 - accuracy: 0.6349
# Start run 57/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 1024, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9777 - accuracy: 0.6413
# 66/66 [==============================] - 0s 2ms/step - loss: 1.0676 - accuracy: 0.6152
# 66/66 [==============================] - 0s 3ms/step - loss: 1.0039 - accuracy: 0.6211
# Start run 58/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 1024, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9555 - accuracy: 0.6432
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9666 - accuracy: 0.6333
# 66/66 [==============================] - 0s 3ms/step - loss: 1.0177 - accuracy: 0.6235
# Start run 59/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 1024, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9821 - accuracy: 0.6428
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9781 - accuracy: 0.6261
# 66/66 [==============================] - 0s 2ms/step - loss: 1.0050 - accuracy: 0.6249
# Start run 60/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 1024, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9571 - accuracy: 0.6475
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9770 - accuracy: 0.6257
# 66/66 [==============================] - 0s 3ms/step - loss: 1.0330 - accuracy: 0.6220
# Start run 61/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 1024, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 1s 5ms/step - loss: 0.9482 - accuracy: 0.6480
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9582 - accuracy: 0.6271
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9835 - accuracy: 0.6325
# Start run 62/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 1024, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9897 - accuracy: 0.6342
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9804 - accuracy: 0.6328
# 66/66 [==============================] - 1s 4ms/step - loss: 1.0244 - accuracy: 0.6225
# Start run 63/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 1024, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 1s 5ms/step - loss: 0.9690 - accuracy: 0.6527
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9741 - accuracy: 0.6371
# 66/66 [==============================] - 1s 4ms/step - loss: 1.0055 - accuracy: 0.6344
# Start run 64/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 1024, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9554 - accuracy: 0.6570
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9836 - accuracy: 0.6461
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9937 - accuracy: 0.6225
# Start run 65/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9094 - accuracy: 0.6684
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9122 - accuracy: 0.6518
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9498 - accuracy: 0.6396
# Start run 66/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 1s 3ms/step - loss: 0.9081 - accuracy: 0.6632
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9184 - accuracy: 0.6518
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9487 - accuracy: 0.6496
# Start run 67/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9054 - accuracy: 0.6708
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9243 - accuracy: 0.6570
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9503 - accuracy: 0.6425
# Start run 68/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9372 - accuracy: 0.6580
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9073 - accuracy: 0.6575
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9723 - accuracy: 0.6382
# Start run 69/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9170 - accuracy: 0.6622
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9334 - accuracy: 0.6461
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9462 - accuracy: 0.6453
# Start run 70/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9376 - accuracy: 0.6618
# 66/66 [==============================] - 0s 3ms/step - loss: 0.8974 - accuracy: 0.6565
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9374 - accuracy: 0.6406
# Start run 71/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9316 - accuracy: 0.6632
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9237 - accuracy: 0.6494
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9784 - accuracy: 0.6443
# Start run 72/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9140 - accuracy: 0.6641
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9102 - accuracy: 0.6618
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9560 - accuracy: 0.6420
# Start run 73/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 512, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9838 - accuracy: 0.6466
# 66/66 [==============================] - 1s 5ms/step - loss: 0.9653 - accuracy: 0.6428
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9917 - accuracy: 0.6301
# Start run 74/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 512, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9579 - accuracy: 0.6423
# 66/66 [==============================] - 0s 4ms/step - loss: 0.9476 - accuracy: 0.6437
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9999 - accuracy: 0.6235
# Start run 75/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 512, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9592 - accuracy: 0.6461
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9481 - accuracy: 0.6413
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9914 - accuracy: 0.6330
# Start run 76/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 512, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 4ms/step - loss: 0.9476 - accuracy: 0.6523
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9677 - accuracy: 0.6394
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9738 - accuracy: 0.6344
# Start run 77/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 512, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9469 - accuracy: 0.6494
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9728 - accuracy: 0.6309
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9968 - accuracy: 0.6277
# Start run 78/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 512, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9516 - accuracy: 0.6504
# 66/66 [==============================] - 0s 4ms/step - loss: 0.9637 - accuracy: 0.6432
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9928 - accuracy: 0.6258
# Start run 79/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 512, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9689 - accuracy: 0.6385
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9686 - accuracy: 0.6461
# 66/66 [==============================] - 1s 3ms/step - loss: 0.9927 - accuracy: 0.6353
# Start run 80/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 512, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9552 - accuracy: 0.6442
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9624 - accuracy: 0.6361
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9909 - accuracy: 0.6287
# Start run 81/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9201 - accuracy: 0.6580
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9060 - accuracy: 0.6556
# 66/66 [==============================] - 1s 3ms/step - loss: 0.9340 - accuracy: 0.6467
# Start run 82/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9457 - accuracy: 0.6618
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9114 - accuracy: 0.6508
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9868 - accuracy: 0.6358
# Start run 83/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 1s 3ms/step - loss: 0.9072 - accuracy: 0.6613
# 66/66 [==============================] - 1s 5ms/step - loss: 0.9730 - accuracy: 0.6347
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9464 - accuracy: 0.6448
# Start run 84/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9163 - accuracy: 0.6622
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9068 - accuracy: 0.6599
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9413 - accuracy: 0.6382
# Start run 85/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9026 - accuracy: 0.6675
# 66/66 [==============================] - 0s 4ms/step - loss: 0.8974 - accuracy: 0.6589
# ...
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9232 - accuracy: 0.6684
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9123 - accuracy: 0.6456
# 66/66 [==============================] - 1s 3ms/step - loss: 0.9414 - accuracy: 0.6486
# Start run 146/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9054 - accuracy: 0.6632
# 66/66 [==============================] - 1s 4ms/step - loss: 0.8991 - accuracy: 0.6546
# 66/66 [==============================] - 1s 5ms/step - loss: 0.9336 - accuracy: 0.6500
# Start run 147/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9013 - accuracy: 0.6694
# 66/66 [==============================] - 1s 6ms/step - loss: 0.9593 - accuracy: 0.6418
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9619 - accuracy: 0.6415
# Start run 148/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.8942 - accuracy: 0.6708
# 66/66 [==============================] - 1s 3ms/step - loss: 0.9680 - accuracy: 0.6347
# 66/66 [==============================] - 1s 6ms/step - loss: 0.9328 - accuracy: 0.6500
# Start run 149/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 1s 6ms/step - loss: 0.9091 - accuracy: 0.6618
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9558 - accuracy: 0.6394
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9381 - accuracy: 0.6410
# Start run 150/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9066 - accuracy: 0.6694
# 66/66 [==============================] - 0s 3ms/step - loss: 0.8954 - accuracy: 0.6542
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9483 - accuracy: 0.6401
# Start run 151/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9086 - accuracy: 0.6660
# 66/66 [==============================] - 1s 4ms/step - loss: 0.8917 - accuracy: 0.6599
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9390 - accuracy: 0.6500
# Start run 152/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9160 - accuracy: 0.6618
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9216 - accuracy: 0.6428
# 66/66 [==============================] - 1s 3ms/step - loss: 0.9447 - accuracy: 0.6391
# Start run 153/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 1s 3ms/step - loss: 0.9595 - accuracy: 0.6423
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9386 - accuracy: 0.6432
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9684 - accuracy: 0.6273
# Start run 154/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9621 - accuracy: 0.6432
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9543 - accuracy: 0.6385
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9707 - accuracy: 0.6410
# Start run 155/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9592 - accuracy: 0.6532
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9440 - accuracy: 0.6437
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9766 - accuracy: 0.6372
# Start run 156/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9636 - accuracy: 0.6428
# 66/66 [==============================] - 1s 3ms/step - loss: 0.9566 - accuracy: 0.6375
# 66/66 [==============================] - 1s 5ms/step - loss: 0.9846 - accuracy: 0.6363
# Start run 157/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9414 - accuracy: 0.6570
# 66/66 [==============================] - 1s 5ms/step - loss: 0.9535 - accuracy: 0.6404
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9844 - accuracy: 0.6292
# Start run 158/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 1s 3ms/step - loss: 0.9432 - accuracy: 0.6461
# 66/66 [==============================] - 1s 5ms/step - loss: 0.9542 - accuracy: 0.6390
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9779 - accuracy: 0.6320
# Start run 159/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9566 - accuracy: 0.6470
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9365 - accuracy: 0.6489
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9875 - accuracy: 0.6339
# Start run 160/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 256, 'units_4': 1024, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9464 - accuracy: 0.6532
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9483 - accuracy: 0.6485
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9964 - accuracy: 0.6211
# Start run 161/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 512, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 1s 3ms/step - loss: 0.8791 - accuracy: 0.6684
# 66/66 [==============================] - 2s 5ms/step - loss: 0.8945 - accuracy: 0.6584
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9275 - accuracy: 0.6519
# Start run 162/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 512, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 4ms/step - loss: 0.8862 - accuracy: 0.6736
# 66/66 [==============================] - 1s 6ms/step - loss: 0.8861 - accuracy: 0.6622
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9253 - accuracy: 0.6600
# Start run 163/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 512, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 1s 4ms/step - loss: 0.8994 - accuracy: 0.6665
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9015 - accuracy: 0.6537
# 66/66 [==============================] - 1s 5ms/step - loss: 0.9500 - accuracy: 0.6519
# Start run 164/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 512, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 1s 4ms/step - loss: 0.8993 - accuracy: 0.6608
# 66/66 [==============================] - 0s 3ms/step - loss: 0.8902 - accuracy: 0.6546
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9284 - accuracy: 0.6500
# Start run 165/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 512, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 4ms/step - loss: 0.8869 - accuracy: 0.6713
# 66/66 [==============================] - 0s 2ms/step - loss: 0.8793 - accuracy: 0.6580
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9357 - accuracy: 0.6491
# Start run 166/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 512, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 1s 3ms/step - loss: 0.8957 - accuracy: 0.6675
# 66/66 [==============================] - 0s 3ms/step - loss: 0.8889 - accuracy: 0.6637
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9412 - accuracy: 0.6453
# Start run 167/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 512, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.8728 - accuracy: 0.6846
# 66/66 [==============================] - 0s 2ms/step - loss: 0.8937 - accuracy: 0.6551
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9268 - accuracy: 0.6562
# Start run 168/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 512, 'units_4': 512, 'batch_size': 512, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.8894 - accuracy: 0.6736
# 66/66 [==============================] - 0s 3ms/step - loss: 0.8832 - accuracy: 0.6698
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9323 - accuracy: 0.6486
# Start run 169/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 512, 'units_4': 512, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9196 - accuracy: 0.6508
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9395 - accuracy: 0.6371
# 66/66 [==============================] - 1s 3ms/step - loss: 0.9713 - accuracy: 0.6334
# Start run 170/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 512, 'units_4': 512, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 2ms/step - loss: 0.9711 - accuracy: 0.6399
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9538 - accuracy: 0.6399
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9935 - accuracy: 0.6273
# Start run 171/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 512, 'units_4': 512, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 1s 4ms/step - loss: 0.9515 - accuracy: 0.6523
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9363 - accuracy: 0.6442
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9865 - accuracy: 0.6334
# Start run 172/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 512, 'units_4': 512, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.1, 'reduce_lr_patience': 7, 'reduce_lr_min_lr': 1e-05}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9651 - accuracy: 0.6480
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9422 - accuracy: 0.6437
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9661 - accuracy: 0.6425
# Start run 173/1024: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 512, 'units_4': 512, 'batch_size': 1024, 'early_stopping_patience': 15, 'reduce_lr_factor': 0.5, 'reduce_lr_patience': 5, 'reduce_lr_min_lr': 1e-07}
# 66/66 [==============================] - 0s 3ms/step - loss: 0.9406 - accuracy: 0.6561

# %% [markdown]
# ### Sichern der Hyperparameter in csv Datei

# %%
resultsDF = pd.DataFrame(search_results)
resultsDF['delta_acc'] = (resultsDF['best_train_accuracy']-resultsDF['best_val_accuracy'])/resultsDF['best_val_accuracy']
resultsDF.to_csv('../data/optimization_results_final.csv', index=False)
resultsDF = pd.read_csv('../data/optimization_results_final.csv')
resultsDF.head()

# %% [markdown]
# ### graphische Darstellung der Performanceänderung

# %%
import seaborn as sns

# Mapping der activation_function auf numerische Werte
activation_mapping = {'relu': 0, 'LeakyReLU': 1}
resultsDF['activation_numerical'] = resultsDF['activation_function'].map(activation_mapping)

x_vars = [
    'num_hidden_layers',
    'units_1',
    'units_2',
    'units_3',
    'units_4',
    'dropout_rate',
    'activation_numerical',
    'batch_size',
    'early_stopping_patience',
    'reduce_lr_factor',
    'reduce_lr_patience',
    'reduce_lr_min_lr'
]

y_vars = [
    'best_val_accuracy',
    'best_train_accuracy',
    'delta_acc'
]

sns.pairplot(resultsDF, x_vars=x_vars, y_vars=y_vars, kind='reg', height=2)

# %% [markdown]
# ### Auswählen der besten Hyperparameter-Kombination

# %%
def calculate_score(row):
    # Bestmöglicher Score ist 
    best_score = 1.0
    
    # Berechnung des Scores basierend auf Delta-Accuracy und Best Validation Accuracy
    delta_acc_score = 1.0 - abs(row['delta_acc'])  # Je kleiner das Delta, desto besser der Score
    best_val_acc_score = row['best_val_accuracy']  # Je größer die Best Validation Accuracy, desto besser der Score
    
    #Gewichte
    w1=0.1
    w2=1
    
    # Gesamtscore berechnen
    score = (w1 * delta_acc_score + w2 * best_val_acc_score) / 2
    
    # Normalisierung des Scores auf den Bereich [0, 1]
    normalized_score = score / best_score
    
    return normalized_score

# Score-Spalte hinzufügen
resultsDF['score'] = resultsDF.apply(calculate_score, axis=1)
resultsDF = resultsDF.sort_values('score', ascending=False)
resultsDF.head()

# %%
import matplotlib.pyplot as plt

best_params = resultsDF.head(1)

# Scatterplot erstellen
sns.scatterplot(data=resultsDF, x='best_val_accuracy', y='delta_acc', alpha=0.5)
sns.scatterplot(data=best_params, x='best_val_accuracy', y='delta_acc', color='red')

# Achsentitel hinzufügen
plt.xlabel('best_val_accuracy')
plt.ylabel('delta_acc')

# Plot anzeigen
plt.show()

# %%
best_params = resultsDF.iloc[1]
model = build_model_from_params(best_params)
model.summary()

# %% [markdown]
# ### Das beste Modell

# %%
batch_size = best_params['batch_size']
nb_epoch = 300

# Definiere die Early Stopping-Bedingungen
early_stopping = EarlyStopping(monitor='val_loss', patience=best_params['early_stopping_patience'], mode='min', restore_best_weights=True)

# Definiere die Reduzierung der Lernrate, falls die Verbesserung stagniert
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=best_params['reduce_lr_factor'], best_patience=best_params['reduce_lr_patience'], mode='min', min_lr=best_params['reduce_lr_min_lr'])

hist = model.fit(X_train, Y_train, validation_data=(X_val, Y_val), 
                 epochs=nb_epoch, batch_size=batch_size, callbacks=[early_stopping, reduce_lr], verbose=0)

# %%
Y_pred = model.predict(X_test)

# %% [markdown]
# ### Evaluation

# %%
def plot_history(network_history):
    plt.figure()
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.plot(network_history.history['loss'])
    plt.plot(network_history.history['val_loss'])
    plt.legend(['Training', 'Validation'])

    plt.figure()
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.plot(network_history.history['accuracy'])
    plt.plot(network_history.history['val_accuracy'])
    plt.legend(['Training', 'Validation'], loc='lower right')
    plt.show()

# %%
plot_history(hist)

# %%
from sklearn.metrics import confusion_matrix

Y_pred_classes = np.argmax(Y_pred, axis=1)

cm = confusion_matrix(Y_test_classes, Y_pred_classes, normalize='true')
plt.figure(figsize=(20,20))
sns.heatmap(cm, annot=True, xticklabels=label, yticklabels=label)
plt.xlabel('Vorhergesagtes Genre')
plt.ylabel('Tatsächliches Genre')
plt.savefig('../figures/confusion_matrix_NN.png')
plt.show()

# %%
from sklearn.metrics import precision_recall_curve, auc

if isinstance(Y_test, pd.DataFrame):
    Y_test = Y_test.values
if isinstance(Y_pred, pd.DataFrame):
    Y_pred = Y_pred.values

precision, recall, thresholds = precision_recall_curve(Y_test.ravel(), Y_pred.ravel())


# Berechne Precision, Recall und Schwellenwerte
precision, recall, thresholds = precision_recall_curve(Y_test.ravel(), Y_pred.ravel())

# Berechne den AUC-PR
auc_pr = auc(recall, precision)

plt.plot(recall, precision, label=f"AUC-PR = {auc_pr:.3}")
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend()
plt.title('Precision-Recall Curve')
plt.show()

# %%
# Precision Recall Curve für jede Klasse einzeln

n_classes = Y_test.shape[1]

if isinstance(Y_test, np.ndarray):
    Y_test = pd.DataFrame(Y_test)
if isinstance(Y_pred, np.ndarray):
    Y_pred = pd.DataFrame(Y_pred)

auc_pr_values = []

# Für jede Klasse
for i in range(n_classes):
    precision, recall, _ = precision_recall_curve(Y_test.iloc[:, i], Y_pred.iloc[:, i])

    # Berechne den AUC-PR
    auc_pr = auc(recall, precision)
    auc_pr_values.append((label[i], auc_pr))

    plt.plot(
        recall,
        precision,
        label=f"{label[i]}, AUC-PR = {auc_pr:.3}",
    )

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.legend()
plt.title("Precision-Recall Curve")

# Genres nach AUC-PR-Wert sortieren
auc_pr_values_sorted = sorted(auc_pr_values, key=lambda x: x[1], reverse=True)

# Ausgabe der Genres und AUC-PR-Werte
for genre, auc_pr in auc_pr_values_sorted:
    print(f"{genre}: AUC-PR = {auc_pr:.3}")
