# %% [markdown]
# # Notiz für Henry:
# diese Datei ist dafür da das Neuronale Netz zu entwickeln. In einem Notebook kann man schneller Hyperparameter ändern und einfacher weitere kleine Änderungen vornehmen. Wenn das Gröbste steht können wir das Notebook einfach als .py Datei exportieren und sind happy

# %% [markdown]
# Korrelationen für Pop
#
# Cluster in Pop?
#
# Pop in Cluster aufteilen
#
# eventuell auch mit Rock?
#
# Hyperparameter optimieren

# %% [markdown]
# ## Importieren der wichtigsten Pakete

# %%
import csv
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
from sklearn.utils.class_weight import compute_class_weight
import pandas as pd

# %%
# GPU Test
import tensorflow as tf

# Funktioniert momentan bei mir immernoch nicht
#if tf.test.is_gpu_available():
#   print("GPU is available")
#   print("GPU(s) that Tensorflow recognizes:", tf.config.list_physical_devices('GPU'))
#else:
#   print("GPU not available")
# Manuell auf CPU einschränken
tf.config.set_visible_devices([], 'GPU')

# %% [markdown]
# ## Sinnvolle Funktionen

# %%
################################################################################################### 
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_history(network_history):
    plt.figure()
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.plot(network_history.history['loss'])
    plt.plot(network_history.history['val_loss'])
    plt.legend(['Training', 'Validation'])

    plt.figure()
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.plot(network_history.history['accuracy'])
    plt.plot(network_history.history['val_accuracy'])
    plt.legend(['Training', 'Validation'], loc='lower right')
    plt.show()
    
###################################################################################################    

import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        value = f'{cm[i, j]:.3f}'  # Runde den Wert auf 3 Dezimalstellen
        plt.text(j, i, value,
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
################################################################################################### 
import matplotlib.cm as cm
def display_errors(errors_index,img_errors,pred_errors, obs_errors):
    """ This function shows 6 images with their predicted and real labels"""
    n = 0
    nrows = 2
    ncols = 3
    fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True)
    for row in range(nrows):
        for col in range(ncols):
            error = errors_index[n]
            ax[row,col].imshow((img_errors[n]).reshape((28,28)), cmap=cm.Greys, interpolation='nearest')
            ax[row,col].set_title("Predicted label :{}\nTrue label :{}".format(pred_errors[n],obs_errors[n]))
            n += 1
            
###################################################################################################

# %%
def evaluate(X_test, Y_test):
    # Make predictions on test data
    Y_pred = model.predict(X_test)
    # Calculate loss and accuracy
    loss, accuracy = model.evaluate(X_test, Y_test, verbose=0)
    print(f"loss:     {loss:.3}")
    print(f"accuracy: {accuracy:.3}")

    # Compute the classification report
    report = classification_report(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))
    print(report)
    
    # Plot probability of being zero for true !genre! and non-!genre!
    true_genre = np.where(np.argmax(Y_test, axis=1) == 0)[0]
    true_non_genre = np.where(np.argmax(Y_test, axis=1) != 0)[0]
    
    plt.figure()
    plt.hist(Y_pred[true_genre, 0], bins=50, color='red', label='True !genre!', alpha=0.5)
    plt.hist(Y_pred[true_non_genre, 0], bins=50, color='blue', label='True Non-!genre!', alpha=0.5)
    plt.xlabel('Probability of !hier genre einfügen!')
    plt.ylabel('Frequency')
    plt.yscale('log')
    plt.legend()

    # Compute the confusion matrix
    confusion_mtx = confusion_matrix(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))
    # Plot the confusion matrix
    plt.figure(figsize=(10, 10))
    plot_confusion_matrix(confusion_mtx, classes=range(10), normalize='true')

# %% [markdown]
# ## Laden der Daten
# Am besten wir fügen das Genre in einer separaten Datei dem Datensatz hinzu und machen ab hier nur mit dem fertigen Datensatz weiter

# %% [markdown]
# ## Convert target

# %%
#csv_file = "../data/data_selected.csv"
csv_file = "../data/data_selected_v1.csv"

df = pd.read_csv(csv_file)
df.columns
# Out:
# Index(['Unnamed: 0', 'Danceability', 'Energy', 'Key', 'Loudness',
#        'Speechiness', 'Acousticness', 'Instrumentalness', 'Liveness',
#        'Valence', 'Tempo', 'Duration_ms', 'Views', 'Likes', 'Comments',
#        'Stream', 'Genre', 'Artist_encoded', 'Album_type_encoded',
#        'Licensed_encoded', 'official_video_encoded'],
#       dtype='object')

# %%
df = df.loc[~df["Genre"].isin(["bullshit"])]
#df = df.loc[~df["Genre"].isin(["country"])]
#df = df.loc[~df["Genre"].isin(["raggae"])]
#df = df.loc[~df["Genre"].isin(["rock"])]
#df = df.loc[~df["Genre"].isin(["soul"])]
#df = df.loc[~df["Genre"].isin(["folk"])]
#df = df.loc[~df["Genre"].isin(["pop"])]

genres_to_keep = ["classic", "metal", "rock", "hip hop", "electronic", "pop"]
df = df[df['Genre'].isin(genres_to_keep)]

n=100
genre_counts = df["Genre"].value_counts()
df= df[df["Genre"].isin(genre_counts[genre_counts > n].index)]

# %%
features_drop = ['Genre', 'Unnamed: 0']

df = df.sample(frac=1, random_state=42) #daten mischen

X = df.drop(features_drop, axis=1)
Y = df['Genre']

# %%
# One-Hot-Encoding durchführen
Y = pd.get_dummies(Y)

# label um One-Hot-Encoding hinterher wieder zu übersetzen
genre_mapping = Y.columns
label = []
for index, genre in enumerate(genre_mapping):
    label.append(genre)
    print("Genre", index, ":", genre)
# Out:
# Genre 0 : classic
# Genre 1 : electronic
# Genre 2 : hip hop
# Genre 3 : metal
# Genre 4 : pop
# Genre 5 : rock

# %% [markdown]
# ## Splitten von Training und Test Datensätzen

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, stratify=Y, random_state=42)
X_train, X_val,  Y_train, Y_val  = train_test_split(X_train, Y_train, test_size=0.3, stratify=Y_train, random_state=42)

# %%
#from sklearn.model_selection import StratifiedShuffleSplit

# Erstellen Sie den StratifiedShuffleSplit-Teiler
#sss = StratifiedShuffleSplit(n_splits=5, test_size=0.2, random_state=42)

# Verwenden Sie den Teiler, um Ihre Daten in Trainings- und Testsets aufzuteilen.
#for train_index, test_index in sss.split(X, Y):
#    X_train, X_test = X[train_index], X[test_index]
#    Y_train, Y_test = Y[train_index], Y[test_index]
    
    # Erstellen Sie einen zweiten StratifiedShuffleSplit-Teiler für das Validierungsset
#    sss_val = StratifiedShuffleSplit(n_splits=1, test_size=0.25, random_state=42)
    
#    for train_index, val_index in sss_val.split(X_train, Y_train):
#        X_train, X_val = X_train[train_index], X_train[val_index]
#        Y_train, Y_val = Y_train[train_index], Y_train[val_index]

# %% [markdown]
# ## Daten skalieren

# %%
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Gewichte berechnen um Überrepräsentation zu vermeiden

# %%
from sklearn.utils.class_weight import compute_class_weight

num_classes = len(Y.value_counts())
class_counts = np.sum(Y_train, axis=0)
total_samples = np.sum(class_counts)
class_weights = total_samples / (num_classes * class_counts)

class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}

# Anpassung der Gewichte auf das One-Hot-kodierte Y_train
Y_train_encoded = np.argmax(Y_train, axis=1)
sample_weights = np.array([class_weights_dict[class_label] for class_label in Y_train_encoded])

# Transformieren, damit die wichtigsten Klassen nicht unterrepräsentiert sind 
# TODO: finde eine gute Funktion dafür
#transformed_weights = np.log(sample_weights + 1) #log acc~25% -> funktioniert glaube ich am besten
#transformed_weights = sample_weights ** 2 # square acc~10% -> der ist ziemlich kacke
#transformed_weights = np.exp(sample_weights) # exp acc~7%
transformed_weights = 1 / (1 + np.exp(-sample_weights)) #sigmoid acc~40%

# %% [markdown]
# ## Modell
# hier ein schönes Modell ergänzen

# %%
model = Sequential()
model.add(Dense(units=64, activation='relu', input_dim=X_train.shape[1]))
model.add(Dropout(0.5))
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'], jit_compile=False)

# %%
model.summary()
# Out:
# Model: "sequential_2637"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12144 (Dense)         (None, 64)                1280
#
#  dropout_9513 (Dropout)      (None, 64)                0
#
#  dense_12145 (Dense)         (None, 128)               8320
#
#  dropout_9514 (Dropout)      (None, 128)               0
#
#  dense_12146 (Dense)         (None, 256)               33024
#
#  dropout_9515 (Dropout)      (None, 256)               0
#
#  dense_12147 (Dense)         (None, 512)               131584
#
#  dropout_9516 (Dropout)      (None, 512)               0
#
#  dense_12148 (Dense)         (None, 6)                 3078
#
# =================================================================
# Total params: 177,286
# Trainable params: 177,286
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

batch_size = 32
nb_epoch = 300

# Definiere die Early Stopping-Bedingungen
early_stopping = EarlyStopping(monitor='val_loss', patience=5, mode='min', restore_best_weights=True)

# Definiere die Reduzierung der Lernrate, falls die Verbesserung stagniert
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, mode='min', min_lr=1e-7)

hist = model.fit(X_train, Y_train, validation_data=(X_val, Y_val), 
                 epochs=nb_epoch, batch_size=batch_size, callbacks=[early_stopping, reduce_lr])
#hist = model.fit(X_train, Y_train, sample_weight=transformed_weights, validation_data=(X_val, Y_val), 
#                 epochs=nb_epoch, batch_size=batch_size, callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/300
# 99/99 [==============================] - 2s 8ms/step - loss: 1.5645 - accuracy: 0.3727 - val_loss: 1.3014 - val_accuracy: 0.5177 - lr: 0.0010
# Epoch 2/300
# 99/99 [==============================] - 1s 7ms/step - loss: 1.3593 - accuracy: 0.4652 - val_loss: 1.1776 - val_accuracy: 0.5569 - lr: 0.0010
# Epoch 3/300
# 99/99 [==============================] - 1s 7ms/step - loss: 1.2581 - accuracy: 0.5082 - val_loss: 1.0937 - val_accuracy: 0.5857 - lr: 0.0010
# Epoch 4/300
# 99/99 [==============================] - 1s 8ms/step - loss: 1.2054 - accuracy: 0.5367 - val_loss: 1.0582 - val_accuracy: 0.6056 - lr: 0.0010
# Epoch 5/300
# 99/99 [==============================] - 1s 7ms/step - loss: 1.1622 - accuracy: 0.5408 - val_loss: 1.0228 - val_accuracy: 0.6064 - lr: 0.0010
# Epoch 6/300
# 99/99 [==============================] - 1s 7ms/step - loss: 1.1797 - accuracy: 0.5339 - val_loss: 1.0259 - val_accuracy: 0.5968 - lr: 0.0010
# Epoch 7/300
# 99/99 [==============================] - 1s 8ms/step - loss: 1.1374 - accuracy: 0.5605 - val_loss: 1.0143 - val_accuracy: 0.6256 - lr: 0.0010
# Epoch 8/300
# 99/99 [==============================] - 1s 8ms/step - loss: 1.1407 - accuracy: 0.5621 - val_loss: 1.0114 - val_accuracy: 0.6270 - lr: 0.0010
# Epoch 9/300
# 99/99 [==============================] - 1s 8ms/step - loss: 1.1026 - accuracy: 0.5716 - val_loss: 0.9723 - val_accuracy: 0.6329 - lr: 0.0010
# Epoch 10/300
# 99/99 [==============================] - 1s 7ms/step - loss: 1.0774 - accuracy: 0.5921 - val_loss: 0.9689 - val_accuracy: 0.6100 - lr: 0.0010
# Epoch 11/300
# 99/99 [==============================] - 1s 7ms/step - loss: 1.0908 - accuracy: 0.5722 - val_loss: 0.9675 - val_accuracy: 0.6352 - lr: 0.0010
# Epoch 12/300
# 99/99 [==============================] - 1s 7ms/step - loss: 1.0892 - accuracy: 0.5874 - val_loss: 0.9803 - val_accuracy: 0.6278 - lr: 0.0010
# Epoch 13/300
# 99/99 [==============================] - 1s 7ms/step - loss: 1.0611 - accuracy: 0.5944 - val_loss: 0.9706 - val_accuracy: 0.6219 - lr: 0.0010
# Epoch 14/300
# 99/99 [==============================] - 1s 7ms/step - loss: 1.0547 - accuracy: 0.5969 - val_loss: 0.9480 - val_accuracy: 0.6352 - lr: 0.0010
# Epoch 15/300
# 99/99 [==============================] - 1s 8ms/step - loss: 1.0597 - accuracy: 0.5953 - val_loss: 0.9564 - val_accuracy: 0.6337 - lr: 0.0010
# Epoch 16/300
# 99/99 [==============================] - 1s 7ms/step - loss: 1.0507 - accuracy: 0.5991 - val_loss: 0.9417 - val_accuracy: 0.6278 - lr: 0.0010
# Epoch 17/300
# 99/99 [==============================] - 1s 7ms/step - loss: 1.0390 - accuracy: 0.6035 - val_loss: 0.9477 - val_accuracy: 0.6381 - lr: 0.0010
# Epoch 18/300
# 99/99 [==============================] - 1s 7ms/step - loss: 1.0215 - accuracy: 0.6153 - val_loss: 0.9398 - val_accuracy: 0.6366 - lr: 0.0010
# Epoch 19/300
# 99/99 [==============================] - 1s 7ms/step - loss: 1.0239 - accuracy: 0.6102 - val_loss: 0.9429 - val_accuracy: 0.6433 - lr: 0.0010
# Epoch 20/300
# 99/99 [==============================] - 1s 8ms/step - loss: 1.0145 - accuracy: 0.6061 - val_loss: 0.9304 - val_accuracy: 0.6403 - lr: 0.0010
# Epoch 21/300
# 99/99 [==============================] - 1s 8ms/step - loss: 1.0305 - accuracy: 0.6096 - val_loss: 0.9319 - val_accuracy: 0.6411 - lr: 0.0010
# Epoch 22/300
# 99/99 [==============================] - 1s 8ms/step - loss: 1.0168 - accuracy: 0.6035 - val_loss: 0.9240 - val_accuracy: 0.6374 - lr: 0.0010
# Epoch 23/300
# 99/99 [==============================] - 1s 8ms/step - loss: 1.0232 - accuracy: 0.6162 - val_loss: 0.9329 - val_accuracy: 0.6381 - lr: 0.0010
# Epoch 24/300
# 99/99 [==============================] - 1s 7ms/step - loss: 1.0005 - accuracy: 0.6083 - val_loss: 0.9264 - val_accuracy: 0.6337 - lr: 0.0010
# Epoch 25/300
# 99/99 [==============================] - 1s 8ms/step - loss: 1.0019 - accuracy: 0.6254 - val_loss: 0.9181 - val_accuracy: 0.6411 - lr: 0.0010
# Epoch 26/300
# 99/99 [==============================] - 1s 8ms/step - loss: 1.0089 - accuracy: 0.6153 - val_loss: 0.9290 - val_accuracy: 0.6337 - lr: 0.0010
# Epoch 27/300
# 99/99 [==============================] - 1s 8ms/step - loss: 1.0020 - accuracy: 0.6206 - val_loss: 0.9235 - val_accuracy: 0.6411 - lr: 0.0010
# Epoch 28/300
# 99/99 [==============================] - 1s 7ms/step - loss: 1.0016 - accuracy: 0.6194 - val_loss: 0.9185 - val_accuracy: 0.6440 - lr: 0.0010
# Epoch 29/300
# 99/99 [==============================] - 1s 6ms/step - loss: 0.9893 - accuracy: 0.6267 - val_loss: 0.9205 - val_accuracy: 0.6411 - lr: 0.0010
# Epoch 30/300
# 99/99 [==============================] - 1s 6ms/step - loss: 0.9884 - accuracy: 0.6162 - val_loss: 0.9262 - val_accuracy: 0.6411 - lr: 0.0010

# %%
plot_history(hist)

# %% [markdown]
# ## Vorhersage

# %%
Y_pred = model.predict(X_test)
# Out:
# 61/61 [==============================] - 0s 2ms/step

# %%
#import matplotlib.pyplot as plt
#
#for i in range(len(label)):
#    genre = label[i]
#    probabilities = Y_pred[:, i]
    
#    plt.figure()
#    plt.hist(probabilities, bins=50)
#    plt.xlabel('Wahrscheinlichkeit')
#    plt.ylabel('Anzahl der Vorhersagen')
#    plt.yscale("log")
#    plt.title(f'Genre: {genre}')

# %% [markdown]
# ## Evaluation

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

#Y_pred_classes = np.argmax(Y_pred, axis=1)
Y_pred_classes = np.argmax(Y_pred, axis=1)

for i in range(len(Y_pred_classes)):
    if label[Y_pred_classes[i]] == 'pop' and Y_pred[i, Y_pred_classes[i]] > 0.9:
        # Finde den Index des zweithöchsten Werts
        second_highest_index = np.argsort(Y_pred[i])[-2]
        Y_pred_classes[i] = second_highest_index
Y_test_classes = np.argmax(Y_test, axis=1)

cm = confusion_matrix(Y_test_classes, Y_pred_classes, normalize='true')
plt.figure(figsize=(20,20))
sns.heatmap(cm, annot=True, xticklabels=label, yticklabels=label)
plt.xlabel('Vorhergesagtes Genre')
plt.ylabel('Tatsächliches Genre')
plt.savefig('../figures/confusion_matrix.png')
plt.show()

# %%
# Precision-Recall Curve
#-> die sollte eigentlich anders aussehen...

from sklearn.metrics import precision_recall_curve, auc

Y_prob = Y_pred

if isinstance(Y_test, pd.DataFrame):
    Y_test = Y_test.values
if isinstance(Y_prob, pd.DataFrame):
    Y_prob = Y_prob.values

precision, recall, thresholds = precision_recall_curve(Y_test.ravel(), Y_prob.ravel())


# Berechne Precision, Recall und Schwellenwerte
precision, recall, thresholds = precision_recall_curve(Y_test.ravel(), Y_prob.ravel())

# Berechne den AUC-PR
auc_pr = auc(recall, precision)

plt.plot(recall, precision, label=f"AUC-PR = {auc_pr:.3}")
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend()
plt.title('Precision-Recall Curve')
plt.show()

# %%
# Precision Recall Curve für jede Klasse einzeln

n_classes = Y_test.shape[1]

if isinstance(Y_test, np.ndarray):
    Y_test = pd.DataFrame(Y_test)
if isinstance(Y_pred, np.ndarray):
    Y_pred = pd.DataFrame(Y_pred)

auc_pr_values = []

# Für jede Klasse
for i in range(n_classes):
    precision, recall, _ = precision_recall_curve(Y_test.iloc[:, i], Y_pred.iloc[:, i])

    # Berechne den AUC-PR
    auc_pr = auc(recall, precision)
    auc_pr_values.append((label[i], auc_pr))

    plt.plot(
        recall,
        precision,
        label=f"{label[i]}, AUC-PR = {auc_pr:.3}",
    )

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.legend()
plt.title("Precision-Recall Curve")

# Genres nach AUC-PR-Wert sortieren
auc_pr_values_sorted = sorted(auc_pr_values, key=lambda x: x[1], reverse=True)

# Ausgabe der Genres und AUC-PR-Werte
for genre, auc_pr in auc_pr_values_sorted:
    print(f"{genre}: AUC-PR = {auc_pr:.3}")
# Out:
# hip hop: AUC-PR = 0.856
# classic: AUC-PR = 0.757
# rock: AUC-PR = 0.644
# metal: AUC-PR = 0.612
# pop: AUC-PR = 0.491
# electronic: AUC-PR = 0.485

# %% [markdown]
# ## Hyperparameter Optimierung

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

def build_model_from_params(params):
    num_hidden_layers = params['num_hidden_layers']
    activation_function = params['activation_function']
    dropout_rate = params['dropout_rate']
    units_per_layer = [params['units_1'],params['units_2'],params['units_3'],params['units_4']]

    model = Sequential()
    model.add(Dense(units=units_per_layer[0], activation=activation_function, input_dim=X_train.shape[1]))
    model.add(Dropout(dropout_rate))

    for i in range(1, num_hidden_layers+1):
        if i < len(units_per_layer):
            model.add(Dense(units=units_per_layer[i], activation=activation_function))
            model.add(Dropout(dropout_rate))

    model.add(Dense(units=num_classes, activation='softmax'))
    
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
param_space = {
    'num_hidden_layers': [2, 3],
    'activation_function': ['LeakyReLU'],
    'dropout_rate': [0.3, 0.5, 0.7],
    'units_1': [64, 128, 256],
    'units_2': [128, 256, 512],
    'units_3': [256, 512, 1024],
    'units_4': [512, 1024],
}
#param_space = {
#    'units_1': [64, 128, 256],
#    'units_2': [128, 256, 512],
#    'units_3': [256, 512, 1024],
#    'units_4': [512, 1024, 2048],
#    'dropout_rate': [0.3, 0.5],
#    'activation_function' : ['LeakyReLU'] # LeakyReLU verbessert val_acc, train_acc und senkt delta_acc
#}


value_combis = itertools.product(*[v for v in param_space.values()])

# List comprehension short form:
param_combis = [{key:value for key, value in zip(param_space.keys(), combi)} for combi in value_combis]

print(f"We have a total of {len(param_combis)} combinations:")
print(param_combis)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.model_selection import StratifiedKFold

search_results = []

k_folds = 3
skf = StratifiedKFold(n_splits=k_folds)

for idx, params in enumerate(param_combis):
    print(f"Start run {idx+1}/{len(param_combis)}: Parameters: {params}")
    
    val_accuracies = []
    val_losses = []
    train_accuracies = []
    train_losses = []
    
    for fold_idx, (train_index, val_index) in enumerate(skf.split(X_train, np.argmax(Y_train, axis=1))):
        X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
        Y_train_fold, Y_val_fold = Y_train.reset_index(drop=True).iloc[train_index], Y_train.reset_index(drop=True).iloc[val_index]
        
        filepath = f"../model_fold/model_fold_{idx+1}_fold_{fold_idx+1}.h5"
        checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=0, save_best_only=True, mode='max')
        
        this_model = build_model_from_params(params)
        
        fit_results = this_model.fit(X_train_fold, Y_train_fold, validation_data=(X_val_fold, Y_val_fold), 
                                     epochs=10, batch_size=512, callbacks=[checkpoint], verbose=0)
        
        # Extract the best validation scores
        best_val_epoch = np.argmax(fit_results.history['val_accuracy'])
        val_accuracies.append(np.max(fit_results.history['val_accuracy']))
        val_losses.append(fit_results.history['val_loss'][best_val_epoch])
        
        # Get training accuracy and loss
        best_model = load_model(filepath)
        train_loss, train_acc = best_model.evaluate(X_train_fold, Y_train_fold)
        train_accuracies.append(train_acc)
        train_losses.append(train_loss)
    
    # Store results
    search_results.append({
        **params,
        'best_val_accuracy': np.mean(val_accuracies),
        'val_accuracy_std': np.std(val_accuracies),
        'best_val_loss': np.mean(val_losses),
        'val_loss_std': np.std(val_losses),
        'best_train_accuracy': np.mean(train_accuracies),
        'train_accuracy_std': np.std(train_accuracies),
        'best_train_loss': np.mean(train_losses),
        'train_loss_std': np.std(train_losses)
    })
# Out:
# Start run 1/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5100 - accuracy: 0.8178
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5713 - accuracy: 0.8091
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5103 - accuracy: 0.8267
# Start run 2/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 1024}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5182 - accuracy: 0.8121
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5109 - accuracy: 0.8299
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4908 - accuracy: 0.8261
# Start run 3/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4845 - accuracy: 0.8272
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5398 - accuracy: 0.8078
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4859 - accuracy: 0.8336
# Start run 4/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 1024}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5017 - accuracy: 0.8241
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4975 - accuracy: 0.8242
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4865 - accuracy: 0.8242
# Start run 5/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 1024, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4891 - accuracy: 0.8279
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5012 - accuracy: 0.8198
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5327 - accuracy: 0.8147
# Start run 6/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 128, 'units_3': 1024, 'units_4': 1024}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5062 - accuracy: 0.8153
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4845 - accuracy: 0.8305
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4869 - accuracy: 0.8349
# Start run 7/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4993 - accuracy: 0.8159
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4811 - accuracy: 0.8210
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4882 - accuracy: 0.8273
# Start run 8/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4919 - accuracy: 0.8247
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5084 - accuracy: 0.8154
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4871 - accuracy: 0.8286
# Start run 9/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 256, 'units_3': 512, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4691 - accuracy: 0.8298
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5054 - accuracy: 0.8141
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4898 - accuracy: 0.8305
# Start run 10/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 256, 'units_3': 512, 'units_4': 1024}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4842 - accuracy: 0.8222
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4882 - accuracy: 0.8286
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4741 - accuracy: 0.8374
# Start run 11/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 256, 'units_3': 1024, 'units_4': 512}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4848 - accuracy: 0.8247
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4749 - accuracy: 0.8412
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4670 - accuracy: 0.8286
# Start run 12/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 256, 'units_3': 1024, 'units_4': 1024}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4729 - accuracy: 0.8247
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5078 - accuracy: 0.8198
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4660 - accuracy: 0.8381
# Start run 13/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 512, 'units_3': 256, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4753 - accuracy: 0.8285
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4823 - accuracy: 0.8248
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4705 - accuracy: 0.8355
# Start run 14/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 512, 'units_3': 256, 'units_4': 1024}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4698 - accuracy: 0.8285
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4809 - accuracy: 0.8273
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4921 - accuracy: 0.8311
# Start run 15/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 512, 'units_3': 512, 'units_4': 512}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4585 - accuracy: 0.8361
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4888 - accuracy: 0.8273
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4884 - accuracy: 0.8305
# Start run 16/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 512, 'units_3': 512, 'units_4': 1024}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4758 - accuracy: 0.8216
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4864 - accuracy: 0.8318
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4690 - accuracy: 0.8393
# Start run 17/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 512, 'units_3': 1024, 'units_4': 512}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4645 - accuracy: 0.8348
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4892 - accuracy: 0.8318
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4699 - accuracy: 0.8387
# Start run 18/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 64, 'units_2': 512, 'units_3': 1024, 'units_4': 1024}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4680 - accuracy: 0.8228
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4986 - accuracy: 0.8267
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4747 - accuracy: 0.8305
# Start run 19/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 256, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4848 - accuracy: 0.8209
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4956 - accuracy: 0.8255
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4754 - accuracy: 0.8374
# Start run 20/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 256, 'units_4': 1024}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5095 - accuracy: 0.8197
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4844 - accuracy: 0.8349
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4789 - accuracy: 0.8229
# Start run 21/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 512, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4571 - accuracy: 0.8335
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4915 - accuracy: 0.8229
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4707 - accuracy: 0.8324
# Start run 22/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 512, 'units_4': 1024}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4889 - accuracy: 0.8216
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4781 - accuracy: 0.8311
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4658 - accuracy: 0.8318
# Start run 23/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 1024, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4706 - accuracy: 0.8291
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4944 - accuracy: 0.8210
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4736 - accuracy: 0.8362
# Start run 24/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 128, 'units_3': 1024, 'units_4': 1024}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4658 - accuracy: 0.8272
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4614 - accuracy: 0.8355
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4667 - accuracy: 0.8362
# Start run 25/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 256, 'units_3': 256, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4827 - accuracy: 0.8197
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4733 - accuracy: 0.8255
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4511 - accuracy: 0.8437
# Start run 26/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 256, 'units_3': 256, 'units_4': 1024}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5044 - accuracy: 0.8260
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4717 - accuracy: 0.8299
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4627 - accuracy: 0.8349
# Start run 27/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 256, 'units_3': 512, 'units_4': 512}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4586 - accuracy: 0.8354
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4643 - accuracy: 0.8343
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4582 - accuracy: 0.8418
# Start run 28/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 256, 'units_3': 512, 'units_4': 1024}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4837 - accuracy: 0.8235
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4888 - accuracy: 0.8368
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4689 - accuracy: 0.8343
# Start run 29/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 256, 'units_3': 1024, 'units_4': 512}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4596 - accuracy: 0.8323
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4784 - accuracy: 0.8349
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4426 - accuracy: 0.8494
# Start run 30/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 256, 'units_3': 1024, 'units_4': 1024}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4550 - accuracy: 0.8335
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4583 - accuracy: 0.8387
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4609 - accuracy: 0.8349
# Start run 31/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 512, 'units_3': 256, 'units_4': 512}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4429 - accuracy: 0.8367
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4541 - accuracy: 0.8494
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4611 - accuracy: 0.8362
# Start run 32/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 512, 'units_3': 256, 'units_4': 1024}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4619 - accuracy: 0.8411
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4692 - accuracy: 0.8406
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4617 - accuracy: 0.8425
# Start run 33/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 512, 'units_3': 512, 'units_4': 512}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4511 - accuracy: 0.8367
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4731 - accuracy: 0.8355
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4626 - accuracy: 0.8349
# Start run 34/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 512, 'units_3': 512, 'units_4': 1024}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4432 - accuracy: 0.8310
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4603 - accuracy: 0.8387
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4564 - accuracy: 0.8437
# Start run 35/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 512, 'units_3': 1024, 'units_4': 512}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4731 - accuracy: 0.8449
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4555 - accuracy: 0.8444
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4969 - accuracy: 0.8387
# Start run 36/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 128, 'units_2': 512, 'units_3': 1024, 'units_4': 1024}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4788 - accuracy: 0.8291
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4653 - accuracy: 0.8343
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4380 - accuracy: 0.8469
# Start run 37/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 256, 'units_2': 128, 'units_3': 256, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4602 - accuracy: 0.8329
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4593 - accuracy: 0.8381
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4845 - accuracy: 0.8311
# Start run 38/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 256, 'units_2': 128, 'units_3': 256, 'units_4': 1024}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4557 - accuracy: 0.8323
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4871 - accuracy: 0.8305
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4502 - accuracy: 0.8494
# Start run 39/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 256, 'units_2': 128, 'units_3': 512, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4492 - accuracy: 0.8291
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4674 - accuracy: 0.8318
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4651 - accuracy: 0.8374
# Start run 40/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 256, 'units_2': 128, 'units_3': 512, 'units_4': 1024}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4614 - accuracy: 0.8310
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4714 - accuracy: 0.8286
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4451 - accuracy: 0.8418
# Start run 41/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 256, 'units_2': 128, 'units_3': 1024, 'units_4': 512}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4700 - accuracy: 0.8279
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4922 - accuracy: 0.8286
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4502 - accuracy: 0.8412
# Start run 42/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 256, 'units_2': 128, 'units_3': 1024, 'units_4': 1024}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4656 - accuracy: 0.8298
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4701 - accuracy: 0.8412
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4647 - accuracy: 0.8336
# Start run 43/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 256, 'units_2': 256, 'units_3': 256, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4531 - accuracy: 0.8317
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4749 - accuracy: 0.8374
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4555 - accuracy: 0.8381
# Start run 44/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 256, 'units_2': 256, 'units_3': 256, 'units_4': 1024}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4493 - accuracy: 0.8373
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4576 - accuracy: 0.8393
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4954 - accuracy: 0.8299
# Start run 45/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 256, 'units_2': 256, 'units_3': 512, 'units_4': 512}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4811 - accuracy: 0.8197
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4686 - accuracy: 0.8343
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4481 - accuracy: 0.8469
# Start run 46/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 256, 'units_2': 256, 'units_3': 512, 'units_4': 1024}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4507 - accuracy: 0.8405
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4712 - accuracy: 0.8368
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4434 - accuracy: 0.8469
# Start run 47/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 256, 'units_2': 256, 'units_3': 1024, 'units_4': 512}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4424 - accuracy: 0.8335
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4365 - accuracy: 0.8444
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4640 - accuracy: 0.8399
# Start run 48/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 256, 'units_2': 256, 'units_3': 1024, 'units_4': 1024}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4944 - accuracy: 0.8260
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4695 - accuracy: 0.8311
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4357 - accuracy: 0.8494
# Start run 49/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 256, 'units_2': 512, 'units_3': 256, 'units_4': 512}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4513 - accuracy: 0.8373
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4505 - accuracy: 0.8507
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4556 - accuracy: 0.8437
# Start run 50/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 256, 'units_2': 512, 'units_3': 256, 'units_4': 1024}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4471 - accuracy: 0.8380
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4537 - accuracy: 0.8387
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4359 - accuracy: 0.8532
# Start run 51/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 256, 'units_2': 512, 'units_3': 512, 'units_4': 512}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4271 - accuracy: 0.8493
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4708 - accuracy: 0.8299
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4567 - accuracy: 0.8362
# Start run 52/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 256, 'units_2': 512, 'units_3': 512, 'units_4': 1024}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4457 - accuracy: 0.8342
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4481 - accuracy: 0.8481
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4651 - accuracy: 0.8412
# Start run 53/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 256, 'units_2': 512, 'units_3': 1024, 'units_4': 512}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4530 - accuracy: 0.8398
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4632 - accuracy: 0.8387
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4204 - accuracy: 0.8513
# Start run 54/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.3, 'units_1': 256, 'units_2': 512, 'units_3': 1024, 'units_4': 1024}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4266 - accuracy: 0.8380
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4515 - accuracy: 0.8393
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4316 - accuracy: 0.8513
# Start run 55/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5627 - accuracy: 0.8077
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6814 - accuracy: 0.7744
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6214 - accuracy: 0.7940
# Start run 56/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 1024}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5665 - accuracy: 0.8121
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5859 - accuracy: 0.8097
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5839 - accuracy: 0.8166
# Start run 57/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5627 - accuracy: 0.8083
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5542 - accuracy: 0.8154
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5859 - accuracy: 0.7908
# Start run 58/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 64, 'units_2': 128, 'units_3': 512, 'units_4': 1024}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5810 - accuracy: 0.8235
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5592 - accuracy: 0.8135
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5342 - accuracy: 0.8299
# Start run 59/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 64, 'units_2': 128, 'units_3': 1024, 'units_4': 512}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5719 - accuracy: 0.8071
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5286 - accuracy: 0.8091
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5220 - accuracy: 0.8286
# Start run 60/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 64, 'units_2': 128, 'units_3': 1024, 'units_4': 1024}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5407 - accuracy: 0.8045
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5541 - accuracy: 0.8097
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5388 - accuracy: 0.8204
# Start run 61/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5266 - accuracy: 0.8197
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5624 - accuracy: 0.8097
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5168 - accuracy: 0.8229
# Start run 62/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 64, 'units_2': 256, 'units_3': 256, 'units_4': 1024}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5334 - accuracy: 0.8159
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5389 - accuracy: 0.8021
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5444 - accuracy: 0.8147
# Start run 63/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 64, 'units_2': 256, 'units_3': 512, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5305 - accuracy: 0.8153
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5294 - accuracy: 0.8318
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5125 - accuracy: 0.8273
# Start run 64/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 64, 'units_2': 256, 'units_3': 512, 'units_4': 1024}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5100 - accuracy: 0.8216
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5194 - accuracy: 0.8135
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5331 - accuracy: 0.8217
# Start run 65/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 64, 'units_2': 256, 'units_3': 1024, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5092 - accuracy: 0.8222
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5249 - accuracy: 0.8242
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5236 - accuracy: 0.8204
# Start run 66/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 64, 'units_2': 256, 'units_3': 1024, 'units_4': 1024}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5179 - accuracy: 0.8197
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5141 - accuracy: 0.8192
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5151 - accuracy: 0.8299
# Start run 67/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 64, 'units_2': 512, 'units_3': 256, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5360 - accuracy: 0.8197
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5238 - accuracy: 0.8192
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5011 - accuracy: 0.8217
# Start run 68/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 64, 'units_2': 512, 'units_3': 256, 'units_4': 1024}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5442 - accuracy: 0.8108
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5132 - accuracy: 0.8261
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5159 - accuracy: 0.8255
# Start run 69/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 64, 'units_2': 512, 'units_3': 512, 'units_4': 512}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5058 - accuracy: 0.8140
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5010 - accuracy: 0.8229
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5032 - accuracy: 0.8223
# Start run 70/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 64, 'units_2': 512, 'units_3': 512, 'units_4': 1024}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5090 - accuracy: 0.8291
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5033 - accuracy: 0.8273
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5099 - accuracy: 0.8267
# Start run 71/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 64, 'units_2': 512, 'units_3': 1024, 'units_4': 512}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4948 - accuracy: 0.8361
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5193 - accuracy: 0.8223
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5122 - accuracy: 0.8166
# Start run 72/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 64, 'units_2': 512, 'units_3': 1024, 'units_4': 1024}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5335 - accuracy: 0.8083
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5116 - accuracy: 0.8147
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5047 - accuracy: 0.8223
# Start run 73/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 128, 'units_2': 128, 'units_3': 256, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5344 - accuracy: 0.8140
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5665 - accuracy: 0.8034
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5359 - accuracy: 0.8217
# Start run 74/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 128, 'units_2': 128, 'units_3': 256, 'units_4': 1024}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5346 - accuracy: 0.8153
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5326 - accuracy: 0.8248
# 50/50 [==============================] - 0s 990us/step - loss: 0.5515 - accuracy: 0.8103
# Start run 75/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 128, 'units_2': 128, 'units_3': 512, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5013 - accuracy: 0.8266
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5210 - accuracy: 0.8179
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5035 - accuracy: 0.8261
# Start run 76/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 128, 'units_2': 128, 'units_3': 512, 'units_4': 1024}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5199 - accuracy: 0.8190
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5307 - accuracy: 0.8261
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5075 - accuracy: 0.8267
# Start run 77/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 128, 'units_2': 128, 'units_3': 1024, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5049 - accuracy: 0.8190
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4946 - accuracy: 0.8280
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4878 - accuracy: 0.8343
# Start run 78/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 128, 'units_2': 128, 'units_3': 1024, 'units_4': 1024}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4958 - accuracy: 0.8190
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5031 - accuracy: 0.8242
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4999 - accuracy: 0.8286
# Start run 79/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 128, 'units_2': 256, 'units_3': 256, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5169 - accuracy: 0.8216
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4908 - accuracy: 0.8336
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5076 - accuracy: 0.8299
# Start run 80/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 128, 'units_2': 256, 'units_3': 256, 'units_4': 1024}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4890 - accuracy: 0.8222
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5586 - accuracy: 0.8185
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5376 - accuracy: 0.8286
# Start run 81/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 128, 'units_2': 256, 'units_3': 512, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4803 - accuracy: 0.8298
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4890 - accuracy: 0.8292
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4838 - accuracy: 0.8273
# Start run 82/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 128, 'units_2': 256, 'units_3': 512, 'units_4': 1024}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5014 - accuracy: 0.8247
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4825 - accuracy: 0.8324
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5040 - accuracy: 0.8299
# Start run 83/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 128, 'units_2': 256, 'units_3': 1024, 'units_4': 512}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4887 - accuracy: 0.8222
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4947 - accuracy: 0.8204
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4845 - accuracy: 0.8349
# Start run 84/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 128, 'units_2': 256, 'units_3': 1024, 'units_4': 1024}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4919 - accuracy: 0.8096
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4925 - accuracy: 0.8280
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4821 - accuracy: 0.8349
# Start run 85/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 128, 'units_2': 512, 'units_3': 256, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5348 - accuracy: 0.8134
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5019 - accuracy: 0.8299
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4818 - accuracy: 0.8305
# Start run 86/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 128, 'units_2': 512, 'units_3': 256, 'units_4': 1024}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4853 - accuracy: 0.8279
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4966 - accuracy: 0.8236
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4736 - accuracy: 0.8318
# Start run 87/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 128, 'units_2': 512, 'units_3': 512, 'units_4': 512}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4851 - accuracy: 0.8165
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5121 - accuracy: 0.8204
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4828 - accuracy: 0.8324
# Start run 88/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 128, 'units_2': 512, 'units_3': 512, 'units_4': 1024}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4768 - accuracy: 0.8272
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4981 - accuracy: 0.8242
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4702 - accuracy: 0.8431
# Start run 89/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 128, 'units_2': 512, 'units_3': 1024, 'units_4': 512}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4861 - accuracy: 0.8260
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4878 - accuracy: 0.8355
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4855 - accuracy: 0.8292
# Start run 90/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 128, 'units_2': 512, 'units_3': 1024, 'units_4': 1024}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4575 - accuracy: 0.8317
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4729 - accuracy: 0.8336
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4895 - accuracy: 0.8242
# Start run 91/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 256, 'units_2': 128, 'units_3': 256, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5026 - accuracy: 0.8272
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5294 - accuracy: 0.8223
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4924 - accuracy: 0.8280
# Start run 92/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 256, 'units_2': 128, 'units_3': 256, 'units_4': 1024}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5014 - accuracy: 0.8260
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5026 - accuracy: 0.8229
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4926 - accuracy: 0.8248
# Start run 93/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 256, 'units_2': 128, 'units_3': 512, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4965 - accuracy: 0.8222
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5036 - accuracy: 0.8204
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4809 - accuracy: 0.8387
# Start run 94/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 256, 'units_2': 128, 'units_3': 512, 'units_4': 1024}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5220 - accuracy: 0.8178
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4902 - accuracy: 0.8374
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4835 - accuracy: 0.8362
# Start run 95/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 256, 'units_2': 128, 'units_3': 1024, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4646 - accuracy: 0.8279
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4943 - accuracy: 0.8261
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4742 - accuracy: 0.8343
# Start run 96/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 256, 'units_2': 128, 'units_3': 1024, 'units_4': 1024}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4972 - accuracy: 0.8222
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4885 - accuracy: 0.8192
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5391 - accuracy: 0.8248
# Start run 97/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 256, 'units_2': 256, 'units_3': 256, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5003 - accuracy: 0.8190
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4823 - accuracy: 0.8229
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4619 - accuracy: 0.8431
# Start run 98/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 256, 'units_2': 256, 'units_3': 256, 'units_4': 1024}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5052 - accuracy: 0.8235
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4851 - accuracy: 0.8349
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5012 - accuracy: 0.8336
# Start run 99/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 256, 'units_2': 256, 'units_3': 512, 'units_4': 512}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4751 - accuracy: 0.8304
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4844 - accuracy: 0.8324
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4776 - accuracy: 0.8330
# Start run 100/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 256, 'units_2': 256, 'units_3': 512, 'units_4': 1024}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4859 - accuracy: 0.8222
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5119 - accuracy: 0.8192
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4756 - accuracy: 0.8311
# Start run 101/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 256, 'units_2': 256, 'units_3': 1024, 'units_4': 512}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4633 - accuracy: 0.8323
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5041 - accuracy: 0.8204
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4710 - accuracy: 0.8311
# Start run 102/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 256, 'units_2': 256, 'units_3': 1024, 'units_4': 1024}
# 50/50 [==============================] - 0s 3ms/step - loss: 0.4654 - accuracy: 0.8260
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5011 - accuracy: 0.8292
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4809 - accuracy: 0.8393
# Start run 103/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 256, 'units_2': 512, 'units_3': 256, 'units_4': 512}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4940 - accuracy: 0.8235
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4868 - accuracy: 0.8318
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4560 - accuracy: 0.8425
# Start run 104/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 256, 'units_2': 512, 'units_3': 256, 'units_4': 1024}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4670 - accuracy: 0.8260
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4753 - accuracy: 0.8286
# 50/50 [==============================] - 0s 1ms/step - loss: 0.4609 - accuracy: 0.8425
# Start run 105/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 256, 'units_2': 512, 'units_3': 512, 'units_4': 512}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4594 - accuracy: 0.8279
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4674 - accuracy: 0.8418
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4598 - accuracy: 0.8431
# Start run 106/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 256, 'units_2': 512, 'units_3': 512, 'units_4': 1024}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4585 - accuracy: 0.8398
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4677 - accuracy: 0.8374
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4659 - accuracy: 0.8393
# Start run 107/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 256, 'units_2': 512, 'units_3': 1024, 'units_4': 512}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4766 - accuracy: 0.8260
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4620 - accuracy: 0.8368
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4468 - accuracy: 0.8425
# Start run 108/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.5, 'units_1': 256, 'units_2': 512, 'units_3': 1024, 'units_4': 1024}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4666 - accuracy: 0.8222
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4865 - accuracy: 0.8381
# 50/50 [==============================] - 0s 2ms/step - loss: 0.4663 - accuracy: 0.8387
# Start run 109/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 512}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.8482 - accuracy: 0.7617
# 50/50 [==============================] - 0s 1ms/step - loss: 0.8246 - accuracy: 0.7650
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7880 - accuracy: 0.7845
# Start run 110/324: Parameters: {'num_hidden_layers': 2, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 64, 'units_2': 128, 'units_3': 256, 'units_4': 1024}
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7396 - accuracy: 0.7825
# ...
# 50/50 [==============================] - 0s 5ms/step - loss: 0.9091 - accuracy: 0.7606
# 50/50 [==============================] - 0s 6ms/step - loss: 0.6606 - accuracy: 0.8003
# Start run 289/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 128, 'units_2': 128, 'units_3': 256, 'units_4': 512}
# 50/50 [==============================] - 0s 3ms/step - loss: 0.8854 - accuracy: 0.7831
# 50/50 [==============================] - 0s 4ms/step - loss: 0.8680 - accuracy: 0.7832
# 50/50 [==============================] - 0s 3ms/step - loss: 0.8452 - accuracy: 0.7687
# Start run 290/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 128, 'units_2': 128, 'units_3': 256, 'units_4': 1024}
# 50/50 [==============================] - 0s 4ms/step - loss: 0.7952 - accuracy: 0.7825
# 50/50 [==============================] - 0s 4ms/step - loss: 0.7993 - accuracy: 0.7750
# 50/50 [==============================] - 0s 4ms/step - loss: 0.8476 - accuracy: 0.7889
# Start run 291/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 128, 'units_2': 128, 'units_3': 512, 'units_4': 512}
# 50/50 [==============================] - 0s 4ms/step - loss: 0.8191 - accuracy: 0.7926
# 50/50 [==============================] - 0s 4ms/step - loss: 0.9520 - accuracy: 0.7624
# 50/50 [==============================] - 0s 4ms/step - loss: 0.7849 - accuracy: 0.8040
# Start run 292/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 128, 'units_2': 128, 'units_3': 512, 'units_4': 1024}
# 50/50 [==============================] - 1s 5ms/step - loss: 0.7209 - accuracy: 0.7938
# 50/50 [==============================] - 1s 6ms/step - loss: 0.9645 - accuracy: 0.7643
# 50/50 [==============================] - 0s 4ms/step - loss: 0.7701 - accuracy: 0.8034
# Start run 293/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 128, 'units_2': 128, 'units_3': 1024, 'units_4': 512}
# 50/50 [==============================] - 1s 4ms/step - loss: 0.7205 - accuracy: 0.7963
# 50/50 [==============================] - 1s 5ms/step - loss: 0.7668 - accuracy: 0.7908
# 50/50 [==============================] - 1s 6ms/step - loss: 0.7364 - accuracy: 0.7946
# Start run 294/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 128, 'units_2': 128, 'units_3': 1024, 'units_4': 1024}
# 50/50 [==============================] - 1s 5ms/step - loss: 0.7441 - accuracy: 0.8001
# 50/50 [==============================] - 0s 5ms/step - loss: 0.7142 - accuracy: 0.7921
# 50/50 [==============================] - 0s 5ms/step - loss: 0.7165 - accuracy: 0.8003
# Start run 295/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 128, 'units_2': 256, 'units_3': 256, 'units_4': 512}
# 50/50 [==============================] - 0s 3ms/step - loss: 0.8383 - accuracy: 0.7844
# 50/50 [==============================] - 0s 3ms/step - loss: 0.8290 - accuracy: 0.7914
# 50/50 [==============================] - 0s 3ms/step - loss: 0.8077 - accuracy: 0.7744
# Start run 296/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 128, 'units_2': 256, 'units_3': 256, 'units_4': 1024}
# 50/50 [==============================] - 0s 3ms/step - loss: 0.7617 - accuracy: 0.7793
# 50/50 [==============================] - 0s 4ms/step - loss: 0.8348 - accuracy: 0.7977
# 50/50 [==============================] - 0s 4ms/step - loss: 0.8610 - accuracy: 0.7908
# Start run 297/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 128, 'units_2': 256, 'units_3': 512, 'units_4': 512}
# 50/50 [==============================] - 0s 4ms/step - loss: 0.7316 - accuracy: 0.7869
# 50/50 [==============================] - 0s 4ms/step - loss: 0.7329 - accuracy: 0.7984
# 50/50 [==============================] - 0s 5ms/step - loss: 0.7110 - accuracy: 0.8110
# Start run 298/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 128, 'units_2': 256, 'units_3': 512, 'units_4': 1024}
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6805 - accuracy: 0.7907
# 50/50 [==============================] - 0s 4ms/step - loss: 0.9033 - accuracy: 0.7914
# 50/50 [==============================] - 0s 5ms/step - loss: 0.7141 - accuracy: 0.8072
# Start run 299/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 128, 'units_2': 256, 'units_3': 1024, 'units_4': 512}
# 50/50 [==============================] - 0s 5ms/step - loss: 0.8774 - accuracy: 0.7825
# 50/50 [==============================] - 1s 6ms/step - loss: 0.7003 - accuracy: 0.7971
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6620 - accuracy: 0.8103
# Start run 300/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 128, 'units_2': 256, 'units_3': 1024, 'units_4': 1024}
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6603 - accuracy: 0.8014
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6985 - accuracy: 0.7858
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6978 - accuracy: 0.7908
# Start run 301/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 128, 'units_2': 512, 'units_3': 256, 'units_4': 512}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.8272 - accuracy: 0.7869
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7334 - accuracy: 0.7908
# 50/50 [==============================] - 0s 2ms/step - loss: 0.8044 - accuracy: 0.8122
# Start run 302/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 128, 'units_2': 512, 'units_3': 256, 'units_4': 1024}
# 50/50 [==============================] - 1s 4ms/step - loss: 0.7264 - accuracy: 0.8039
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6861 - accuracy: 0.7883
# 50/50 [==============================] - 0s 4ms/step - loss: 0.9209 - accuracy: 0.7832
# Start run 303/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 128, 'units_2': 512, 'units_3': 512, 'units_4': 512}
# 50/50 [==============================] - 1s 5ms/step - loss: 0.6883 - accuracy: 0.7799
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6643 - accuracy: 0.7858
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6214 - accuracy: 0.8141
# Start run 304/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 128, 'units_2': 512, 'units_3': 512, 'units_4': 1024}
# 50/50 [==============================] - 1s 6ms/step - loss: 0.6984 - accuracy: 0.7869
# 50/50 [==============================] - 0s 4ms/step - loss: 0.9223 - accuracy: 0.7744
# 50/50 [==============================] - 1s 7ms/step - loss: 0.9027 - accuracy: 0.8122
# Start run 305/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 128, 'units_2': 512, 'units_3': 1024, 'units_4': 512}
# 50/50 [==============================] - 1s 5ms/step - loss: 0.5856 - accuracy: 0.8108
# 50/50 [==============================] - 1s 9ms/step - loss: 0.6181 - accuracy: 0.7990
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6497 - accuracy: 0.8091
# Start run 306/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 128, 'units_2': 512, 'units_3': 1024, 'units_4': 1024}
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6321 - accuracy: 0.8020
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6722 - accuracy: 0.7977
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6250 - accuracy: 0.8066
# Start run 307/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 256, 'units_2': 128, 'units_3': 256, 'units_4': 512}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.8033 - accuracy: 0.7856
# 50/50 [==============================] - 0s 2ms/step - loss: 0.9282 - accuracy: 0.7782
# 50/50 [==============================] - 0s 2ms/step - loss: 0.9043 - accuracy: 0.7776
# Start run 308/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 256, 'units_2': 128, 'units_3': 256, 'units_4': 1024}
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7111 - accuracy: 0.7989
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6986 - accuracy: 0.8040
# 50/50 [==============================] - 0s 2ms/step - loss: 0.9131 - accuracy: 0.7757
# Start run 309/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 256, 'units_2': 128, 'units_3': 512, 'units_4': 512}
# 50/50 [==============================] - 0s 3ms/step - loss: 0.8141 - accuracy: 0.7894
# 50/50 [==============================] - 0s 3ms/step - loss: 0.8496 - accuracy: 0.7902
# 50/50 [==============================] - 0s 3ms/step - loss: 0.7666 - accuracy: 0.7977
# Start run 310/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 256, 'units_2': 128, 'units_3': 512, 'units_4': 1024}
# 50/50 [==============================] - 0s 3ms/step - loss: 0.9151 - accuracy: 0.7875
# 50/50 [==============================] - 0s 2ms/step - loss: 0.8177 - accuracy: 0.7738
# 50/50 [==============================] - 0s 2ms/step - loss: 0.8249 - accuracy: 0.8072
# Start run 311/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 256, 'units_2': 128, 'units_3': 1024, 'units_4': 512}
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6616 - accuracy: 0.7844
# 50/50 [==============================] - 1s 5ms/step - loss: 0.8670 - accuracy: 0.7858
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6721 - accuracy: 0.8078
# Start run 312/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 256, 'units_2': 128, 'units_3': 1024, 'units_4': 1024}
# 50/50 [==============================] - 1s 5ms/step - loss: 0.6321 - accuracy: 0.8083
# 50/50 [==============================] - 1s 6ms/step - loss: 0.6228 - accuracy: 0.8166
# 50/50 [==============================] - 1s 5ms/step - loss: 0.6458 - accuracy: 0.8129
# Start run 313/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 256, 'units_2': 256, 'units_3': 256, 'units_4': 512}
# 50/50 [==============================] - 0s 4ms/step - loss: 0.7395 - accuracy: 0.8045
# 50/50 [==============================] - 0s 3ms/step - loss: 0.8986 - accuracy: 0.7813
# 50/50 [==============================] - 0s 3ms/step - loss: 0.7470 - accuracy: 0.8034
# Start run 314/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 256, 'units_2': 256, 'units_3': 256, 'units_4': 1024}
# 50/50 [==============================] - 0s 4ms/step - loss: 0.8789 - accuracy: 0.7699
# 50/50 [==============================] - 0s 4ms/step - loss: 0.8970 - accuracy: 0.7946
# 50/50 [==============================] - 1s 5ms/step - loss: 0.6708 - accuracy: 0.8003
# Start run 315/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 256, 'units_2': 256, 'units_3': 512, 'units_4': 512}
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6969 - accuracy: 0.7938
# 50/50 [==============================] - 0s 4ms/step - loss: 0.7820 - accuracy: 0.7996
# 50/50 [==============================] - 0s 4ms/step - loss: 0.7989 - accuracy: 0.8053
# Start run 316/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 256, 'units_2': 256, 'units_3': 512, 'units_4': 1024}
# 50/50 [==============================] - 0s 5ms/step - loss: 0.9091 - accuracy: 0.7894
# 50/50 [==============================] - 0s 4ms/step - loss: 0.7277 - accuracy: 0.7908
# 50/50 [==============================] - 1s 5ms/step - loss: 0.6861 - accuracy: 0.8047
# Start run 317/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 256, 'units_2': 256, 'units_3': 1024, 'units_4': 512}
# 50/50 [==============================] - 1s 5ms/step - loss: 0.6741 - accuracy: 0.8052
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6047 - accuracy: 0.8147
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6176 - accuracy: 0.8129
# Start run 318/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 256, 'units_2': 256, 'units_3': 1024, 'units_4': 1024}
# 50/50 [==============================] - 1s 7ms/step - loss: 0.6253 - accuracy: 0.8058
# 50/50 [==============================] - 1s 6ms/step - loss: 0.8559 - accuracy: 0.7996
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6345 - accuracy: 0.8091
# Start run 319/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 256, 'units_2': 512, 'units_3': 256, 'units_4': 512}
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6462 - accuracy: 0.8083
# 50/50 [==============================] - 0s 4ms/step - loss: 0.8307 - accuracy: 0.8053
# 50/50 [==============================] - 1s 5ms/step - loss: 0.7045 - accuracy: 0.8116
# Start run 320/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 256, 'units_2': 512, 'units_3': 256, 'units_4': 1024}
# 50/50 [==============================] - 1s 5ms/step - loss: 0.6165 - accuracy: 0.7957
# 50/50 [==============================] - 1s 6ms/step - loss: 0.8716 - accuracy: 0.7940
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6134 - accuracy: 0.8166
# Start run 321/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 256, 'units_2': 512, 'units_3': 512, 'units_4': 512}
# 50/50 [==============================] - 0s 3ms/step - loss: 0.7203 - accuracy: 0.7963
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7919 - accuracy: 0.7870
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7486 - accuracy: 0.8021
# Start run 322/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 256, 'units_2': 512, 'units_3': 512, 'units_4': 1024}
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6880 - accuracy: 0.7831
# 50/50 [==============================] - 0s 3ms/step - loss: 0.8304 - accuracy: 0.7952
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6464 - accuracy: 0.7908
# Start run 323/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 256, 'units_2': 512, 'units_3': 1024, 'units_4': 512}
# 50/50 [==============================] - 0s 3ms/step - loss: 0.5854 - accuracy: 0.7951
# 50/50 [==============================] - 0s 3ms/step - loss: 0.8205 - accuracy: 0.7933
# 50/50 [==============================] - 0s 3ms/step - loss: 0.5949 - accuracy: 0.8053
# Start run 324/324: Parameters: {'num_hidden_layers': 3, 'activation_function': 'LeakyReLU', 'dropout_rate': 0.7, 'units_1': 256, 'units_2': 512, 'units_3': 1024, 'units_4': 1024}
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6459 - accuracy: 0.7919
# 50/50 [==============================] - 0s 3ms/step - loss: 0.9023 - accuracy: 0.7782
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6213 - accuracy: 0.8078

# %%
resultsDF = pd.DataFrame(search_results)
resultsDF['delta_acc'] = (resultsDF['best_train_accuracy']-resultsDF['best_val_accuracy'])/resultsDF['best_val_accuracy']
resultsDF.to_csv('../data/optimization_results20.csv', index=False)
resultsDF = pd.read_csv('../data/optimization_results20.csv')
resultsDF.head()
# Out:
#    num_hidden_layers activation_function  dropout_rate  units_1  units_2
# 0                  2           LeakyReLU           0.3       64      128  \
# 1                  2           LeakyReLU           0.3       64      128
# 2                  2           LeakyReLU           0.3       64      128
# 3                  2           LeakyReLU           0.3       64      128
# 4                  2           LeakyReLU           0.3       64      128
#
#    units_3  units_4  best_val_accuracy  val_accuracy_std  best_val_loss
# 0      256      512           0.809241          0.005365       0.559204  \
# 1      256     1024           0.817645          0.003712       0.525376
# 2      512      512           0.827727          0.008641       0.528510
# 3      512     1024           0.824789          0.005750       0.513748
# 4     1024      512           0.823946          0.006131       0.524987
#
#    val_loss_std  best_train_accuracy  train_accuracy_std  best_train_loss
# 0      0.024527             0.817857            0.007203         0.530517  \
# 1      0.005760             0.822687            0.007639         0.506629
# 2      0.022255             0.822900            0.010984         0.503371
# 3      0.007285             0.824160            0.000052         0.495238
# 4      0.024635             0.820800            0.005406         0.507656
#
#    train_loss_std  delta_acc
# 0        0.028804   0.010647
# 1        0.011577   0.006166
# 2        0.025750  -0.005832
# 3        0.006395  -0.000763
# 4        0.018378  -0.003818

# %%
import seaborn as sns
import numpy as np

# Mapping der activation_function auf numerische Werte
activation_mapping = {'relu': 0, 'LeakyReLU': 1}
resultsDF['activation_numerical'] = resultsDF['activation_function'].map(activation_mapping)

x_vars = [
    'num_hidden_layers',
    'units_1',
    'units_2',
    'units_3',
    'units_4',
    'dropout_rate',
    'activation_numerical'
]

y_vars = [
    'best_val_accuracy',
    'best_train_accuracy',
    'delta_acc'
]

sns.pairplot(resultsDF, x_vars=x_vars, y_vars=y_vars, kind='reg', height=2)

# %%
def calculate_score(row):
    # Bestmöglicher Score ist 
    best_score = 1.0
    
    # Berechnung des Scores basierend auf Delta-Accuracy und Best Validation Accuracy
    delta_acc_score = 1.0 - abs(row['delta_acc'])  # Je kleiner das Delta, desto besser der Score
    best_val_acc_score = row['best_val_accuracy']  # Je größer die Best Validation Accuracy, desto besser der Score
    
    #Gewichte
    w1=0.1
    w2=1
    
    # Gesamtscore berechnen
    score = (w1 * delta_acc_score + w2 * best_val_acc_score) / 2
    
    # Normalisierung des Scores auf den Bereich [0, 1]
    normalized_score = score / best_score
    
    return normalized_score

# Score-Spalte hinzufügen
resultsDF['score'] = resultsDF.apply(calculate_score, axis=1)
resultsDF = resultsDF.sort_values('score', ascending=False)
resultsDF.head()
# Out:
#      num_hidden_layers activation_function  dropout_rate  units_1  units_2
# 215                  3           LeakyReLU           0.3      256      512  \
# 183                  3           LeakyReLU           0.3      128      128
# 26                   2           LeakyReLU           0.3      128      256
# 49                   2           LeakyReLU           0.3      256      512
# 198                  3           LeakyReLU           0.3      256      128
#
#      units_3  units_4  best_val_accuracy  val_accuracy_std  best_val_loss
# 215     1024     1024           0.834454          0.001594       0.490642  \
# 183      512     1024           0.833189          0.007807       0.500976
# 26       512      512           0.833189          0.008342       0.495286
# 49       256     1024           0.833607          0.010790       0.493860
# 198      256      512           0.831087          0.009524       0.504763
#
#      val_loss_std  best_train_accuracy  train_accuracy_std  best_train_loss
# 215      0.031226             0.844955            0.011542         0.432115  \
# 183      0.010392             0.830042            0.001918         0.478649
# 26       0.007002             0.837185            0.003326         0.460381
# 49       0.013121             0.843276            0.007011         0.445558
# 198      0.016367             0.832983            0.004041         0.466115
#
#      train_loss_std  delta_acc  activation_numerical     score
# 215        0.031568   0.012584                     1  0.466598
# 183        0.008216  -0.003777                     1  0.466406
# 26         0.002794   0.004796                     1  0.466355
# 49         0.007351   0.011599                     1  0.466224
# 198        0.007149   0.002281                     1  0.465430

# %%
best_params = resultsDF.head(1)

# Scatterplot erstellen
sns.scatterplot(data=resultsDF, x='best_val_accuracy', y='delta_acc', alpha=0.5)
sns.scatterplot(data=best_result, x='best_val_accuracy', y='delta_acc', color='red')

# Achsentitel hinzufügen
plt.xlabel('best_val_accuracy')
plt.ylabel('delta_acc')

# Plot anzeigen
plt.show()

# %% [markdown]
# ## hier das hoffentlich beste Modell

# %%
best_params = resultsDF.iloc[1]
best_model = build_model_from_params(best_params)
model.summary()
# Out:
# Model: "sequential_1033"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5142 (Dense)          (None, 256)               5120
#
#  dropout_4114 (Dropout)      (None, 256)               0
#
#  dense_5143 (Dense)          (None, 128)               32896
#
#  dropout_4115 (Dropout)      (None, 128)               0
#
#  dense_5144 (Dense)          (None, 256)               33024
#
#  dropout_4116 (Dropout)      (None, 256)               0
#
#  dense_5145 (Dense)          (None, 512)               131584
#
#  dropout_4117 (Dropout)      (None, 512)               0
#
#  dense_5146 (Dense)          (None, 4)                 2052
#
# =================================================================
# Total params: 204,676
# Trainable params: 204,676
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = Sequential()
model.add(Dense(units=256, activation='LeakyReLU', input_dim=X_train.shape[1]))
model.add(Dropout(0.3))
model.add(Dense(units=512, activation='LeakyReLU'))
model.add(Dropout(0.3))
model.add(Dense(units=1024, activation='LeakyReLU'))
model.add(Dropout(0.3))
model.add(Dense(units=1024, activation='LeakyReLU'))
model.add(Dropout(0.3))
model.add(Dense(units=num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'], jit_compile=False)

# %%
batch_size = 512
nb_epoch = 300

# Definiere die Early Stopping-Bedingungen
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min', restore_best_weights=True)

# Definiere die Reduzierung der Lernrate, falls die Verbesserung stagniert
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, mode='min', min_lr=1e-7)

hist = model.fit(X_train, Y_train, validation_data=(X_val, Y_val), 
                 epochs=nb_epoch, batch_size=batch_size, callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/300
# 5/5 [==============================] - 2s 101ms/step - loss: 0.9535 - accuracy: 0.5866 - val_loss: 0.5932 - val_accuracy: 0.7922 - lr: 0.0010
# Epoch 2/300
# 5/5 [==============================] - 0s 62ms/step - loss: 0.5722 - accuracy: 0.7912 - val_loss: 0.5478 - val_accuracy: 0.8186 - lr: 0.0010
# Epoch 3/300
# 5/5 [==============================] - 0s 62ms/step - loss: 0.5398 - accuracy: 0.8088 - val_loss: 0.5149 - val_accuracy: 0.8216 - lr: 0.0010
# Epoch 4/300
# 5/5 [==============================] - 0s 61ms/step - loss: 0.5135 - accuracy: 0.8134 - val_loss: 0.5163 - val_accuracy: 0.8127 - lr: 0.0010
# Epoch 5/300
# 5/5 [==============================] - 0s 63ms/step - loss: 0.4936 - accuracy: 0.8172 - val_loss: 0.4944 - val_accuracy: 0.8324 - lr: 0.0010
# Epoch 6/300
# 5/5 [==============================] - 0s 66ms/step - loss: 0.4693 - accuracy: 0.8252 - val_loss: 0.5093 - val_accuracy: 0.8167 - lr: 0.0010
# Epoch 7/300
# 5/5 [==============================] - 0s 74ms/step - loss: 0.4653 - accuracy: 0.8328 - val_loss: 0.4961 - val_accuracy: 0.8343 - lr: 0.0010
# Epoch 8/300
# 5/5 [==============================] - 0s 67ms/step - loss: 0.4680 - accuracy: 0.8294 - val_loss: 0.4937 - val_accuracy: 0.8255 - lr: 0.0010
# Epoch 9/300
# 5/5 [==============================] - 0s 76ms/step - loss: 0.4609 - accuracy: 0.8315 - val_loss: 0.4805 - val_accuracy: 0.8324 - lr: 0.0010
# Epoch 10/300
# 5/5 [==============================] - 0s 76ms/step - loss: 0.4340 - accuracy: 0.8420 - val_loss: 0.4855 - val_accuracy: 0.8275 - lr: 0.0010
# Epoch 11/300
# 5/5 [==============================] - 0s 64ms/step - loss: 0.4379 - accuracy: 0.8349 - val_loss: 0.4890 - val_accuracy: 0.8314 - lr: 0.0010
# Epoch 12/300
# 5/5 [==============================] - 0s 62ms/step - loss: 0.4305 - accuracy: 0.8420 - val_loss: 0.4812 - val_accuracy: 0.8373 - lr: 0.0010
# Epoch 13/300
# 5/5 [==============================] - 0s 67ms/step - loss: 0.4307 - accuracy: 0.8319 - val_loss: 0.4928 - val_accuracy: 0.8186 - lr: 0.0010
# Epoch 14/300
# 5/5 [==============================] - 0s 78ms/step - loss: 0.4270 - accuracy: 0.8357 - val_loss: 0.4836 - val_accuracy: 0.8353 - lr: 0.0010
# Epoch 15/300
# 5/5 [==============================] - 0s 65ms/step - loss: 0.4303 - accuracy: 0.8336 - val_loss: 0.4757 - val_accuracy: 0.8373 - lr: 0.0010
# Epoch 16/300
# 5/5 [==============================] - 0s 62ms/step - loss: 0.4152 - accuracy: 0.8433 - val_loss: 0.4936 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 17/300
# 5/5 [==============================] - 0s 67ms/step - loss: 0.4130 - accuracy: 0.8403 - val_loss: 0.4774 - val_accuracy: 0.8412 - lr: 0.0010
# Epoch 18/300
# 5/5 [==============================] - 0s 63ms/step - loss: 0.4120 - accuracy: 0.8408 - val_loss: 0.5066 - val_accuracy: 0.8157 - lr: 0.0010
# Epoch 19/300
# 5/5 [==============================] - 0s 64ms/step - loss: 0.4049 - accuracy: 0.8466 - val_loss: 0.4732 - val_accuracy: 0.8431 - lr: 0.0010
# Epoch 20/300
# 5/5 [==============================] - 0s 62ms/step - loss: 0.4070 - accuracy: 0.8479 - val_loss: 0.4998 - val_accuracy: 0.8324 - lr: 0.0010
# Epoch 21/300
# 5/5 [==============================] - 0s 61ms/step - loss: 0.3992 - accuracy: 0.8479 - val_loss: 0.4883 - val_accuracy: 0.8382 - lr: 0.0010
# Epoch 22/300
# 5/5 [==============================] - 0s 62ms/step - loss: 0.3837 - accuracy: 0.8605 - val_loss: 0.4821 - val_accuracy: 0.8353 - lr: 0.0010
# Epoch 23/300
# 5/5 [==============================] - 0s 61ms/step - loss: 0.3833 - accuracy: 0.8563 - val_loss: 0.5058 - val_accuracy: 0.8353 - lr: 0.0010
# Epoch 24/300
# 5/5 [==============================] - 0s 62ms/step - loss: 0.3940 - accuracy: 0.8475 - val_loss: 0.5059 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 25/300
# 5/5 [==============================] - 0s 62ms/step - loss: 0.3750 - accuracy: 0.8542 - val_loss: 0.4888 - val_accuracy: 0.8333 - lr: 0.0010
# Epoch 26/300
# 5/5 [==============================] - 0s 61ms/step - loss: 0.4089 - accuracy: 0.8395 - val_loss: 0.4944 - val_accuracy: 0.8255 - lr: 0.0010
# Epoch 27/300
# 5/5 [==============================] - 0s 63ms/step - loss: 0.3836 - accuracy: 0.8513 - val_loss: 0.4889 - val_accuracy: 0.8422 - lr: 0.0010
# Epoch 28/300
# 5/5 [==============================] - 0s 62ms/step - loss: 0.3703 - accuracy: 0.8630 - val_loss: 0.4922 - val_accuracy: 0.8382 - lr: 0.0010
# Epoch 29/300
# 5/5 [==============================] - 0s 63ms/step - loss: 0.3748 - accuracy: 0.8613 - val_loss: 0.4997 - val_accuracy: 0.8294 - lr: 0.0010

# %%
plot_history(hist)

# %%
Y_pred = model.predict(X_test)
# Out:
# 46/46 [==============================] - 0s 3ms/step

# %%
Y_pred_classes = np.argmax(Y_pred, axis=1)

for i in range(len(Y_pred_classes)):
    if label[Y_pred_classes[i]] == 'pop' and Y_pred[i, Y_pred_classes[i]] > 0.9:
        # Finde den Index des zweithöchsten Werts
        second_highest_index = np.argsort(Y_pred[i])[-2]
        Y_pred_classes[i] = second_highest_index
Y_test_classes = np.argmax(Y_test, axis=1)

cm = confusion_matrix(Y_test_classes, Y_pred_classes, normalize='true')
plt.figure(figsize=(20,20))
sns.heatmap(cm, annot=True, xticklabels=label, yticklabels=label)
plt.xlabel('Vorhergesagtes Genre')
plt.ylabel('Tatsächliches Genre')
plt.savefig('../figures/confusion_matrix.png')
plt.show()

# %%
Y_prob = Y_pred

if isinstance(Y_test, pd.DataFrame):
    Y_test = Y_test.values
if isinstance(Y_prob, pd.DataFrame):
    Y_prob = Y_prob.values

precision, recall, thresholds = precision_recall_curve(Y_test.ravel(), Y_prob.ravel())


# Berechne Precision, Recall und Schwellenwerte
precision, recall, thresholds = precision_recall_curve(Y_test.ravel(), Y_prob.ravel())

# Berechne den AUC-PR
auc_pr = auc(recall, precision)

plt.plot(recall, precision, label=f"AUC-PR = {auc_pr:.3}")
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend()
plt.title('Precision-Recall Curve')
plt.show()

# %%
# Precision Recall Curve für jede Klasse einzeln

n_classes = Y_test.shape[1]

if isinstance(Y_test, np.ndarray):
    Y_test = pd.DataFrame(Y_test)
if isinstance(Y_pred, np.ndarray):
    Y_pred = pd.DataFrame(Y_pred)

auc_pr_values = []

# Für jede Klasse
for i in range(n_classes):
    precision, recall, _ = precision_recall_curve(Y_test.iloc[:, i], Y_pred.iloc[:, i])

    # Berechne den AUC-PR
    auc_pr = auc(recall, precision)
    auc_pr_values.append((label[i], auc_pr))

    plt.plot(
        recall,
        precision,
        label=f"{label[i]}, AUC-PR = {auc_pr:.3}",
    )

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.legend()
plt.title("Precision-Recall Curve")

# Genres nach AUC-PR-Wert sortieren
auc_pr_values_sorted = sorted(auc_pr_values, key=lambda x: x[1], reverse=True)

# Ausgabe der Genres und AUC-PR-Werte
for genre, auc_pr in auc_pr_values_sorted:
    print(f"{genre}: AUC-PR = {auc_pr:.3}")
# Out:
# hip hop: AUC-PR = 0.94
# classic: AUC-PR = 0.911
# rock: AUC-PR = 0.867
# metal: AUC-PR = 0.717
