# %% [markdown]
# # Notiz für Henry:
# diese Datei ist dafür da das Neuronale Netz zu entwickeln. In einem Notebook kann man schneller Hyperparameter ändern und einfacher weitere kleine Änderungen vornehmen. Wenn das Gröbste steht können wir das Notebook einfach als .py Datei exportieren und sind happy

# %% [markdown]
# ## Importieren der wichtigsten Pakete

# %%
import csv
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
from sklearn.utils.class_weight import compute_class_weight
import pandas as pd

# %%
# GPU Test
import tensorflow as tf

# Funktioniert momentan bei mir immernoch nicht
#if tf.test.is_gpu_available():
#   print("GPU is available")
#   print("GPU(s) that Tensorflow recognizes:", tf.config.list_physical_devices('GPU'))
#else:
#   print("GPU not available")
# Manuell auf CPU einschränken
tf.config.set_visible_devices([], 'GPU')

# %% [markdown]
# ## Sinnvolle Funktionen

# %%
################################################################################################### 
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_history(network_history):
    plt.figure()
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.plot(network_history.history['loss'])
    plt.plot(network_history.history['val_loss'])
    plt.legend(['Training', 'Validation'])

    plt.figure()
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.plot(network_history.history['accuracy'])
    plt.plot(network_history.history['val_accuracy'])
    plt.legend(['Training', 'Validation'], loc='lower right')
    plt.show()
    
###################################################################################################    

import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        value = f'{cm[i, j]:.3f}'  # Runde den Wert auf 3 Dezimalstellen
        plt.text(j, i, value,
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
################################################################################################### 
import matplotlib.cm as cm
def display_errors(errors_index,img_errors,pred_errors, obs_errors):
    """ This function shows 6 images with their predicted and real labels"""
    n = 0
    nrows = 2
    ncols = 3
    fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True)
    for row in range(nrows):
        for col in range(ncols):
            error = errors_index[n]
            ax[row,col].imshow((img_errors[n]).reshape((28,28)), cmap=cm.Greys, interpolation='nearest')
            ax[row,col].set_title("Predicted label :{}\nTrue label :{}".format(pred_errors[n],obs_errors[n]))
            n += 1
            
###################################################################################################

# %%
def evaluate(X_test, Y_test):
    # Make predictions on test data
    Y_pred = model.predict(X_test)
    # Calculate loss and accuracy
    loss, accuracy = model.evaluate(X_test, Y_test, verbose=0)
    print(f"loss:     {loss:.3}")
    print(f"accuracy: {accuracy:.3}")

    # Compute the classification report
    report = classification_report(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))
    print(report)
    
    # Plot probability of being zero for true !genre! and non-!genre!
    true_genre = np.where(np.argmax(Y_test, axis=1) == 0)[0]
    true_non_genre = np.where(np.argmax(Y_test, axis=1) != 0)[0]
    
    plt.figure()
    plt.hist(Y_pred[true_genre, 0], bins=50, color='red', label='True !genre!', alpha=0.5)
    plt.hist(Y_pred[true_non_genre, 0], bins=50, color='blue', label='True Non-!genre!', alpha=0.5)
    plt.xlabel('Probability of !hier genre einfügen!')
    plt.ylabel('Frequency')
    plt.yscale('log')
    plt.legend()

    # Compute the confusion matrix
    confusion_mtx = confusion_matrix(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))
    # Plot the confusion matrix
    plt.figure(figsize=(10, 10))
    plot_confusion_matrix(confusion_mtx, classes=range(10), normalize='true')

# %% [markdown]
# ## Laden der Daten
# Am besten wir fügen das Genre in einer separaten Datei dem Datensatz hinzu und machen ab hier nur mit dem fertigen Datensatz weiter

# %% [markdown]
# ## Convert target

# %%
csv_file = "../data/data_selected.csv"

df = pd.read_csv(csv_file)
df.columns
# Out:
# Index(['Unnamed: 0', 'Danceability', 'Energy', 'Key', 'Loudness',
#        'Speechiness', 'Acousticness', 'Instrumentalness', 'Liveness',
#        'Valence', 'Tempo', 'Duration_ms', 'Views', 'Likes', 'Comments',
#        'Stream', 'Genre'],
#       dtype='object')

# %%
features_drop = ['Genre', 'Unnamed: 0']
X = df.drop(features_drop, axis=1)
Y = df['Genre']

# %%
# One-Hot-Encoding durchführen
Y = pd.get_dummies(Y)

# label um One-Hot-Encoding hinterher wieder zu übersetzen
genre_mapping = Y.columns
label = []
for index, genre in enumerate(genre_mapping):
    label.append(genre)
    print("Genre", index, ":", genre)
# Out:
# Genre 0 : R&B
# Genre 1 : afrobeats
# Genre 2 : alternative rock
# Genre 3 : blues
# Genre 4 : christian
# Genre 5 : christmas
# Genre 6 : classic
# Genre 7 : country
# Genre 8 : cumbia
# Genre 9 : disco
# Genre 10 : electronic
# Genre 11 : film score
# Genre 12 : folk
# Genre 13 : funk
# Genre 14 : hip hop
# Genre 15 : jazz
# Genre 16 : latin
# Genre 17 : metal
# Genre 18 : mexican
# Genre 19 : minimalist music
# Genre 20 : new wave
# Genre 21 : opera
# Genre 22 : pagode
# Genre 23 : reggae
# Genre 24 : reggaeton
# Genre 25 : rock
# Genre 26 : sertanejo
# Genre 27 : soul

# %% [markdown]
# ## Splitten von Training und Test Datensätzen

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
X_train, X_val,  Y_train, Y_val  = train_test_split(X_train, Y_train, test_size=0.3, random_state=42)

# %% [markdown]
# ## Daten skalieren

# %%
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Gewichte berechnen um Überrepräsentation zu vermeiden

# %%
from sklearn.utils.class_weight import compute_class_weight

num_classes = len(Y.value_counts())
class_counts = np.sum(Y_train, axis=0)
total_samples = np.sum(class_counts)
class_weights = total_samples / (num_classes * class_counts)

class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}

# Anpassung der Gewichte auf das One-Hot-kodierte Y_train
Y_train_encoded = np.argmax(Y_train, axis=1)
sample_weights = np.array([class_weights_dict[class_label] for class_label in Y_train_encoded])

# Transformieren, damit die wichtigsten Klassen nicht unterrepräsentiert sind 
# TODO: finde eine gute Funktion dafür
transformed_weights = np.log(sample_weights + 1) #log acc~25% -> funktioniert glaube ich am besten
#transformed_weights = sample_weights ** 2 # square acc~10% -> der ist ziemlich kacke
#transformed_weights = np.exp(sample_weights) # exp acc~7%
#transformed_weights = 1 / (1 + np.exp(-sample_weights)) #sigmoid acc~40%

# %% [markdown]
# ## Modell
# hier ein schönes Modell ergänzen

# %%
model = Sequential()
model.add(Dense(units=64, activation='relu', input_dim=X_train.shape[1]))
model.add(Dropout(0.5))
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=256, activation='relu'))  # Neue Dense-Schicht mit 256 Einheiten hinzugefügt
model.add(Dropout(0.5))
model.add(Dense(units=512, activation='relu'))  # Neue Dense-Schicht mit 512 Einheiten hinzugefügt
model.add(Dropout(0.5))
model.add(Dense(units=num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'], jit_compile=False)

# %%
model.summary()
# Out:
# Model: "sequential_250"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1001 (Dense)          (None, 64)                1024
#
#  dropout_751 (Dropout)       (None, 64)                0
#
#  dense_1002 (Dense)          (None, 128)               8320
#
#  dropout_752 (Dropout)       (None, 128)               0
#
#  dense_1003 (Dense)          (None, 256)               33024
#
#  dropout_753 (Dropout)       (None, 256)               0
#
#  dense_1004 (Dense)          (None, 512)               131584
#
#  dropout_754 (Dropout)       (None, 512)               0
#
#  dense_1005 (Dense)          (None, 28)                14364
#
# =================================================================
# Total params: 188,316
# Trainable params: 188,316
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training

# %%
from keras.callbacks import EarlyStopping

batch_size = 64
nb_epoch = 200

# Definiere die Early Stopping-Bedingungen
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min', restore_best_weights=True)

hist = model.fit(X_train, Y_train, sample_weight=transformed_weights, validation_data=(X_val, Y_val), epochs=nb_epoch, batch_size=batch_size, callbacks=[early_stopping])
# Out:
# Epoch 1/200
# 64/64 [==============================] - 3s 20ms/step - loss: 1.7653 - accuracy: 0.1256 - val_loss: 3.1448 - val_accuracy: 0.3119
# Epoch 2/200
# 64/64 [==============================] - 1s 11ms/step - loss: 1.6990 - accuracy: 0.1775 - val_loss: 2.9569 - val_accuracy: 0.3245
# Epoch 3/200
# 64/64 [==============================] - 1s 12ms/step - loss: 1.6424 - accuracy: 0.2189 - val_loss: 2.7736 - val_accuracy: 0.2883
# Epoch 4/200
# 64/64 [==============================] - 1s 13ms/step - loss: 1.6049 - accuracy: 0.2216 - val_loss: 2.6800 - val_accuracy: 0.2820
# Epoch 5/200
# 64/64 [==============================] - 1s 14ms/step - loss: 1.5589 - accuracy: 0.2388 - val_loss: 2.6015 - val_accuracy: 0.2929
# Epoch 6/200
# 64/64 [==============================] - 1s 16ms/step - loss: 1.5427 - accuracy: 0.2280 - val_loss: 2.5329 - val_accuracy: 0.3027
# Epoch 7/200
# 64/64 [==============================] - 1s 15ms/step - loss: 1.5201 - accuracy: 0.2363 - val_loss: 2.5327 - val_accuracy: 0.3079
# Epoch 8/200
# 64/64 [==============================] - 1s 14ms/step - loss: 1.5121 - accuracy: 0.2383 - val_loss: 2.4984 - val_accuracy: 0.3280
# Epoch 9/200
# 64/64 [==============================] - 1s 14ms/step - loss: 1.4969 - accuracy: 0.2427 - val_loss: 2.4907 - val_accuracy: 0.3188
# Epoch 10/200
# 64/64 [==============================] - 1s 12ms/step - loss: 1.4881 - accuracy: 0.2496 - val_loss: 2.4622 - val_accuracy: 0.3297
# Epoch 11/200
# 64/64 [==============================] - 1s 12ms/step - loss: 1.4534 - accuracy: 0.2708 - val_loss: 2.4959 - val_accuracy: 0.3205
# Epoch 12/200
# 64/64 [==============================] - 1s 12ms/step - loss: 1.4560 - accuracy: 0.2469 - val_loss: 2.4258 - val_accuracy: 0.3584
# Epoch 13/200
# 64/64 [==============================] - 1s 13ms/step - loss: 1.4445 - accuracy: 0.2799 - val_loss: 2.4473 - val_accuracy: 0.3165
# Epoch 14/200
# 64/64 [==============================] - 1s 13ms/step - loss: 1.4342 - accuracy: 0.2642 - val_loss: 2.4200 - val_accuracy: 0.3188
# Epoch 15/200
# 64/64 [==============================] - 1s 14ms/step - loss: 1.4247 - accuracy: 0.2755 - val_loss: 2.3977 - val_accuracy: 0.3354
# Epoch 16/200
# 64/64 [==============================] - 1s 14ms/step - loss: 1.4322 - accuracy: 0.2619 - val_loss: 2.3804 - val_accuracy: 0.3343
# Epoch 17/200
# 64/64 [==============================] - 1s 15ms/step - loss: 1.4175 - accuracy: 0.2693 - val_loss: 2.3978 - val_accuracy: 0.3343
# Epoch 18/200
# 64/64 [==============================] - 1s 15ms/step - loss: 1.4041 - accuracy: 0.2738 - val_loss: 2.3664 - val_accuracy: 0.3395
# Epoch 19/200
# 64/64 [==============================] - 1s 16ms/step - loss: 1.3818 - accuracy: 0.2853 - val_loss: 2.3415 - val_accuracy: 0.3331
# Epoch 20/200
# 64/64 [==============================] - 1s 15ms/step - loss: 1.3917 - accuracy: 0.2971 - val_loss: 2.3035 - val_accuracy: 0.3487
# Epoch 21/200
# 64/64 [==============================] - 1s 15ms/step - loss: 1.3882 - accuracy: 0.2624 - val_loss: 2.3552 - val_accuracy: 0.3349
# Epoch 22/200
# 64/64 [==============================] - 1s 14ms/step - loss: 1.3811 - accuracy: 0.2848 - val_loss: 2.3705 - val_accuracy: 0.3303
# Epoch 23/200
# 64/64 [==============================] - 1s 15ms/step - loss: 1.3813 - accuracy: 0.2851 - val_loss: 2.3199 - val_accuracy: 0.3469
# Epoch 24/200
# 64/64 [==============================] - 1s 19ms/step - loss: 1.3686 - accuracy: 0.2839 - val_loss: 2.3555 - val_accuracy: 0.3285
# Epoch 25/200
# 64/64 [==============================] - 1s 15ms/step - loss: 1.3599 - accuracy: 0.2922 - val_loss: 2.3316 - val_accuracy: 0.3240
# Epoch 26/200
# 64/64 [==============================] - 1s 13ms/step - loss: 1.3628 - accuracy: 0.2841 - val_loss: 2.3361 - val_accuracy: 0.3240
# Epoch 27/200
# 64/64 [==============================] - 1s 11ms/step - loss: 1.3435 - accuracy: 0.2839 - val_loss: 2.2808 - val_accuracy: 0.3544
# Epoch 28/200
# 64/64 [==============================] - 1s 12ms/step - loss: 1.3446 - accuracy: 0.2915 - val_loss: 2.2897 - val_accuracy: 0.3308
# Epoch 29/200
# 64/64 [==============================] - 1s 13ms/step - loss: 1.3291 - accuracy: 0.2824 - val_loss: 2.3108 - val_accuracy: 0.3182
# Epoch 30/200
# 64/64 [==============================] - 1s 15ms/step - loss: 1.3400 - accuracy: 0.2829 - val_loss: 2.2796 - val_accuracy: 0.3280
# Epoch 31/200
# 64/64 [==============================] - 1s 15ms/step - loss: 1.3583 - accuracy: 0.2708 - val_loss: 2.2952 - val_accuracy: 0.3441
# Epoch 32/200
# 64/64 [==============================] - 1s 15ms/step - loss: 1.3388 - accuracy: 0.2991 - val_loss: 2.2980 - val_accuracy: 0.3257
# Epoch 33/200
# 64/64 [==============================] - 1s 15ms/step - loss: 1.3610 - accuracy: 0.2839 - val_loss: 2.3481 - val_accuracy: 0.3211
# Epoch 34/200
# 64/64 [==============================] - 1s 15ms/step - loss: 1.3397 - accuracy: 0.2925 - val_loss: 2.3008 - val_accuracy: 0.3504
# Epoch 35/200
# 64/64 [==============================] - 1s 15ms/step - loss: 1.3278 - accuracy: 0.2880 - val_loss: 2.2896 - val_accuracy: 0.3360
# Epoch 36/200
# 64/64 [==============================] - 1s 15ms/step - loss: 1.3133 - accuracy: 0.2912 - val_loss: 2.2963 - val_accuracy: 0.3331
# Epoch 37/200
# 64/64 [==============================] - 1s 15ms/step - loss: 1.3172 - accuracy: 0.2898 - val_loss: 2.2456 - val_accuracy: 0.3291
# Epoch 38/200
# 64/64 [==============================] - 1s 15ms/step - loss: 1.3113 - accuracy: 0.2856 - val_loss: 2.3089 - val_accuracy: 0.3257
# Epoch 39/200
# 64/64 [==============================] - 1s 16ms/step - loss: 1.3282 - accuracy: 0.2646 - val_loss: 2.2941 - val_accuracy: 0.3245
# Epoch 40/200
# 64/64 [==============================] - 1s 17ms/step - loss: 1.3043 - accuracy: 0.2962 - val_loss: 2.2452 - val_accuracy: 0.3515
# Epoch 41/200
# 64/64 [==============================] - 1s 15ms/step - loss: 1.3314 - accuracy: 0.2969 - val_loss: 2.2894 - val_accuracy: 0.3383
# Epoch 42/200
# 64/64 [==============================] - 1s 14ms/step - loss: 1.3115 - accuracy: 0.2873 - val_loss: 2.2797 - val_accuracy: 0.3262
# Epoch 43/200
# 64/64 [==============================] - 1s 15ms/step - loss: 1.3087 - accuracy: 0.2947 - val_loss: 2.2595 - val_accuracy: 0.3412
# Epoch 44/200
# 64/64 [==============================] - 1s 15ms/step - loss: 1.3182 - accuracy: 0.2949 - val_loss: 2.2792 - val_accuracy: 0.3366
# Epoch 45/200
# 64/64 [==============================] - 1s 15ms/step - loss: 1.2928 - accuracy: 0.2937 - val_loss: 2.2504 - val_accuracy: 0.3418
# Epoch 46/200
# 64/64 [==============================] - 1s 14ms/step - loss: 1.2934 - accuracy: 0.3011 - val_loss: 2.2547 - val_accuracy: 0.3331
# Epoch 47/200
# 64/64 [==============================] - 1s 15ms/step - loss: 1.2964 - accuracy: 0.2952 - val_loss: 2.2581 - val_accuracy: 0.3383
# Epoch 48/200
# 64/64 [==============================] - 1s 15ms/step - loss: 1.2951 - accuracy: 0.2890 - val_loss: 2.3227 - val_accuracy: 0.3038
# Epoch 49/200
# 64/64 [==============================] - 1s 16ms/step - loss: 1.2968 - accuracy: 0.2893 - val_loss: 2.2771 - val_accuracy: 0.3199
# Epoch 50/200
# 64/64 [==============================] - 1s 19ms/step - loss: 1.3027 - accuracy: 0.2829 - val_loss: 2.2429 - val_accuracy: 0.3423
# Epoch 51/200
# 64/64 [==============================] - 1s 16ms/step - loss: 1.2908 - accuracy: 0.2895 - val_loss: 2.2688 - val_accuracy: 0.3245
# Epoch 52/200
# 64/64 [==============================] - 1s 12ms/step - loss: 1.2958 - accuracy: 0.3018 - val_loss: 2.2467 - val_accuracy: 0.3475
# Epoch 53/200
# 64/64 [==============================] - 1s 12ms/step - loss: 1.2723 - accuracy: 0.2989 - val_loss: 2.2305 - val_accuracy: 0.3383
# Epoch 54/200
# 64/64 [==============================] - 1s 12ms/step - loss: 1.2813 - accuracy: 0.2944 - val_loss: 2.2325 - val_accuracy: 0.3268
# Epoch 55/200
# 64/64 [==============================] - 1s 13ms/step - loss: 1.2903 - accuracy: 0.2861 - val_loss: 2.2182 - val_accuracy: 0.3469
# Epoch 56/200
# 64/64 [==============================] - 1s 12ms/step - loss: 1.2862 - accuracy: 0.2843 - val_loss: 2.2374 - val_accuracy: 0.3182
# Epoch 57/200
# 64/64 [==============================] - 1s 13ms/step - loss: 1.2856 - accuracy: 0.2875 - val_loss: 2.2457 - val_accuracy: 0.3136
# Epoch 58/200
# 64/64 [==============================] - 1s 14ms/step - loss: 1.2780 - accuracy: 0.2836 - val_loss: 2.2282 - val_accuracy: 0.3291
# Epoch 59/200
# 64/64 [==============================] - 1s 13ms/step - loss: 1.2898 - accuracy: 0.3028 - val_loss: 2.2488 - val_accuracy: 0.3303
# Epoch 60/200
# 64/64 [==============================] - 1s 15ms/step - loss: 1.2614 - accuracy: 0.2974 - val_loss: 2.2357 - val_accuracy: 0.3194
# Epoch 61/200
# 64/64 [==============================] - 1s 15ms/step - loss: 1.2769 - accuracy: 0.2875 - val_loss: 2.2554 - val_accuracy: 0.3159
# Epoch 62/200
# 64/64 [==============================] - 1s 15ms/step - loss: 1.2623 - accuracy: 0.2971 - val_loss: 2.2420 - val_accuracy: 0.3130
# Epoch 63/200
# 64/64 [==============================] - 1s 15ms/step - loss: 1.2750 - accuracy: 0.2868 - val_loss: 2.2749 - val_accuracy: 0.3159
# Epoch 64/200
# 64/64 [==============================] - 1s 15ms/step - loss: 1.2803 - accuracy: 0.2848 - val_loss: 2.2710 - val_accuracy: 0.3136
# Epoch 65/200
# 64/64 [==============================] - 1s 15ms/step - loss: 1.2628 - accuracy: 0.2984 - val_loss: 2.2490 - val_accuracy: 0.3182

# %%
plot_history(hist)

# %% [markdown]
# ## Vorhersage

# %%
Y_pred = model.predict(X_val)
# Out:
# 55/55 [==============================] - 1s 5ms/step

# %% [markdown]
# ## Evaluation

# %%
# Überprüfung auf Spalte mit nur False-Werten
column_with_only_false = Y_val.columns[(Y_val == False).all()]

# Ausgabe der Spalten mit nur False-Werten
if not column_with_only_false.empty:
    print("Spalte mit nur False-Werten gefunden:", column_with_only_false)
else:
    print("Keine Spalte mit nur False-Werten gefunden.")
# Out:
# Keine Spalte mit nur False-Werten gefunden.

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

Y_pred_classes = np.argmax(Y_pred, axis=1)
Y_val_classes = np.argmax(Y_val, axis=1)

cm = confusion_matrix(Y_val_classes, Y_pred_classes, normalize='true')
plt.figure(figsize=(20,20))
sns.heatmap(cm, annot=True, xticklabels=label, yticklabels=label)
plt.xlabel('Vorhergesagtes Genre')
plt.ylabel('Tatsächliches Genre')
plt.savefig('../figures/confusion_matrix.png')
plt.show()

# %% [markdown]
# ## Hyperparameter Optimierung

# %%
Y_train = Y_train.values
Y_test  = Y_test.values
print(type(Y_train))
print(Y_train.shape)
print(type(Y_test))
print(Y_test.shape)
# Out:
# <class 'numpy.ndarray'>
# (4062, 28)
# <class 'numpy.ndarray'>
# (2487, 28)

# %%
unique_labels_train = np.unique(Y_train)
unique_labels_test = np.unique(Y_test)

print("Einzigartige Labels in Trainingsdaten:", unique_labels_train)
print("Einzigartige Labels in Testdaten:", unique_labels_test)
# Out:
# Einzigartige Labels in Trainingsdaten: [False  True]
# Einzigartige Labels in Testdaten: [False  True]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, accuracy_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.metrics import f1_score


# Definiere die Funktion zur Erstellung des Modells
def create_model(hidden_units=64, dropout_rate=0.5):
    model = Sequential()
    model.add(Dense(units=hidden_units, activation='relu', input_dim=X_train.shape[1]))
    model.add(Dropout(dropout_rate))
    model.add(Dense(units=hidden_units*2, activation='relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(units=hidden_units*4, activation='relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(units=num_classes, activation='sigmoid'))  # Anpassung: 'softmax' zu 'sigmoid'
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])  # Anpassung: 'categorical_crossentropy' zu 'binary_crossentropy'
    return model


# Definiere den Parameterraum für die Grid Search
param_grid = {
    'hidden_units': [64, 128], #[64, 128, 256],
    'dropout_rate': [0.2] #[0.2, 0.5, 0.8]
}

# Definiere den Scorer für die Grid Search
scorer = make_scorer(f1_score)

# Erstelle das GridSearchCV-Objekt
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, scoring=scorer, cv=5)

# Führe die Grid Search durch
grid_search.fit(X_train, Y_train)
# Out:
# 26/26 [==============================] - 0s 3ms/step
# /home/christopher/mambaforge/envs/smd/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/christopher/mambaforge/envs/smd/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/home/christopher/mambaforge/envs/smd/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#   File "/home/christopher/mambaforge/envs/smd/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/home/christopher/mambaforge/envs/smd/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1146, in f1_score
#     return fbeta_score(
#   File "/home/christopher/mambaforge/envs/smd/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1287, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/home/christopher/mambaforge/envs/smd/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1573, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/home/christopher/mambaforge/envs/smd/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1374, in _check_set_wise_labels
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/home/christopher/mambaforge/envs/smd/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(
# 26/26 [==============================] - 0s 2ms/step
# /home/christopher/mambaforge/envs/smd/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/christopher/mambaforge/envs/smd/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/home/christopher/mambaforge/envs/smd/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 234, in __call__
#     return self._score(
#   File "/home/christopher/mambaforge/envs/smd/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 282, in _score
#     return self._sign * self._score_func(y_true, y_pred, **self._kwargs)
#   File "/home/christopher/mambaforge/envs/smd/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1146, in f1_score
#     return fbeta_score(
#   File "/home/christopher/mambaforge/envs/smd/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1287, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/home/christopher/mambaforge/envs/smd/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1573, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/home/christopher/mambaforge/envs/smd/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1374, in _check_set_wise_labels
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/home/christopher/mambaforge/envs/smd/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 95, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and multiclass targets
#
#   warnings.warn(

# %%
# Zugriff auf die besten Parameter und den besten Score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print("Beste Parameter: ", best_params)
print("Best Score: ", best_score)
# Out:
# Beste Parameter:  {'dropout_rate': 0.2, 'hidden_units': 64}
# Best Score:  nan
