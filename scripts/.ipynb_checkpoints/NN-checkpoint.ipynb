# %% [markdown]
# # Notiz für Henry:
# diese Datei ist dafür da das Neuronale Netz zu entwickeln. In einem Notebook kann man schneller Hyperparameter ändern und einfacher weitere kleine Änderungen vornehmen. Wenn das Gröbste steht können wir das Notebook einfach als .py Datei exportieren und sind happy

# %% [markdown]
# ## Importieren der wichtigsten Pakete

# %%
import csv
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
import pandas as pd

# %% [markdown]
# ## Sinnvolle Funktionen

# %%
################################################################################################### 
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_history(network_history):
    plt.figure()
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.plot(network_history.history['loss'])
    plt.plot(network_history.history['val_loss'])
    plt.legend(['Training', 'Validation'])

    plt.figure()
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.plot(network_history.history['accuracy'])
    plt.plot(network_history.history['val_accuracy'])
    plt.legend(['Training', 'Validation'], loc='lower right')
    plt.show()
    
###################################################################################################    

import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        value = f'{cm[i, j]:.3f}'  # Runde den Wert auf 3 Dezimalstellen
        plt.text(j, i, value,
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
################################################################################################### 
import matplotlib.cm as cm
def display_errors(errors_index,img_errors,pred_errors, obs_errors):
    """ This function shows 6 images with their predicted and real labels"""
    n = 0
    nrows = 2
    ncols = 3
    fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True)
    for row in range(nrows):
        for col in range(ncols):
            error = errors_index[n]
            ax[row,col].imshow((img_errors[n]).reshape((28,28)), cmap=cm.Greys, interpolation='nearest')
            ax[row,col].set_title("Predicted label :{}\nTrue label :{}".format(pred_errors[n],obs_errors[n]))
            n += 1
            
###################################################################################################

# %%
def evaluate(X_test, Y_test):
    # Make predictions on test data
    Y_pred = model.predict(X_test)
    # Calculate loss and accuracy
    loss, accuracy = model.evaluate(X_test, Y_test, verbose=0)
    print(f"loss:     {loss:.3}")
    print(f"accuracy: {accuracy:.3}")

    # Compute the classification report
    report = classification_report(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))
    print(report)
    
    # Plot probability of being zero for true !genre! and non-!genre!
    true_genre = np.where(np.argmax(Y_test, axis=1) == 0)[0]
    true_non_genre = np.where(np.argmax(Y_test, axis=1) != 0)[0]
    
    plt.figure()
    plt.hist(Y_pred[true_genre, 0], bins=50, color='red', label='True !genre!', alpha=0.5)
    plt.hist(Y_pred[true_non_genre, 0], bins=50, color='blue', label='True Non-!genre!', alpha=0.5)
    plt.xlabel('Probability of !hier genre einfügen!')
    plt.ylabel('Frequency')
    plt.yscale('log')
    plt.legend()

    # Compute the confusion matrix
    confusion_mtx = confusion_matrix(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))
    # Plot the confusion matrix
    plt.figure(figsize=(10, 10))
    plot_confusion_matrix(confusion_mtx, classes=range(10), normalize='true')

# %% [markdown]
# ## Laden der Daten
# am besten wir fügen das Genre in einer separaten Datei dem Datensatz hinzu und machen ab hier nur mit dem fertigen Datensatz weiter

# %% [markdown]
# ## Convert target

# %%
csv_file = "../data/data_selected.csv"

df = pd.read_csv(csv_file)
df.columns
# Out:
# Index(['Unnamed: 0', 'Danceability', 'Energy', 'Key', 'Loudness',
#        'Speechiness', 'Acousticness', 'Instrumentalness', 'Liveness',
#        'Valence', 'Tempo', 'Duration_ms', 'Views', 'Likes', 'Comments',
#        'Stream', 'Genre'],
#       dtype='object')

# %%
features_drop = ['Genre', 'Unnamed: 0']
X = df.drop(features_drop, axis=1)
Y = df['Genre']

# %%
# One-Hot-Encoding durchführen
Y = pd.get_dummies(Y)

# label um One-Hot-Encoding hinterher wieder zu übersetzen
genre_mapping = Y.columns
label = []
for index, genre in enumerate(genre_mapping):
    label.append(genre)
    print("Genre", index, ":", genre)
# Out:
# Genre 0 : R&B
# Genre 1 : afrobeats
# Genre 2 : alternative rock
# Genre 3 : blues
# Genre 4 : christian
# Genre 5 : christmas
# Genre 6 : classic
# Genre 7 : country
# Genre 8 : cumbia
# Genre 9 : disco
# Genre 10 : electronic
# Genre 11 : film score
# Genre 12 : folk
# Genre 13 : funk
# Genre 14 : hip hop
# Genre 15 : jazz
# Genre 16 : latin
# Genre 17 : metal
# Genre 18 : mexican
# Genre 19 : minimalist music
# Genre 20 : new wave
# Genre 21 : opera
# Genre 22 : pagode
# Genre 23 : pop
# Genre 24 : reggae
# Genre 25 : reggaeton
# Genre 26 : rock
# Genre 27 : sertanejo
# Genre 28 : soul

# %% [markdown]
# ## Splitten von Training und Test Datensätzen

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
X_train, X_val,  Y_train, Y_val  = train_test_split(X_train, Y_train, test_size=0.3, random_state=42)

# %% [markdown]
# ## Daten skalieren

# %%
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Modell
# hier ein schönes Modell ergänzen

# %%
num_classes = len(Y.value_counts())

model = Sequential()
model.add(Dense(units=64, activation='relu', input_dim=X_train.shape[1]))
model.add(Dropout(0.5))
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=256, activation='relu'))  # Neue Dense-Schicht mit 256 Einheiten hinzugefügt
model.add(Dropout(0.5))
model.add(Dense(units=512, activation='relu'))  # Neue Dense-Schicht mit 512 Einheiten hinzugefügt
model.add(Dropout(0.5))
model.add(Dense(units=num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_88 (Dense)            (None, 64)                1024
#
#  dropout_68 (Dropout)        (None, 64)                0
#
#  dense_89 (Dense)            (None, 128)               8320
#
#  dropout_69 (Dropout)        (None, 128)               0
#
#  dense_90 (Dense)            (None, 256)               33024
#
#  dropout_70 (Dropout)        (None, 256)               0
#
#  dense_91 (Dense)            (None, 512)               131584
#
#  dropout_71 (Dropout)        (None, 512)               0
#
#  dense_92 (Dense)            (None, 29)                14877
#
# =================================================================
# Total params: 188,829
# Trainable params: 188,829
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training

# %%
from keras.callbacks import EarlyStopping

batch_size = 64
nb_epoch = 200

# Definiere die Early Stopping-Bedingungen
early_stopping = EarlyStopping(monitor='val_loss', patience=15, mode='min', restore_best_weights=True)

hist = model.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=nb_epoch, batch_size=batch_size, callbacks=[early_stopping])
# Out:
# Epoch 1/200
# 85/85 [==============================] - 2s 13ms/step - loss: 2.6791 - accuracy: 0.2676 - val_loss: 2.5186 - val_accuracy: 0.3496
# Epoch 2/200
# 85/85 [==============================] - 0s 5ms/step - loss: 2.4515 - accuracy: 0.3298 - val_loss: 2.3905 - val_accuracy: 0.3582
# Epoch 3/200
# 85/85 [==============================] - 1s 6ms/step - loss: 2.3604 - accuracy: 0.3416 - val_loss: 2.2775 - val_accuracy: 0.3707
# Epoch 4/200
# 85/85 [==============================] - 0s 6ms/step - loss: 2.2997 - accuracy: 0.3418 - val_loss: 2.1900 - val_accuracy: 0.3784
# Epoch 5/200
# 85/85 [==============================] - 0s 5ms/step - loss: 2.2529 - accuracy: 0.3437 - val_loss: 2.1782 - val_accuracy: 0.3793
# Epoch 6/200
# 85/85 [==============================] - 0s 6ms/step - loss: 2.2185 - accuracy: 0.3598 - val_loss: 2.1420 - val_accuracy: 0.3866
# Epoch 7/200
# 85/85 [==============================] - 0s 5ms/step - loss: 2.1819 - accuracy: 0.3599 - val_loss: 2.1268 - val_accuracy: 0.3754
# Epoch 8/200
# 85/85 [==============================] - 0s 5ms/step - loss: 2.1792 - accuracy: 0.3657 - val_loss: 2.1149 - val_accuracy: 0.3802
# Epoch 9/200
# 85/85 [==============================] - 0s 5ms/step - loss: 2.1413 - accuracy: 0.3675 - val_loss: 2.0954 - val_accuracy: 0.3828
# Epoch 10/200
# 85/85 [==============================] - 1s 6ms/step - loss: 2.1338 - accuracy: 0.3692 - val_loss: 2.0720 - val_accuracy: 0.3897
# Epoch 11/200
# 85/85 [==============================] - 1s 6ms/step - loss: 2.1279 - accuracy: 0.3721 - val_loss: 2.0649 - val_accuracy: 0.3819
# Epoch 12/200
# 85/85 [==============================] - 0s 5ms/step - loss: 2.1102 - accuracy: 0.3745 - val_loss: 2.0630 - val_accuracy: 0.3858
# Epoch 13/200
# 85/85 [==============================] - 0s 5ms/step - loss: 2.1004 - accuracy: 0.3847 - val_loss: 2.0634 - val_accuracy: 0.3806
# Epoch 14/200
# 85/85 [==============================] - 0s 5ms/step - loss: 2.1010 - accuracy: 0.3777 - val_loss: 2.0499 - val_accuracy: 0.3944
# Epoch 15/200
# 85/85 [==============================] - 0s 5ms/step - loss: 2.0853 - accuracy: 0.3780 - val_loss: 2.0505 - val_accuracy: 0.3909
# Epoch 16/200
# 85/85 [==============================] - 0s 6ms/step - loss: 2.0749 - accuracy: 0.3806 - val_loss: 2.0516 - val_accuracy: 0.3931
# Epoch 17/200
# 85/85 [==============================] - 0s 5ms/step - loss: 2.0670 - accuracy: 0.3830 - val_loss: 2.0328 - val_accuracy: 0.3909
# Epoch 18/200
# 85/85 [==============================] - 0s 5ms/step - loss: 2.0664 - accuracy: 0.3838 - val_loss: 2.0358 - val_accuracy: 0.3866
# Epoch 19/200
# 85/85 [==============================] - 1s 6ms/step - loss: 2.0604 - accuracy: 0.3853 - val_loss: 2.0223 - val_accuracy: 0.3909
# Epoch 20/200
# 85/85 [==============================] - 0s 5ms/step - loss: 2.0621 - accuracy: 0.3793 - val_loss: 2.0326 - val_accuracy: 0.3888
# Epoch 21/200
# 85/85 [==============================] - 1s 6ms/step - loss: 2.0425 - accuracy: 0.3906 - val_loss: 2.0298 - val_accuracy: 0.3935
# Epoch 22/200
# 85/85 [==============================] - 0s 6ms/step - loss: 2.0447 - accuracy: 0.3856 - val_loss: 2.0212 - val_accuracy: 0.3983
# Epoch 23/200
# 85/85 [==============================] - 0s 6ms/step - loss: 2.0580 - accuracy: 0.3829 - val_loss: 2.0236 - val_accuracy: 0.3862
# Epoch 24/200
# 85/85 [==============================] - 0s 6ms/step - loss: 2.0402 - accuracy: 0.3912 - val_loss: 2.0175 - val_accuracy: 0.3914
# Epoch 25/200
# 85/85 [==============================] - 0s 6ms/step - loss: 2.0340 - accuracy: 0.3869 - val_loss: 2.0131 - val_accuracy: 0.3957
# Epoch 26/200
# 85/85 [==============================] - 0s 6ms/step - loss: 2.0263 - accuracy: 0.3880 - val_loss: 2.0127 - val_accuracy: 0.4000
# Epoch 27/200
# 85/85 [==============================] - 0s 5ms/step - loss: 2.0310 - accuracy: 0.3847 - val_loss: 2.0086 - val_accuracy: 0.4000
# Epoch 28/200
# 85/85 [==============================] - 0s 6ms/step - loss: 2.0224 - accuracy: 0.3912 - val_loss: 2.0004 - val_accuracy: 0.3931
# Epoch 29/200
# 85/85 [==============================] - 0s 5ms/step - loss: 2.0119 - accuracy: 0.3912 - val_loss: 2.0047 - val_accuracy: 0.3983
# Epoch 30/200
# 85/85 [==============================] - 0s 5ms/step - loss: 2.0175 - accuracy: 0.3897 - val_loss: 2.0022 - val_accuracy: 0.3875
# Epoch 31/200
# 85/85 [==============================] - 0s 6ms/step - loss: 2.0041 - accuracy: 0.3891 - val_loss: 1.9936 - val_accuracy: 0.3957
# Epoch 32/200
# 85/85 [==============================] - 0s 6ms/step - loss: 2.0047 - accuracy: 0.3886 - val_loss: 1.9908 - val_accuracy: 0.3901
# Epoch 33/200
# 85/85 [==============================] - 1s 6ms/step - loss: 1.9950 - accuracy: 0.3891 - val_loss: 1.9907 - val_accuracy: 0.4034
# Epoch 34/200
# 85/85 [==============================] - 1s 6ms/step - loss: 2.0004 - accuracy: 0.3954 - val_loss: 1.9900 - val_accuracy: 0.3909
# Epoch 35/200
# 85/85 [==============================] - 0s 5ms/step - loss: 2.0113 - accuracy: 0.3939 - val_loss: 1.9910 - val_accuracy: 0.4017
# Epoch 36/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9969 - accuracy: 0.3926 - val_loss: 1.9941 - val_accuracy: 0.3961
# Epoch 37/200
# 85/85 [==============================] - 0s 5ms/step - loss: 2.0037 - accuracy: 0.3975 - val_loss: 1.9907 - val_accuracy: 0.3996
# Epoch 38/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.9935 - accuracy: 0.3965 - val_loss: 1.9922 - val_accuracy: 0.3884
# Epoch 39/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9958 - accuracy: 0.3914 - val_loss: 1.9833 - val_accuracy: 0.3944
# Epoch 40/200
# 85/85 [==============================] - 1s 6ms/step - loss: 1.9896 - accuracy: 0.3871 - val_loss: 1.9870 - val_accuracy: 0.3909
# Epoch 41/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.9811 - accuracy: 0.3928 - val_loss: 1.9858 - val_accuracy: 0.3922
# Epoch 42/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.9868 - accuracy: 0.3941 - val_loss: 1.9760 - val_accuracy: 0.4022
# Epoch 43/200
# 85/85 [==============================] - 1s 6ms/step - loss: 1.9833 - accuracy: 0.3938 - val_loss: 1.9835 - val_accuracy: 0.4004
# Epoch 44/200
# 85/85 [==============================] - 1s 6ms/step - loss: 1.9744 - accuracy: 0.3880 - val_loss: 1.9741 - val_accuracy: 0.3944
# Epoch 45/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9845 - accuracy: 0.3954 - val_loss: 1.9791 - val_accuracy: 0.3970
# Epoch 46/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9684 - accuracy: 0.3895 - val_loss: 1.9732 - val_accuracy: 0.3991
# Epoch 47/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9823 - accuracy: 0.3904 - val_loss: 1.9814 - val_accuracy: 0.4004
# Epoch 48/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.9633 - accuracy: 0.4013 - val_loss: 1.9748 - val_accuracy: 0.4004
# Epoch 49/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.9724 - accuracy: 0.3906 - val_loss: 1.9728 - val_accuracy: 0.4009
# Epoch 50/200
# 85/85 [==============================] - 1s 6ms/step - loss: 1.9661 - accuracy: 0.3954 - val_loss: 1.9754 - val_accuracy: 0.4034
# Epoch 51/200
# 85/85 [==============================] - 1s 6ms/step - loss: 1.9771 - accuracy: 0.3926 - val_loss: 1.9723 - val_accuracy: 0.3948
# Epoch 52/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.9715 - accuracy: 0.3884 - val_loss: 1.9686 - val_accuracy: 0.3983
# Epoch 53/200
# 85/85 [==============================] - 1s 6ms/step - loss: 1.9632 - accuracy: 0.3947 - val_loss: 1.9676 - val_accuracy: 0.4052
# Epoch 54/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9718 - accuracy: 0.3950 - val_loss: 1.9794 - val_accuracy: 0.4026
# Epoch 55/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9625 - accuracy: 0.3945 - val_loss: 1.9685 - val_accuracy: 0.4047
# Epoch 56/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9459 - accuracy: 0.4028 - val_loss: 1.9692 - val_accuracy: 0.4073
# Epoch 57/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9501 - accuracy: 0.3995 - val_loss: 1.9650 - val_accuracy: 0.4056
# Epoch 58/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9655 - accuracy: 0.3999 - val_loss: 1.9680 - val_accuracy: 0.3944
# Epoch 59/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9551 - accuracy: 0.4059 - val_loss: 1.9692 - val_accuracy: 0.3987
# Epoch 60/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9616 - accuracy: 0.3914 - val_loss: 1.9632 - val_accuracy: 0.4022
# Epoch 61/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9458 - accuracy: 0.3969 - val_loss: 1.9669 - val_accuracy: 0.3970
# Epoch 62/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9433 - accuracy: 0.3976 - val_loss: 1.9689 - val_accuracy: 0.4034
# Epoch 63/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9466 - accuracy: 0.3986 - val_loss: 1.9561 - val_accuracy: 0.4103
# Epoch 64/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9511 - accuracy: 0.4059 - val_loss: 1.9591 - val_accuracy: 0.4052
# Epoch 65/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.9459 - accuracy: 0.4017 - val_loss: 1.9583 - val_accuracy: 0.3978
# Epoch 66/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.9527 - accuracy: 0.3943 - val_loss: 1.9585 - val_accuracy: 0.4043
# Epoch 67/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.9474 - accuracy: 0.3980 - val_loss: 1.9594 - val_accuracy: 0.4000
# Epoch 68/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.9361 - accuracy: 0.4030 - val_loss: 1.9539 - val_accuracy: 0.4004
# Epoch 69/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.9421 - accuracy: 0.4004 - val_loss: 1.9565 - val_accuracy: 0.4091
# Epoch 70/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.9389 - accuracy: 0.3963 - val_loss: 1.9590 - val_accuracy: 0.4073
# Epoch 71/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.9418 - accuracy: 0.3997 - val_loss: 1.9620 - val_accuracy: 0.4013
# Epoch 72/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.9385 - accuracy: 0.3967 - val_loss: 1.9496 - val_accuracy: 0.4039
# Epoch 73/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.9277 - accuracy: 0.4032 - val_loss: 1.9496 - val_accuracy: 0.4022
# Epoch 74/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.9378 - accuracy: 0.3975 - val_loss: 1.9515 - val_accuracy: 0.4065
# Epoch 75/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.9440 - accuracy: 0.4054 - val_loss: 1.9549 - val_accuracy: 0.4151
# Epoch 76/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.9432 - accuracy: 0.4023 - val_loss: 1.9509 - val_accuracy: 0.4095
# Epoch 77/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.9375 - accuracy: 0.4011 - val_loss: 1.9504 - val_accuracy: 0.4103
# Epoch 78/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.9252 - accuracy: 0.3991 - val_loss: 1.9472 - val_accuracy: 0.4095
# Epoch 79/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.9236 - accuracy: 0.3989 - val_loss: 1.9507 - val_accuracy: 0.4112
# Epoch 80/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.9330 - accuracy: 0.4135 - val_loss: 1.9534 - val_accuracy: 0.4052
# Epoch 81/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.9382 - accuracy: 0.3995 - val_loss: 1.9551 - val_accuracy: 0.4065
# Epoch 82/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9356 - accuracy: 0.4013 - val_loss: 1.9575 - val_accuracy: 0.4052
# Epoch 83/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9289 - accuracy: 0.4008 - val_loss: 1.9508 - val_accuracy: 0.4112
# Epoch 84/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9163 - accuracy: 0.4002 - val_loss: 1.9497 - val_accuracy: 0.4078
# Epoch 85/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9216 - accuracy: 0.4006 - val_loss: 1.9553 - val_accuracy: 0.4034
# Epoch 86/200
# 85/85 [==============================] - 1s 6ms/step - loss: 1.9246 - accuracy: 0.4074 - val_loss: 1.9517 - val_accuracy: 0.4043
# Epoch 87/200
# 85/85 [==============================] - 1s 8ms/step - loss: 1.9238 - accuracy: 0.4058 - val_loss: 1.9532 - val_accuracy: 0.4112
# Epoch 88/200
# 85/85 [==============================] - 1s 6ms/step - loss: 1.9111 - accuracy: 0.4008 - val_loss: 1.9484 - val_accuracy: 0.4134
# Epoch 89/200
# 85/85 [==============================] - 1s 6ms/step - loss: 1.9359 - accuracy: 0.4089 - val_loss: 1.9485 - val_accuracy: 0.4095
# Epoch 90/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9273 - accuracy: 0.3971 - val_loss: 1.9500 - val_accuracy: 0.4060
# Epoch 91/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.9245 - accuracy: 0.3971 - val_loss: 1.9417 - val_accuracy: 0.4103
# Epoch 92/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.9126 - accuracy: 0.4061 - val_loss: 1.9413 - val_accuracy: 0.4052
# Epoch 93/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.9192 - accuracy: 0.3947 - val_loss: 1.9435 - val_accuracy: 0.4103
# Epoch 94/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.9264 - accuracy: 0.4058 - val_loss: 1.9419 - val_accuracy: 0.4112
# Epoch 95/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9231 - accuracy: 0.4063 - val_loss: 1.9484 - val_accuracy: 0.4026
# Epoch 96/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9252 - accuracy: 0.4008 - val_loss: 1.9484 - val_accuracy: 0.4065
# Epoch 97/200
# 85/85 [==============================] - 1s 7ms/step - loss: 1.9105 - accuracy: 0.4047 - val_loss: 1.9451 - val_accuracy: 0.4138
# Epoch 98/200
# 85/85 [==============================] - 1s 6ms/step - loss: 1.9257 - accuracy: 0.4072 - val_loss: 1.9397 - val_accuracy: 0.4060
# Epoch 99/200
# 85/85 [==============================] - 1s 6ms/step - loss: 1.9228 - accuracy: 0.4004 - val_loss: 1.9337 - val_accuracy: 0.4108
# Epoch 100/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9082 - accuracy: 0.4076 - val_loss: 1.9386 - val_accuracy: 0.4099
# Epoch 101/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9099 - accuracy: 0.4063 - val_loss: 1.9417 - val_accuracy: 0.4095
# Epoch 102/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9117 - accuracy: 0.3987 - val_loss: 1.9407 - val_accuracy: 0.4082
# Epoch 103/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9136 - accuracy: 0.3993 - val_loss: 1.9435 - val_accuracy: 0.4086
# Epoch 104/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.9091 - accuracy: 0.4106 - val_loss: 1.9461 - val_accuracy: 0.4082
# Epoch 105/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9068 - accuracy: 0.4034 - val_loss: 1.9478 - val_accuracy: 0.4047
# Epoch 106/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9089 - accuracy: 0.4067 - val_loss: 1.9501 - val_accuracy: 0.4086
# Epoch 107/200
# 85/85 [==============================] - 0s 6ms/step - loss: 1.9183 - accuracy: 0.4076 - val_loss: 1.9426 - val_accuracy: 0.4030
# Epoch 108/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.8980 - accuracy: 0.4163 - val_loss: 1.9506 - val_accuracy: 0.4121
# Epoch 109/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.8934 - accuracy: 0.4128 - val_loss: 1.9424 - val_accuracy: 0.4043
# Epoch 110/200
# 85/85 [==============================] - 1s 6ms/step - loss: 1.9066 - accuracy: 0.4089 - val_loss: 1.9429 - val_accuracy: 0.4017
# Epoch 111/200
# 85/85 [==============================] - 1s 6ms/step - loss: 1.9156 - accuracy: 0.4056 - val_loss: 1.9428 - val_accuracy: 0.4047
# Epoch 112/200
# 85/85 [==============================] - 1s 6ms/step - loss: 1.9048 - accuracy: 0.4002 - val_loss: 1.9466 - val_accuracy: 0.4013
# Epoch 113/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.9020 - accuracy: 0.4072 - val_loss: 1.9431 - val_accuracy: 0.4073
# Epoch 114/200
# 85/85 [==============================] - 0s 5ms/step - loss: 1.8992 - accuracy: 0.4069 - val_loss: 1.9362 - val_accuracy: 0.4034

# %%
plot_history(hist)

# %% [markdown]
# ## Vorhersage

# %%
Y_pred = model.predict(X_val)
# Out:
# 73/73 [==============================] - 0s 1ms/step

# %% [markdown]
# ## Evaluation

# %%
# Überprüfung auf Spalte mit nur False-Werten
column_with_only_false = Y_val.columns[(Y_val == False).all()]

# Ausgabe der Spalten mit nur False-Werten
if not column_with_only_false.empty:
    print("Spalte mit nur False-Werten gefunden:", column_with_only_false)
else:
    print("Keine Spalte mit nur False-Werten gefunden.")
# Out:
# Keine Spalte mit nur False-Werten gefunden.

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

Y_pred_classes = np.argmax(Y_pred, axis=1)
Y_val_classes = np.argmax(Y_val, axis=1)

cm = confusion_matrix(Y_val_classes, Y_pred_classes, normalize='true')
plt.figure(figsize=(20,20))
sns.heatmap(cm, annot=True, xticklabels=label, yticklabels=label)
plt.xlabel('Vorhergesagtes Genre')
plt.ylabel('Tatsächliches Genre')
plt.show()

# %%
evaluate(X_test, Y_test)
# Out:
# 104/104 [==============================] - 0s 1ms/step
# loss:     1.94
# accuracy: 0.415
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       121
#            1       0.00      0.00      0.00        15
#            2       0.30      0.20      0.24       273
#            3       0.00      0.00      0.00        69
#            4       0.00      0.00      0.00        15
#            5       0.00      0.00      0.00        13
#            6       0.37      0.93      0.53        30
#            7       0.00      0.00      0.00       175
#            8       0.00      0.00      0.00         7
#            9       0.00      0.00      0.00        36
#           10       0.28      0.11      0.16       133
#           11       0.00      0.00      0.00        23
#           12       0.00      0.00      0.00        43
#           13       0.00      0.00      0.00        12
#           14       0.57      0.81      0.67       632
#           15       0.00      0.00      0.00        59
#           16       0.34      0.39      0.36        41
#           17       0.56      0.31      0.40        81
#           18       0.00      0.00      0.00        21
#           19       0.00      0.00      0.00         6
#           20       0.00      0.00      0.00        25
#           21       0.00      0.00      0.00        19
#           22       0.22      0.25      0.24         8
#           23       0.37      0.67      0.48       839
#           24       0.00      0.00      0.00        47
#           25       0.18      0.03      0.05        63
#           26       0.33      0.39      0.36       399
#           27       0.00      0.00      0.00        16
#           28       0.00      0.00      0.00        93
#
#     accuracy                           0.42      3314
#    macro avg       0.12      0.14      0.12      3314
# weighted avg       0.30      0.42      0.34      3314
# /home/christopher/mambaforge/envs/smd/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/christopher/mambaforge/envs/smd/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/christopher/mambaforge/envs/smd/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
plot_history(hist)
