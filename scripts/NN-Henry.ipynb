# %% [markdown]
# # Notiz für Henry:
# diese Datei ist dafür da das Neuronale Netz zu entwickeln. In einem Notebook kann man schneller Hyperparameter ändern und einfacher weitere kleine Änderungen vornehmen. Wenn das Gröbste steht können wir das Notebook einfach als .py Datei exportieren und sind happy

# %% [markdown]
# ## Importieren der wichtigsten Pakete

# %%
import csv
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
from sklearn.utils.class_weight import compute_class_weight
import pandas as pd
# Out:
# 2023-06-14 14:16:02.347851: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# GPU Test
import tensorflow as tf

# Funktioniert momentan bei mir immernoch nicht
#if tf.test.is_gpu_available():
#   print("GPU is available")
#   print("GPU(s) that Tensorflow recognizes:", tf.config.list_physical_devices('GPU'))
#else:
#   print("GPU not available")
# Manuell auf CPU einschränken (nur auf Henrys PC nötig)
tf.config.set_visible_devices([], 'GPU')

# %% [markdown]
# ## Sinnvolle Funktionen

# %%
################################################################################################### 
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_history(network_history):
    plt.figure()
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.plot(network_history.history['loss'])
    plt.plot(network_history.history['val_loss'])
    plt.legend(['Training', 'Validation'])

    plt.figure()
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.plot(network_history.history['accuracy'])
    plt.plot(network_history.history['val_accuracy'])
    plt.legend(['Training', 'Validation'], loc='lower right')
    plt.show()
    
###################################################################################################    

import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        value = f'{cm[i, j]:.3f}'  # Runde den Wert auf 3 Dezimalstellen
        plt.text(j, i, value,
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
################################################################################################### 
import matplotlib.cm as cm
def display_errors(errors_index,img_errors,pred_errors, obs_errors):
    """ This function shows 6 images with their predicted and real labels"""
    n = 0
    nrows = 2
    ncols = 3
    fig, ax = plt.subplots(nrows,ncols,sharex=True,sharey=True)
    for row in range(nrows):
        for col in range(ncols):
            error = errors_index[n]
            ax[row,col].imshow((img_errors[n]).reshape((28,28)), cmap=cm.Greys, interpolation='nearest')
            ax[row,col].set_title("Predicted label :{}\nTrue label :{}".format(pred_errors[n],obs_errors[n]))
            n += 1
            
###################################################################################################

# %%
def evaluate(X_test, Y_test):
    # Make predictions on test data
    Y_pred = model.predict(X_test)
    # Calculate loss and accuracy
    loss, accuracy = model.evaluate(X_test, Y_test, verbose=0)
    print(f"loss:     {loss:.3}")
    print(f"accuracy: {accuracy:.3}")

    # Compute the classification report
    report = classification_report(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))
    print(report)
    
    # Plot probability of being zero for true !genre! and non-!genre!
    true_genre = np.where(np.argmax(Y_test, axis=1) == 0)[0]
    true_non_genre = np.where(np.argmax(Y_test, axis=1) != 0)[0]
    
    plt.figure()
    plt.hist(Y_pred[true_genre, 0], bins=50, color='red', label='True !genre!', alpha=0.5)
    plt.hist(Y_pred[true_non_genre, 0], bins=50, color='blue', label='True Non-!genre!', alpha=0.5)
    plt.xlabel('Probability of !hier genre einfügen!')
    plt.ylabel('Frequency')
    plt.yscale('log')
    plt.legend()

    # Compute the confusion matrix
    confusion_mtx = confusion_matrix(np.argmax(Y_test, axis=1), np.argmax(Y_pred, axis=1))
    # Plot the confusion matrix
    plt.figure(figsize=(10, 10))
    plot_confusion_matrix(confusion_mtx, classes=range(10), normalize='true')

# %% [markdown]
# ## Laden der Daten
# Am besten wir fügen das Genre in einer separaten Datei dem Datensatz hinzu und machen ab hier nur mit dem fertigen Datensatz weiter

# %% [markdown]
# ## Convert target

# %%
csv_file = "../data/data_selected.csv"

df = pd.read_csv(csv_file)
df.columns
# Out:
# Index(['Unnamed: 0', 'Danceability', 'Energy', 'Key', 'Loudness',
#        'Speechiness', 'Acousticness', 'Instrumentalness', 'Liveness',
#        'Valence', 'Tempo', 'Duration_ms', 'Views', 'Likes', 'Comments',
#        'Stream', 'Genre'],
#       dtype='object')

# %%
features_drop = ['Genre', 'Unnamed: 0']
X = df.drop(features_drop, axis=1)
Y = df['Genre']

# %%
# One-Hot-Encoding durchführen
Y = pd.get_dummies(Y)

# label um One-Hot-Encoding hinterher wieder zu übersetzen
genre_mapping = Y.columns
label = []
for index, genre in enumerate(genre_mapping):
    label.append(genre)
    print("Genre", index, ":", genre)
# Out:
# Genre 0 : R&B
# Genre 1 : alternative rock
# Genre 2 : blues
# Genre 3 : classic
# Genre 4 : country
# Genre 5 : electronic
# Genre 6 : hip hop
# Genre 7 : jazz
# Genre 8 : latin
# Genre 9 : pop
# Genre 10 : reggaeton
# Genre 11 : rock
# Genre 12 : soul

# %% [markdown]
# ## Splitten von Training und Test Datensätzen

# %%
# Ich möchte gestratified und geshuffelt werden werden
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
X_train, X_val,  Y_train, Y_val  = train_test_split(X_train, Y_train, test_size=0.3, random_state=42)

# %% [markdown]
# ## Daten skalieren

# %%
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Gewichte berechnen um Überrepräsentation zu vermeiden

# %%
from sklearn.utils.class_weight import compute_class_weight

num_classes = len(Y.value_counts())
class_counts = np.sum(Y_train, axis=0)
total_samples = np.sum(class_counts)
class_weights = total_samples / (num_classes * class_counts)

class_weights_dict = {i: weight for i, weight in enumerate(class_weights)}

# Anpassung der Gewichte auf das One-Hot-kodierte Y_train
Y_train_encoded = np.argmax(Y_train, axis=1)
sample_weights = np.array([class_weights_dict[class_label] for class_label in Y_train_encoded])

# Transformieren, damit die wichtigsten Klassen nicht unterrepräsentiert sind 
# TODO: finde eine gute Funktion dafür
transformed_weights = np.log(sample_weights + 1) #log acc~25% -> funktioniert glaube ich am besten
#transformed_weights = sample_weights ** 2 # square acc~10% -> der ist ziemlich kacke
#transformed_weights = np.exp(sample_weights) # exp acc~7%
#transformed_weights = 1 / (1 + np.exp(-sample_weights)) #sigmoid acc~40%

# %% [markdown]
# ## Modell
# hier ein schönes Modell ergänzen

# %%
model = Sequential()
model.add(Dense(units=64, activation='relu', input_dim=X_train.shape[1]))
model.add(Dropout(0.5))
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=256, activation='relu'))  # Neue Dense-Schicht mit 256 Einheiten hinzugefügt
model.add(Dropout(0.5))
model.add(Dense(units=512, activation='relu'))  # Neue Dense-Schicht mit 512 Einheiten hinzugefügt
model.add(Dropout(0.5))
model.add(Dense(units=num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'], jit_compile=False)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                1024
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 256)               33024
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 512)               131584
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 13)                6669
#
# =================================================================
# Total params: 180,621
# Trainable params: 180,621
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training

# %%
from keras.callbacks import EarlyStopping

batch_size = 64
nb_epoch = 200

# Definiere die Early Stopping-Bedingungen
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min', restore_best_weights=True)

#hist = model.fit(X_train, Y_train, sample_weight=transformed_weights, validation_data=(X_val, Y_val), epochs=nb_epoch, batch_size=batch_size, callbacks=[early_stopping])
hist = model.fit(X_train, Y_train, validation_data=(X_val, Y_val), epochs=nb_epoch, batch_size=batch_size, callbacks=[early_stopping])
# Out:
# Epoch 1/200
# 65/65 [==============================] - 1s 7ms/step - loss: 2.2196 - accuracy: 0.2791 - val_loss: 2.1531 - val_accuracy: 0.3952
# Epoch 2/200
# 65/65 [==============================] - 0s 4ms/step - loss: 2.0500 - accuracy: 0.3486 - val_loss: 1.9549 - val_accuracy: 0.4103
# Epoch 3/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.9536 - accuracy: 0.3726 - val_loss: 1.8720 - val_accuracy: 0.4154
# Epoch 4/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.8971 - accuracy: 0.3870 - val_loss: 1.8087 - val_accuracy: 0.4271
# Epoch 5/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.8477 - accuracy: 0.3925 - val_loss: 1.7795 - val_accuracy: 0.4294
# Epoch 6/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.8389 - accuracy: 0.3995 - val_loss: 1.7842 - val_accuracy: 0.4428
# Epoch 7/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.8245 - accuracy: 0.3971 - val_loss: 1.7609 - val_accuracy: 0.4372
# Epoch 8/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.7790 - accuracy: 0.4118 - val_loss: 1.7626 - val_accuracy: 0.4367
# Epoch 9/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.7803 - accuracy: 0.4231 - val_loss: 1.7349 - val_accuracy: 0.4467
# Epoch 10/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.7597 - accuracy: 0.4137 - val_loss: 1.7226 - val_accuracy: 0.4327
# Epoch 11/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.7554 - accuracy: 0.4197 - val_loss: 1.7166 - val_accuracy: 0.4411
# Epoch 12/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.7487 - accuracy: 0.4260 - val_loss: 1.7248 - val_accuracy: 0.4439
# Epoch 13/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.7366 - accuracy: 0.4245 - val_loss: 1.7061 - val_accuracy: 0.4372
# Epoch 14/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.7323 - accuracy: 0.4171 - val_loss: 1.7052 - val_accuracy: 0.4434
# Epoch 15/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.7289 - accuracy: 0.4200 - val_loss: 1.7063 - val_accuracy: 0.4395
# Epoch 16/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.7106 - accuracy: 0.4248 - val_loss: 1.6934 - val_accuracy: 0.4484
# Epoch 17/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.7067 - accuracy: 0.4361 - val_loss: 1.6956 - val_accuracy: 0.4411
# Epoch 18/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.7199 - accuracy: 0.4238 - val_loss: 1.7164 - val_accuracy: 0.4439
# Epoch 19/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.7082 - accuracy: 0.4288 - val_loss: 1.6982 - val_accuracy: 0.4423
# Epoch 20/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.7001 - accuracy: 0.4245 - val_loss: 1.7007 - val_accuracy: 0.4367
# Epoch 21/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6962 - accuracy: 0.4286 - val_loss: 1.6834 - val_accuracy: 0.4496
# Epoch 22/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6891 - accuracy: 0.4356 - val_loss: 1.7008 - val_accuracy: 0.4333
# Epoch 23/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6774 - accuracy: 0.4416 - val_loss: 1.6874 - val_accuracy: 0.4467
# Epoch 24/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6885 - accuracy: 0.4385 - val_loss: 1.6808 - val_accuracy: 0.4518
# Epoch 25/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6697 - accuracy: 0.4368 - val_loss: 1.6791 - val_accuracy: 0.4490
# Epoch 26/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6760 - accuracy: 0.4269 - val_loss: 1.6870 - val_accuracy: 0.4496
# Epoch 27/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6715 - accuracy: 0.4317 - val_loss: 1.6708 - val_accuracy: 0.4456
# Epoch 28/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6600 - accuracy: 0.4430 - val_loss: 1.6743 - val_accuracy: 0.4479
# Epoch 29/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6649 - accuracy: 0.4397 - val_loss: 1.6746 - val_accuracy: 0.4512
# Epoch 30/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6654 - accuracy: 0.4464 - val_loss: 1.6659 - val_accuracy: 0.4540
# Epoch 31/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6668 - accuracy: 0.4363 - val_loss: 1.6675 - val_accuracy: 0.4512
# Epoch 32/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6512 - accuracy: 0.4375 - val_loss: 1.6626 - val_accuracy: 0.4484
# Epoch 33/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6577 - accuracy: 0.4423 - val_loss: 1.6669 - val_accuracy: 0.4473
# Epoch 34/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6558 - accuracy: 0.4363 - val_loss: 1.6795 - val_accuracy: 0.4383
# Epoch 35/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6686 - accuracy: 0.4373 - val_loss: 1.6612 - val_accuracy: 0.4428
# Epoch 36/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6508 - accuracy: 0.4397 - val_loss: 1.6536 - val_accuracy: 0.4445
# Epoch 37/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6585 - accuracy: 0.4459 - val_loss: 1.6612 - val_accuracy: 0.4462
# Epoch 38/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6531 - accuracy: 0.4413 - val_loss: 1.6762 - val_accuracy: 0.4327
# Epoch 39/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6376 - accuracy: 0.4459 - val_loss: 1.6580 - val_accuracy: 0.4411
# Epoch 40/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6413 - accuracy: 0.4466 - val_loss: 1.6562 - val_accuracy: 0.4400
# Epoch 41/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6540 - accuracy: 0.4397 - val_loss: 1.6596 - val_accuracy: 0.4406
# Epoch 42/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6337 - accuracy: 0.4409 - val_loss: 1.6592 - val_accuracy: 0.4512
# Epoch 43/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6410 - accuracy: 0.4466 - val_loss: 1.6627 - val_accuracy: 0.4400
# Epoch 44/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6439 - accuracy: 0.4428 - val_loss: 1.6656 - val_accuracy: 0.4439
# Epoch 45/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6477 - accuracy: 0.4452 - val_loss: 1.6595 - val_accuracy: 0.4434
# Epoch 46/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6350 - accuracy: 0.4430 - val_loss: 1.6511 - val_accuracy: 0.4546
# Epoch 47/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6435 - accuracy: 0.4476 - val_loss: 1.6550 - val_accuracy: 0.4552
# Epoch 48/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6203 - accuracy: 0.4505 - val_loss: 1.6590 - val_accuracy: 0.4355
# Epoch 49/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6255 - accuracy: 0.4493 - val_loss: 1.6605 - val_accuracy: 0.4490
# Epoch 50/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6407 - accuracy: 0.4389 - val_loss: 1.6561 - val_accuracy: 0.4462
# Epoch 51/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6341 - accuracy: 0.4502 - val_loss: 1.6518 - val_accuracy: 0.4507
# Epoch 52/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6207 - accuracy: 0.4476 - val_loss: 1.6482 - val_accuracy: 0.4445
# Epoch 53/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6292 - accuracy: 0.4454 - val_loss: 1.6447 - val_accuracy: 0.4473
# Epoch 54/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6282 - accuracy: 0.4413 - val_loss: 1.6549 - val_accuracy: 0.4496
# Epoch 55/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6204 - accuracy: 0.4500 - val_loss: 1.6616 - val_accuracy: 0.4428
# Epoch 56/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6171 - accuracy: 0.4536 - val_loss: 1.6407 - val_accuracy: 0.4507
# Epoch 57/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6170 - accuracy: 0.4416 - val_loss: 1.6557 - val_accuracy: 0.4439
# Epoch 58/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6237 - accuracy: 0.4466 - val_loss: 1.6491 - val_accuracy: 0.4467
# Epoch 59/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6198 - accuracy: 0.4447 - val_loss: 1.6463 - val_accuracy: 0.4535
# Epoch 60/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6200 - accuracy: 0.4553 - val_loss: 1.6373 - val_accuracy: 0.4479
# Epoch 61/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6110 - accuracy: 0.4498 - val_loss: 1.6484 - val_accuracy: 0.4467
# Epoch 62/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6127 - accuracy: 0.4529 - val_loss: 1.6461 - val_accuracy: 0.4462
# Epoch 63/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6190 - accuracy: 0.4548 - val_loss: 1.6429 - val_accuracy: 0.4540
# Epoch 64/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6082 - accuracy: 0.4519 - val_loss: 1.6356 - val_accuracy: 0.4596
# Epoch 65/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6113 - accuracy: 0.4514 - val_loss: 1.6394 - val_accuracy: 0.4535
# Epoch 66/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6096 - accuracy: 0.4474 - val_loss: 1.6448 - val_accuracy: 0.4445
# Epoch 67/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6117 - accuracy: 0.4550 - val_loss: 1.6364 - val_accuracy: 0.4445
# Epoch 68/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6068 - accuracy: 0.4464 - val_loss: 1.6361 - val_accuracy: 0.4568
# Epoch 69/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6172 - accuracy: 0.4471 - val_loss: 1.6356 - val_accuracy: 0.4496
# Epoch 70/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6119 - accuracy: 0.4476 - val_loss: 1.6338 - val_accuracy: 0.4479
# Epoch 71/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6103 - accuracy: 0.4452 - val_loss: 1.6349 - val_accuracy: 0.4467
# Epoch 72/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5954 - accuracy: 0.4635 - val_loss: 1.6331 - val_accuracy: 0.4512
# Epoch 73/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6075 - accuracy: 0.4534 - val_loss: 1.6418 - val_accuracy: 0.4462
# Epoch 74/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6052 - accuracy: 0.4543 - val_loss: 1.6508 - val_accuracy: 0.4423
# Epoch 75/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6041 - accuracy: 0.4526 - val_loss: 1.6591 - val_accuracy: 0.4439
# Epoch 76/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5997 - accuracy: 0.4526 - val_loss: 1.6411 - val_accuracy: 0.4484
# Epoch 77/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5985 - accuracy: 0.4526 - val_loss: 1.6507 - val_accuracy: 0.4546
# Epoch 78/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.6003 - accuracy: 0.4474 - val_loss: 1.6476 - val_accuracy: 0.4473
# Epoch 79/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5968 - accuracy: 0.4560 - val_loss: 1.6414 - val_accuracy: 0.4507
# Epoch 80/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5979 - accuracy: 0.4606 - val_loss: 1.6311 - val_accuracy: 0.4512
# Epoch 81/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5959 - accuracy: 0.4541 - val_loss: 1.6294 - val_accuracy: 0.4473
# Epoch 82/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5892 - accuracy: 0.4536 - val_loss: 1.6301 - val_accuracy: 0.4546
# Epoch 83/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5959 - accuracy: 0.4601 - val_loss: 1.6283 - val_accuracy: 0.4507
# Epoch 84/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5865 - accuracy: 0.4572 - val_loss: 1.6360 - val_accuracy: 0.4518
# Epoch 85/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5971 - accuracy: 0.4563 - val_loss: 1.6339 - val_accuracy: 0.4490
# Epoch 86/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5832 - accuracy: 0.4567 - val_loss: 1.6284 - val_accuracy: 0.4552
# Epoch 87/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5845 - accuracy: 0.4572 - val_loss: 1.6228 - val_accuracy: 0.4529
# Epoch 88/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5902 - accuracy: 0.4577 - val_loss: 1.6278 - val_accuracy: 0.4585
# Epoch 89/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5813 - accuracy: 0.4644 - val_loss: 1.6430 - val_accuracy: 0.4501
# Epoch 90/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5808 - accuracy: 0.4644 - val_loss: 1.6243 - val_accuracy: 0.4563
# Epoch 91/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5901 - accuracy: 0.4524 - val_loss: 1.6319 - val_accuracy: 0.4580
# Epoch 92/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5790 - accuracy: 0.4688 - val_loss: 1.6241 - val_accuracy: 0.4524
# Epoch 93/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5877 - accuracy: 0.4608 - val_loss: 1.6325 - val_accuracy: 0.4557
# Epoch 94/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5791 - accuracy: 0.4594 - val_loss: 1.6372 - val_accuracy: 0.4490
# Epoch 95/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5977 - accuracy: 0.4608 - val_loss: 1.6216 - val_accuracy: 0.4591
# Epoch 96/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5675 - accuracy: 0.4558 - val_loss: 1.6258 - val_accuracy: 0.4596
# Epoch 97/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5815 - accuracy: 0.4611 - val_loss: 1.6259 - val_accuracy: 0.4568
# Epoch 98/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5849 - accuracy: 0.4579 - val_loss: 1.6324 - val_accuracy: 0.4574
# Epoch 99/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5823 - accuracy: 0.4599 - val_loss: 1.6339 - val_accuracy: 0.4535
# Epoch 100/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5748 - accuracy: 0.4649 - val_loss: 1.6293 - val_accuracy: 0.4496
# Epoch 101/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5746 - accuracy: 0.4579 - val_loss: 1.6260 - val_accuracy: 0.4557
# Epoch 102/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5666 - accuracy: 0.4642 - val_loss: 1.6277 - val_accuracy: 0.4529
# Epoch 103/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5744 - accuracy: 0.4582 - val_loss: 1.6362 - val_accuracy: 0.4591
# Epoch 104/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5933 - accuracy: 0.4671 - val_loss: 1.6397 - val_accuracy: 0.4540
# Epoch 105/200
# 65/65 [==============================] - 0s 4ms/step - loss: 1.5662 - accuracy: 0.4690 - val_loss: 1.6259 - val_accuracy: 0.4518

# %%
plot_history(hist)

# %% [markdown]
# ## Vorhersage

# %%
Y_pred = model.predict(X_val)
# Out:
# 56/56 [==============================] - 0s 942us/step

# %% [markdown]
# ## Evaluation

# %%
# Überprüfung auf Spalte mit nur False-Werten
column_with_only_false = Y_val.columns[(Y_val == False).all()]

# Ausgabe der Spalten mit nur False-Werten
if not column_with_only_false.empty:
    print("Spalte mit nur False-Werten gefunden:", column_with_only_false)
else:
    print("Keine Spalte mit nur False-Werten gefunden.")
# Out:
# Keine Spalte mit nur False-Werten gefunden.

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

Y_pred_classes = np.argmax(Y_pred, axis=1)
Y_val_classes = np.argmax(Y_val, axis=1)

cm = confusion_matrix(Y_val_classes, Y_pred_classes, normalize='true')
plt.figure(figsize=(20,20))
sns.heatmap(cm, annot=True, xticklabels=label, yticklabels=label)
plt.xlabel('Vorhergesagtes Genre')
plt.ylabel('Tatsächliches Genre')
plt.savefig('../figures/confusion_matrix.png')
plt.show()

# %% [markdown]
# ## Hyperparameter Optimierung
# scheint noch nicht richtig zu laufen

# %%
Y_train = Y_train.values
Y_test  = Y_test.values
print(type(Y_train))
print(Y_train.shape)
print(type(Y_test))
print(Y_test.shape)
# Out:
# <class 'numpy.ndarray'>
# (5412, 29)
# <class 'numpy.ndarray'>
# (3314, 29)

# %%
unique_labels_train = np.unique(Y_train)
unique_labels_test = np.unique(Y_test)

print("Einzigartige Labels in Trainingsdaten:", unique_labels_train)
print("Einzigartige Labels in Testdaten:", unique_labels_test)
# Out:
# Einzigartige Labels in Trainingsdaten: [False  True]
# Einzigartige Labels in Testdaten: [False  True]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, accuracy_score
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.metrics import f1_score


# Definiere die Funktion zur Erstellung des Modells
def create_model(hidden_units=64, dropout_rate=0.5):
    model = Sequential()
    model.add(Dense(units=hidden_units, activation='relu', input_dim=X_train.shape[1]))
    model.add(Dropout(dropout_rate))
    model.add(Dense(units=hidden_units*2, activation='relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(units=hidden_units*4, activation='relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(units=num_classes, activation='sigmoid'))  # Anpassung: 'softmax' zu 'sigmoid'
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])  # Anpassung: 'categorical_crossentropy' zu 'binary_crossentropy'
    return model


# Definiere den Parameterraum für die Grid Search
param_grid = {
    'hidden_units': [64, 128], #[64, 128, 256],
    'dropout_rate': [0.2] #[0.2, 0.5, 0.8]
}

# Definiere den Scorer für die Grid Search
scorer = make_scorer(f1_score)

# Erstelle das GridSearchCV-Objekt
grid_search = GridSearchCV(estimator=model, param_grid=param_grid, scoring=scorer, cv=5)

# Führe die Grid Search durch
grid_search.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[97], line 36
#      33 grid_search = GridSearchCV(estimator=model, param_grid=param_grid, scoring=scorer, cv=5)
#      35 # Führe die Grid Search durch
# ---> 36 grid_search.fit(X_train, Y_train)
#
# File ~/mambaforge/envs/smd/lib/python3.10/site-packages/sklearn/model_selection/_search.py:788, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     785 cv_orig = check_cv(self.cv, y, classifier=is_classifier(estimator))
#     786 n_splits = cv_orig.get_n_splits(X, y, groups)
# --> 788 base_estimator = clone(self.estimator)
#     790 parallel = Parallel(n_jobs=self.n_jobs, pre_dispatch=self.pre_dispatch)
#     792 fit_and_score_kwargs = dict(
#     793     scorer=scorers,
#     794     fit_params=fit_params,
#    (...)
#     800     verbose=self.verbose,
#     801 )
#
# File ~/mambaforge/envs/smd/lib/python3.10/site-packages/sklearn/base.py:79, in clone(estimator, safe)
#      73             raise TypeError(
#      74                 "Cannot clone object. "
#      75                 + "You should provide an instance of "
#      76                 + "scikit-learn estimator instead of a class."
#      77             )
#      78         else:
# ---> 79             raise TypeError(
#      80                 "Cannot clone object '%s' (type %s): "
#      81                 "it does not seem to be a scikit-learn "
#      82                 "estimator as it does not implement a "
#      83                 "'get_params' method." % (repr(estimator), type(estimator))
#      84             )
#      86 klass = estimator.__class__
#      87 new_object_params = estimator.get_params(deep=False)
#
# TypeError: Cannot clone object '<keras.engine.sequential.Sequential object at 0x7fedc4515f00>' (type <class 'keras.engine.sequential.Sequential'>): it does not seem to be a scikit-learn estimator as it does not implement a 'get_params' method.

# %%
# Zugriff auf die besten Parameter und den besten Score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print("Beste Parameter: ", best_params)
print("Best Score: ", best_score)
