# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/data_selected_v1.csv", index_col=0)
df.describe()
# Out:
#        Danceability        Energy           Key      Loudness   Speechiness  \
# count  12774.000000  12774.000000  12774.000000  12774.000000  12774.000000
# mean       0.610532      0.644513      5.301472     -7.490117      0.087910
# std        0.162042      0.211680      3.579827      4.176477      0.092222
# min        0.000000      0.001440      0.000000    -43.988000      0.000000
# 25%        0.506000      0.518000      2.000000     -8.789000      0.034500
# 50%        0.624000      0.675000      5.000000     -6.506000      0.047800
# 75%        0.729000      0.806000      8.000000     -4.906000      0.092900
# max        0.975000      0.998000     11.000000      0.920000      0.944000
#
#        Acousticness  Instrumentalness      Liveness       Valence  \
# count  12774.000000      12774.000000  12774.000000  12774.000000
# mean       0.262299          0.047796      0.190446      0.522359
# std        0.279928          0.172277      0.160988      0.242539
# ...

# %% [markdown]
# Start mit "Danceability"

# %%
sns.histplot(df["Danceability"])
plt.title("Verteilung der Danceability")
# Out:
# Text(0.5, 1.0, 'Verteilung der Danceability')

# %% [markdown]
# Energy

# %%
sns.histplot(df["Energy"])
plt.title("Verteilung der Energy")
# Out:
# Text(0.5, 1.0, 'Verteilung der Energy')

# %% [markdown]
# Hat einen zu starken Tail nach links, sollte daher transformiert werden
